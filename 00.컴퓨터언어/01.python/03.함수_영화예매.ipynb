# %%
customer_check = 'none'

while customer_check == 'none':
    movies = ['Dark Knight','Harry Porter','Parasite','Matrix','La La Land']

    print()
    print('{0:^40}'.format('==========영화 목록=========='))
    for movie in movies:
        formatted = print('')
        print('{0:^40}'.format(movie),end="\n")
    print('{0:^40}'.format('============================'))

    choice = input('예매하실 영화를 입력해주세요: ')

    while choice not in movies:
        print()
        print('예매할 수 없는 영화입니다')
        choice = input('예매하실 영화를 다시 선택해주세요: ')
    print()
    print('%s를 선택하셨습니다.' %choice)

    check = False
    while(not(check)):
        try:
            people = int(input('관람 인원 수를 입력해주세요: '))
            if not people > 0:
                print('관람 인원 수는 양수만 가능합니다.')
            else:
                break

        except ValueError:        
            print('관람 인원 수는 정수만 가능합니다')
    print()
    print('관람할 인원 수는 %s명입니다.' % people)
    print()

    coupon_dic = {'WELCOME':2000,'VALENTINE':3000,'CHRISTMAS':4000,'INDEPENDENCE':5000}
    process = True

    usage = input('할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: ')

    while process:
        if usage == 'y':
            coupon = input('쿠폰 코드를 입력해주세요: ')
            if coupon in coupon_dic:
                sale = coupon_dic.get(coupon)
                print('한 사람 당 %d원 할인됩니다.' %sale)
                process = False
            else:
                print('존재하지 않는 쿠폰 코드입니다.')
                usage = input('다른 쿠폰 코드를 입력하려면 y, 아니면 n를 입력해주세요: ')
                process = False
        elif usage == 'n':
            sale = 0
            print('할인권을 사용하지 않았습니다.')
            process = False
        else:
            usage = input('잘못된 입력입니다. 할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: ')


    origin_price = 12000 * people
    sale_price = people * sale
    total_price = origin_price - sale_price

    print('')
    print('{0:^30}'.format('<예매 상세 내역>'))
    print('{0:^30}'.format('=============================='))
    print(f'  예매 영화: {choice}')
    print(f'  관람 인원 : {people}')
    print('  합산 금액: %d' % origin_price)
    print('  할인 금액: %d' % sale_price)
    print('{0:^30}'.format('-------------------------'))
    print('  실 결제액을 출력합니다: %d' % total_price)
    print('{0:^30}'.format('=============================='))            
    
    checking = True
    customer_check = input('예매 상세 내역을 확인해주세요. 맞으면 y, 틀리면 n을 입력해주세요: ')

    while checking :
        if customer_check == 'n':
            print('다시 예매해주세요.')
            break
        elif customer_check == 'y':
            print()
            print('티켓이 출력됩니다. 즐거운 관람 되세요')
            break 
        else:
            input('예매 상세 내역이 맞으면 y, 틀리면 n를 입력해주세요: ')

print()
print('예매가 종료되었습니다. 시작 화면으로 돌아갑니다.')
# Out:
#        ==========영화 목록==========
#
#               Dark Knight
#
#               Harry Porter
#
#                 Parasite
#
#                  Matrix
#
#                La La Land
#       ============================
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다
#
# 예매할 수 없는 영화입니다

# %%
ticketing = True

while ticketing:
    movies = ['Dark Knight','Harry Porter','Parasite','Matrix','La La Land']

    print()
    print('{0:^40}'.format('==========영화 목록=========='))
    for movie in movies:
        formatted = print('')
        print('{0:^40}'.format(movie),end="\n")
    print('{0:^40}'.format('============================'))

    choice = input('예매하실 영화를 입력해주세요: ')

    while choice not in movies:
        print()
        print('예매할 수 없는 영화입니다')
        choice = input('예매하실 영화를 다시 선택해주세요: ')
    print()
    print('%s를 선택하셨습니다.' %choice)

    check = False
    while(not(check)):
        try:
            people = int(input('관람 인원 수를 입력해주세요: '))
            if not people > 0:
                print('관람 인원 수는 양수만 가능합니다.')
            else:
                break

        except ValueError:        
            print('관람 인원 수는 정수만 가능합니다')
    print()
    print('관람할 인원 수는 %s명입니다.' % people)
    print()

    coupon_dic = {'WELCOME':2000,'VALENTINE':3000,'CHRISTMAS':4000,'INDEPENDENCE':5000}
    process = True

    usage = input('할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: ')

    while process:
        if usage == 'y':
            coupon = input('쿠폰 코드를 입력해주세요: ')
            if coupon in coupon_dic:
                sale = coupon_dic.get(coupon)
                print('한 사람 당 %d원 할인됩니다.' %sale)
                process = False
            else:
                print('존재하지 않는 쿠폰 코드입니다.')
                usage = input('다른 쿠폰 코드를 입력하려면 y, 아니면 n를 입력해주세요: ')
                process = False
        elif usage == 'n':
            sale = 0
            print('할인권을 사용하지 않았습니다.')
            process = False
        else:
            usage = input('잘못된 입력입니다. 할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: ')


    origin_price = 12000 * people
    sale_price = people * sale
    total_price = origin_price - sale_price

    print('')
    print('{0:^30}'.format('<예매 상세 내역>'))
    print('{0:^30}'.format('=============================='))
    print(f'  예매 영화: {choice}')
    print(f'  관람 인원 : {people}')
    print('  합산 금액: %d' % origin_price)
    print('  할인 금액: %d' % sale_price)
    print('{0:^30}'.format('-------------------------'))
    print('  실 결제액을 출력합니다: %d' % total_price)
    print('{0:^30}'.format('=============================='))            
    
    customer_check = input('예매 상세 내역을 확인해주세요. 맞으면 y, 틀리면 n을 입력해주세요: ')
    if customer_check == 'n':
        print('다시 예매해주세요.')
        continue
    elif customer_check == 'y':
        print()
        print('티켓이 출력됩니다. 즐거운 관람 되세요')
        break 
    else:
        input('예매 상세 내역이 맞으면 y, 틀리면 n를 입력해주세요: ')

print()
print('예매가 종료되었습니다. 시작 화면으로 돌아갑니다.')
# Out:
#        ==========영화 목록==========
#
#               Dark Knight
#
#               Harry Porter
#
#                 Parasite
#
#                  Matrix
#
#                La La Land
#       ============================
# 예매하실 영화를 입력해주세요: Matrix
#
# Matrix를 선택하셨습니다.
# 관람 인원 수를 입력해주세요: 3
#
# 관람할 인원 수는 3명입니다.
#
# 할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: y
# 쿠폰 코드를 입력해주세요: WELCOME
# 한 사람 당 2000원 할인됩니다.
#
#           <예매 상세 내역>
# ==============================
#   예매 영화: Matrix
#   관람 인원 : 3
#   합산 금액: 36000
#   할인 금액: 6000
#   -------------------------
#   실 결제액을 출력합니다: 30000
# ==============================
# 예매 상세 내역을 확인해주세요. 맞으면 y, 틀리면 n을 입력해주세요: n
# 다시 예매해주세요.
#
#        ==========영화 목록==========
#
#               Dark Knight
#
#               Harry Porter
#
#                 Parasite
#
#                  Matrix
#
#                La La Land
#       ============================
# 예매하실 영화를 입력해주세요: Matrix
#
# Matrix를 선택하셨습니다.
# 관람 인원 수를 입력해주세요: 2
#
# 관람할 인원 수는 2명입니다.
#
# 할인권을 사용하시려면 y, 금액 확인으로 넘어가시려면 n을 입력해주세요: y
# 쿠폰 코드를 입력해주세요: WELCOME
# 한 사람 당 2000원 할인됩니다.
#
#           <예매 상세 내역>
# ==============================
#   예매 영화: Matrix
#   관람 인원 : 2
#   합산 금액: 24000
#   할인 금액: 4000
#   -------------------------
#   실 결제액을 출력합니다: 20000
# ==============================
# 예매 상세 내역을 확인해주세요. 맞으면 y, 틀리면 n을 입력해주세요: y
#
# 티켓이 출력됩니다. 즐거운 관람 되세요
#
# 예매가 종료되었습니다. 시작 화면으로 돌아갑니다.

# %%
#미션01. 문자가 입력되면 거꾸로 출력하기

original = input('영어 문장을 입력해주세요: ')
changable = list(original)
changable.reverse()
changable
x = ''
for i in range(0,len(changable))
    x = x + changable[i]

print(x)
# Out:
#   Cell In[39], line 8
#     for i in range(0,len(changable))
#                                     ^
# SyntaxError: expected ':'
