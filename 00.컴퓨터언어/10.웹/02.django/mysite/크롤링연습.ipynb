# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import pandas as pd
import requests

code = '005930'

url = f'https://finance.naver.com/item/sise.nhn?code={code}'
html = requests.get(url)
soup = BeautifulSoup(html.text,"html.parser")
middle = soup.find("div",id={'middle'})

stock_name = middle.select("div > div > h2 > a")[0].text
stock_name

# %%
tables = middle.find("div",{"class":'section inner_sub'})
tables
# Out:
# <div class="section inner_sub">
# <div style="float:left;width:381px;margin-right:9px;">
# <h4 class="tlline2"><strong><span class="red03">주요</span>시세</strong></h4>
# <table cellspacing="0" class="type2 type_tax" summary="주요시세 정보에 관한표 입니다.">
# <caption>주요시세</caption>
# <tbody>
# <tr>
# <th class="title">현재가</th>
# <td class="num"><strong class="tah p11" id="_nowVal">73,600</strong></td>
# <th class="title">매도호가</th>
# <td class="num"><span class="tah p11">73,800</span></td>
# </tr>
# <tr>
# <th class="title">전일대비</th>
# <td class="num"><strong id="_diff">
# <em class="bu_p bu_pdn" style="margin:0 4px 0 0"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				1,600
# 				</span>
# </strong></td>
# <th class="title">매수호가</th>
# <td class="num"><span class="tah p11">73,700</span></td>
# </tr>
# <tr>
# <th class="title">등락률(%)</th>
# <td class="num"><strong id="_rate">
# <span class="tah p11 nv01">
# 				-2.13%
# 				</span>
# </strong></td>
# <th class="title">전일가</th>
# ...

# %%
len(tables)
# Out:
# 0

# %%
tables = middle.select("div.inner_sub > h4.tlline2 > table.type_tax")
tables = tables.find_all("tr")
cur_price = tables[0]
cur_rate = tables[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 2
#       1 tables = middle.select("div.inner_sub > h4.tlline2 > table.type_tax")
# ----> 2 tables = tables.find_all("tr")
#       3 cur_price = tables[0]
#       4 cur_rate = tables[2]
#
# File ~/anaconda3/lib/python3.11/site-packages/bs4/element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# ...
