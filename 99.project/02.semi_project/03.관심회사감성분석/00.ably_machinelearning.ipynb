# %% [markdown]
# # 서비스 기획 _ 에이블리 뷰티 리뷰 분석
# ---

# %% [markdown]
# # 감성분석

# %% [markdown]
# ## 1. 뷰티 언급 댓글 리뷰분석

# %%
import pandas as pd
beauty_filtered = pd.read_csv('./data/ably_beauty_filtered.csv')

# %% [markdown]
# ### 토큰화 1: Kiwi

# %%
from kiwipiepy import Kiwi

kiwi = Kiwi()

# %%
def extract_keywords(text):
    result = kiwi.analyze(text)
    for token, pos, _, _ in result[0][0]:
        if pos[0] in 'NV':
            yield f'{token}/{pos}'

# %%
def extract_keywords2(text):
    result = kiwi.analyze(text)
    for token, pos, _, _ in result[0][0]:
        if pos[0] in 'NVM':
            yield f'{token}/{pos}'

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

cv = CountVectorizer(max_features=500, tokenizer=extract_keywords)

# %%
dtm = cv.fit_transform(beauty_filtered['content'][:])
dtm
# Out:
# /Users/brielle/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# <58x486 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1267 stored elements in Compressed Sparse Row format>

# %%
trans = TfidfTransformer()
tf_idf = trans.fit_transform(dtm)
tf_idf
# Out:
# <58x486 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1267 stored elements in Compressed Sparse Row format>

# %%
words = cv.get_feature_names_out()
words
# Out:
# array(['..리뷰/NNG', '가/VV', '가격/NNG', '가격대/NNG', '가능/NNG', '가방/NNG',
#        '가성비/NNG', '가입/NNG', '가지/NNB', '간식/NNG', '감사/NNG', '강제/NNG',
#        '같/VA', '개/NNB', '개/NNG', '개/VV', '개발자/NNG', '개편/NNG', '갯수/NNG',
#        '거/NNB', '거/NP', '거기/NP', '걱정/NNG', '건/NNG', '걸리/VV', '것/NNB',
#        '결국/NNG', '결제/NNG', '경우/NNG', '계산/NNG', '계정/NNG', '계정/NNP',
#        '고/NNG', '고냥/NNG', '고려/NNG', '고민/NNG', '곳/NNG', '공감/NNG', '공구/NNG',
#        '관계자/NNG', '관심/NNG', '광고/NNG', '괜찮/VA', '구경/NNG', '구매/NNG',
#        '구매처/NNG', '구입/NNG', '굿즈/NNG', '궂/VA', '그거/NP', '그것/NP', '그러/VV',
#        '그렇/VA', '금액/NNG', '기능/NNG', '기대/NNG', '기부/NNG', '기쁘/VA', '기존/NNG',
#        '기한/NNG', '기획전/NNG', '깔/VV', '꺼/NNB', '꼽/VV-R', '꾸미/VV', '끊기/VV',
#        '나/NP', '나/VV', '나/VX', '나누/VV', '나오/VV', '나이/NNG', '날짜/NNG',
#        '남/VV', '남기/VV', '낮/VA', '내리/VV', '넘어가/VV', '넘조아요/NNG', '넘치/VV',
#        '넣/VV', '놀랍/VA-I', '놓/VX', '누구/NP', '누르/VV', '눈물/NNG', '느리/VA',
#        '늘리/VV', '늦/VA', '다그/VV', '다양/NNG', '다음/NNG', '다이어리/NNG',
#        '다이어트/NNG', '다행/NNG', '단점/NNG', '달/VV', '달리/VV', '답변/NNG', '대/NNB',
#        '대단하/VA', '대한민국/NNP', '댓글/NNG', '더럽/VA-I', '데/NNB', '데코/NNG',
#        '도구/NNG', '도착/NNG', '돼지/NNG', '되/VV', '두/VX', '드나들/VV', '드리/VV',
#        '득테/NNG', '듣/VV-I', '들/VV', '들어가/VV', '들어오/VV', '듯/NNB', '등/NNB',
#        '등/NNG', '등등/NNB', '때/NNG', '때리/VV', '때문/NNB', '또래/NNG', '똑같/VA',
#        '똥/NNG', '뜨/VV', '랭킹/NNG', '렉/NNG', '로그인/NNG', '리거/NNG', '리뷰/NNG',
#        '립밤/NNP', '마음/NNG', '마찬가지/NNG', '마켓/NNG', '만들/VV', '만약/NNG',
#        '만족/NNG', '만큼/NNB', '많/VA', '많리/NNG', '말/VV', '말/VX', '맘/NNG',
#        '먹/VV', '먹거리/NNG', '며칠/NNG', '명품/NNG', '모르/VV', '모으/VV', '모이/VV',
#        '모자/NNG', '몰/VV', '무/NNG', '무료/NNG', '무엇/NP', '문구/NNG', '문의/NNG',
#        '문자/NNG', '문제/NNG', '묻/VV-I', '묻/VV-R', '묻히/VV', '물/NNG', '물건/NNG',
#        '뭐/NP', '미션/NNG', '믾이/NNG', '믿/VV-R', '바라/VV', '바람/NNG', '바지/NNG',
#        '반지/NNG', '받/VV-R', '발생/NNG', '밥/NNG', '배송/NNG', '배송비/NNG',
#        '버리/VV', '버리/VX', '번/NNB', '번호/NNG', '법/NNG', '변동/NNG', '별점/NNG',
#        '보/VV', '보/VX', '보내/VV', '보세/NNG', '본질/NNG', '부모/NNG', '부분/NNG',
#        '부탁/NNG', '분/NNB', '분/NNG', '불/VV', '뷰티/NNG', '뷰티/NNP', '뷰티템/NNG',
#        '브랜드/NNG', '비/NNG', '비교/NNG', '비누/NNG', '비싸/VA', '빠르/VA', '빼/VV',
#        '뻔/NNB', '뻘겋/VA', '뿌리/VV', '뿐/NNB', '사/NNG', '사/VV', '사람/NNG',
#        '사랑해/NNP', '사용/NNG', '사이트/NNG', '삭제/NNG', '살/VV', '삼/NR', '상태/NNG',
#        '상품/NNG', '새/VV', '새마을금고/NNP', '색/NNG', '생각/NNG', '생활/NNG',
#        '서리/NNG', '설명/NNG', '설정/NNG', '설치/NNG', '세상/NNG', '셀럽/NNG',
#        '소리/NNG', '소마/NNG', '소비자/NNG', '소품/NNG', '속바지/NNG', '속옷/NNG',
#        '쇼핑/NNG', '쇼핑몰/NNG', '수/NNB', '수단/NNG', '순/NNG', '숯/NNG', '쉽/VA-I',
#        '스/VV', '스타일/NNG', '스티커/NNG', '시/NNG', '시간/NNG', '시키/VV',
#        '시킬수있을걱/NNG', '식품/NNG', '신발/NNG', '신세계/NNP', '실망/NNG', '실밥/NNG',
#        '실용/NNG', '싫/VA', '심/VV', '싶/VX', '싸/VA', '싸/VV', '쓰/VV', '씨/NNG',
#        '씨앗/NNG', '아깝/VA-I', '아니/VCN', '아쉽/VA-I', '아이디/NNG', '악/NNG',
#        '악기/NNG', '악세사리/NNG', '악세서리/NNG', '않/VX', '알/VV', '압도/NNG',
#        '앞/NNG', '애용/NNG', '앱/NNG', '약속/NNG', '얘기/NNG', '어디/NP', '어떻/VA',
#        '어이/NNG', '어이없/VA', '어제/NNG', '어쩌/VV', '어플/NNG', '어플리케이션/NNG',
#        '언니/NNG', '얼마/NNG', '업뎃/NNG', '없/VA', '엉덩이/NNG', '에블리/NNG',
#        '에이블리/NNG', '에이블리/NNP', '여기/NP', '여러분/NP', '여부/NNG', '여성/NNG',
#        '여자/NNG', '열/NR', '열리/VV', '영/NNG', '예/NNG', '예쁘/VA', '예상/NNG',
#        '예전/NNG', '오/VV', '오늘/NNG', '오류/NNG', '옷/NNG', '요번/NNG', '요즘/NNG',
#        '용품/NNG', '우/NNG', '원/NNB', '원피스/NNG', '월/NNB', '웨이크메이크/NNG',
#        '위/NNG', '유명/NNG', '유용/NNG', '유저/NNG', '융/NNG', '이/NP', '이/VCP',
#        '이거/NP', '이것/NP', '이것저것/NNG', '이내/NNG', '이동/NNG', '이득/NNG',
#        '이메일/NNG', '이벤트/NNG', '이불/NNG', '이쁘/VA', '이상/NNG', '이용/NNG',
#        '이후/NNG', '인기/NNG', '인스/NNP', '인스타/NNP', '인증/NNG', '인터넷/NNG',
#        '인테리어/NNG', '일/NNB', '일/NNG', '읽/VV', '입/VV-R', '입고/NNG', '입금/NNG',
#        '입력/NNG', '입장/NNG', '입점/NNG', '있/VA', '있/VV', '있/VX', '자체/NNG',
#        '장난감/NNG', '장점/NNG', '재료/NNG', '잼/NNG', '저/NP', '적립/NNG', '적용/NNG',
#        '전/NNG', '전화번호/NNG', '점/NNB', '점/NNG', '접근/NNG', '접하/VV', '정도/NNG',
#        '정보/NNG', '제꺼/NNP', '제외/NNG', '제품/NNG', '조아여/NNG', '조하/NNG',
#        '종류/NNG', '좋/VA', '좋아하/VV', '주/VV', '주/VX', '주문/NNG', '주얼리/NNG',
#        '줄/NNB', '중/NNB', '지/NNB', '지/VX', '지금/NNG', '지방/NNG', '지연/NNG',
#        '지우/VV', '직원/NNG', '진/NNP', '진짜/NNG', '진행/NNG', '집/NNG',
#        '징짜개마나여/NNG', '짜/VA', '쩔/VV', '쪼오오끔/NNG', '쪽/NNB', '참고/NNG',
#        '찾/VV', '찾아보/VV', '처넌/NNG', '처음/NNG', '초짜때/NNG', '최악/NNG',
#        '쵝오/NNG', '추가/NNG', '추천/NNG', '춘/NNG', '취미/NNG', '취소/NNG',
#        '취향/NNG', '치마/NNG', '친구/NNG', '친절/NNG', '칸/NNG', '케이스/NNG',
#        '코너/NNG', '코디/NNG', '쿠팡/NNP', '쿠폰/NNG', '큰일/NNG', '키/NNG',
#        '키워드/NNG', '탈퇴/NNG', '토스/NNG', '통장/NNG', '투쿨포스쿨/NNP', '트라이미/NNP',
#        '특가/NNG', '티/NNG', '파/NNG', '판매/NNG', '팔/VV', '팩/NNG', '페리페라/NNP',
#        '페북/NNP', '편리/NNG', '편의점/NNG', '편하/VA', '포인트/NNG', '폰/NNG',
#        '풀랫폼/NNG', '품목/NNG', '품절/NNG', '필기구/NNG', '필기도구/NNG', '필수/NNG',
#        '필요/NNG', '필통/NNG', '하/VV', '하/VX', '하나/NR', '하루/NNG', '학용품/NNG',
#        '할인/NNG', '합리/NNG', '항상/NNG', '해결/NNG', '핸드폰/NNG', '향수/NNG',
#        '현금/NNG', '홀리/VV', '홈/NNG', '홍보/NNG', '화이팅/NNG', '화장/NNG',
#        '화장실/NNG', '화장품/NNG', '회사/NNG', '후/NNG', '후하/VA', '후회/NNG',
#        '흘리/VV', '흡족/NNG'], dtype=object)

# %%
tf_idf
# Out:
# <58x486 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1267 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### 머신러닝

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

x = dtm
y = beauty_filtered['target']

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# model.fit(X_train.A, y_train, epochs=10)
model.fit(X_train.A, y_train, epochs=10, validation_split=0.1,callbacks = [EarlyStopping(monitor='val_accuracy')])
# Out:
# 2023-12-28 18:14:00.020714: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2/2 [==============================] - 1s 607ms/step - loss: 0.6465 - accuracy: 0.6829 - val_loss: 0.6582 - val_accuracy: 0.8000
# Epoch 2/10
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6256 - accuracy: 0.7073 - val_loss: 0.6398 - val_accuracy: 0.8000

# %% [markdown]
# #### 가중치 및 키워드 확인

# %%
w,b = model.weights
word_sent = pd.DataFrame({'token':words,'weight':w.numpy().flat})
word_sent
# Out:
#         token    weight
# 0    ..리뷰/NNG -0.022836
# 1        가/VV  0.037359
# 2      가격/NNG  0.082657
# 3     가격대/NNG  0.091054
# 4      가능/NNG  0.015737
# ..        ...       ...
# 481     후/NNG  0.099219
# 482     후하/VA -0.018017
# 483    후회/NNG -0.066826
# 484     흘리/VV -0.008854
# 485    흡족/NNG  0.037313
#
# [486 rows x 2 columns]

# %%
word_sent.sort_values('weight',ascending=False).head(10)
# Out:
#        token    weight
# 233   세상/NNG  0.113625
# 55    기대/NNG  0.113500
# 389   주문/NNG  0.112251
# 464   하루/NNG  0.111352
# 121   등등/NNB  0.111266
# 172    바라/VV  0.109050
# 364  장난감/NNG  0.108741
# 314   오늘/NNG  0.108646
# 87     늘리/VV  0.108040
# 103  더럽/VA-I  0.107644

# %%
word_sent.sort_values('weight',ascending=False).tail(10)
# Out:
#           token    weight
# 404  징짜개마나여/NNG -0.104713
# 399      직원/NNG -0.105556
# 335      이내/NNG -0.107466
# 339     이벤트/NNG -0.107503
# 309       예/NNG -0.107698
# 145        말/VX -0.107796
# 291      어플/NNG -0.108277
# 468      항상/NNG -0.108359
# 83        누구/NP -0.110614
# 334    이것저것/NNG -0.113707

# %% [markdown]
# ### 토큰화 2: Okt

# %%
import pandas as pd
from konlpy.tag import Okt

okt = Okt()
beauty_filtered = pd.read_csv('./data/ably_beauty_filtered.csv')

# %%
beauty_filtered['morphs'] = [okt.morphs(content) for content in beauty_filtered['content']]
beauty_filtered
# Out:
#                                               content  score  thumbsUpCount  \
# 0   친구가 추천해서 이용해봤는데 모든제품이 무료배송이고 명품도 있고 여러가지 제품들이 ...      5              0
# 1   설치한지 며칠 안된 사람입니다. 솔직히 쇼핑을 잘 안 하다가 살게 있어서 한번 깔아...      5              0
# 2   대한민국 여자들 필수앱... 올영보다 화장품이 더 싸고 쿠폰도 왕창 많이 뿌려서 너...      5              0
# 3                           좋아요 배송비없이 옷이며 화장품 다 살수있네요      5              0
# 4   진짜 조아여 친구들이 진짜 안들어가면 사람아니라고 진짜 깔아야한다고 해서 처음 깔았...      5              0
# 5   가격도 괜찮고 잘 보고 사면 좋은옷들 많아요 할인도 자주 해주고요 근데 상품정보 설...      3              0
# 6                   옷이 이쁘고 다양한 화장품도 있어 엄청 좋아요!! 추천합니당      5              0
# 7   너무 유명해서 되려 깔 마음이 없었는데 어쩌다 깔고 잘 쓰고 있어요. 단점이라면 옷...      4              0
# 8   무료배송 쉽지않은데 대단하네요^.^. 항상 좋은 물건 좋은 화장품 편리하게 찾을수 ...      5              1
# 9   고2때부터 지금까지 계속 사용하던 유저입니다. 무료배송에다가 이쁜옷들,화장품 등등 ...      3             38
# 10                    주문이 편리해서 좋구요 예쁜옷이나 화장품이 많아서 좋아요      5              0
# 11  쿠폰 많이 주고, 이쁜 옷도 많고, 향수랑 화장품 등도 있어서 넘 좋아요😄 에이블리...      5              0
# 12                   옷도 다양하고 화장품,소품 등도 살수있어서 정말 좋아요 💖      5              0
# 13  제가 좋아하는 옷들,스타일,문구,먹거리,가방,화장품이 많아요 근데 조금 싼티가 나는...      5              0
# 14  무료 배송 이 넘조아요 글구 옷 말고도 문구 화장품 등등 종류가많아서 다른앱 안써도...      4              0
# 15  진짜 예쁘 옷도 많았아서 저 하루에 6개나 구입했잖아요ㅠㅠㅠ 케이스 있고요 옷있고요...      5              0
# 16  아~ 고냥 쵝오입니다 화장품부터 옷 문구류 등등 다~ 여기서 사면 되요 쿠팡보다 좋...      5              0
# 17        옷뿐만 아니라 화장품이나 소품등등도 팔아서 정말 좋아요. 근데 가끔 렉이걸려요      4              0
# 18  무료배송이라서 진짜 좋은데요 무료인만큼 더럽게 안 와요 진짜 3일에 시켰는데 입고지...      3              0
# 19  옷 화장품 악세사리 필기도구 집 인테리어 등 생활하면서 사고싶은 이쁘장한 물건들을 ...      4              0
# 20  너무너무 이쁜 옷, 학용품, 화장품 등등 다양한 게 너무나도 많은 데다 색도 여러가...      5             22
# 21  진짜 에이블리 옷도 팔고 화장품 뭐 가방 이런거 다 팔아서 진짜 개편하고 개좋은데 ...      4              1
# 22                              화장품들이 모여있고 무료배송이라 좋네요      4              0
# 23  예쁜옷들도 많고 화장품이나 장난감?같은것도 있어서좋아요 또한 빠른배송이 있어서 좋은...      5              0
# 24    필통 옷 바지 화장품 립밤 도구 엄청 많아서 좋아요! 배송도 빨라요!! 무료 배송😆😎      5              0
# 25  옷 뿐만이 아니라 거전제품, 취미, 악기, 화장품, 악세서리, 신발, 모자 등등 다...      3             22
# 26                            옷도 예쁘고 화장품도 종류가 많아서 좋아요      5              0
# 27  옷도 많고 화장품이나 물건등등 여러가지 많아서 굉장히 편리해서 좋게 쓰고있습니당 !...      5              0
# 28                       뷰티도 팔고 쿠폰도 적용금액이 낮아 사용하기 좋아요      4              0
# 29  이메일 문제때문에 기존 계정을 탈퇴하고 새 계정을 만들려고 했는데, 재가입 할 때 ...      2              0
# 30  리뷰를 썼었는데 삭제 됐네요ㅠㅠ 이 앱 정말정말 추천드려요 10, 20대 여성분이고...      5             44
# 31  아직배송안받아봐서 모르겠는데 풀랫폼자체는 매우 괜춘함. 옷뿐아니라 뷰티템들도 쉽게 ...      5              0
# 32  앱에서 옷 뿐만이 아니라 인스,스티커,케이스,화장품 등등 팔아서 좋은것 같애요!! ...      5             11
# 33  진짜 너무 조하요ㅜㅜ 마켓도 많고 취향별로 가격대,색,나이,키 등 많은 키워드가 있...      5              5
# 34  정말 가성비쩌는곳은 여기밖에없을듯 15000원짜리를 6처넌에 파는곳이 또 어디있을까...      5              0
# 35                      가성비 좋은 옷,화장품, 홈데코 이쁜거 짱 많음..♡      5              0
# 36  다좋은데..뷰티상품이 좀더 많았으면 좋겠어요.. 저는 진짜진짜 숯비누 사고싶은데 없...      4              1
# 37  부모님 몰래 화장품이나 옷 사시는분들한테 강추하는 앱입니다!쿠폰도 진짜 많고 예쁜 ...      5             24
# 38  화장품이나 여러 옷들도 살수 있어서 너무너무 좋아요! 근데 마켓들이 의외로 제가 생...      4             95
# 39  옷 뿐만 아니라 다이어리, 이불, 필기구, 화장품 , 악세사리 등 여러가지가 있어서...      5             41
# 40  옷이 예뻐요. 그런데 바람이 불면 큰일 ^^;; 좀더 실용성 있게 만들어 주시고 두...      4             16
# 41  아쉬운점은 마켓랭킹에서 브랜드 들어가면 뷰티브랜드가 너무 많아서 본질인 옷브랜드가 ...      3              1
# 42  너무 좋아요. 여기에서 옷사서 예쁘다는 소리 많이 들었습니다 ㅎㅎ 그리고 요즘 화장...      5              1
# 43  무료배송인 점이 맘에들지만 옷살때는 괜찮다 생각했지만 옷이아닌 악세사리나 화장품 등...      4              0
# 44  완전 애용하는 앱이기도 하고 이벤트도 많이하고 쿠폰도 계속 주시고 정말 잘 사용하고...      4             45
# 45  에이블리 이용하면서 편하고 좋은데 진~~~짜 아쉬운건 결제수단에 편의점결제도 넣어주...      5            189
# 46  넘좋아요!!잘 쓰고 있어요!!근데..아쉬운점은..리뷰가많이 없다는점..?그리고 렉이...      5             56
# 47                     예쁜 옷들과 좋은 화장품이 많아서 짱 좋은거 같아요!!      5              0
# 48       좋아하는 화장품이 있어서 찾는더 아무리 찾아도 없었는데 여기있었네요ㅠㅠ 다행이다      5              0
# 49  이렇게 제마음에 쏙든 쇼핑 어플리케이션은 이게 처음입니다 . 제 언니도 마찬가지로 ...      5              9
# 50                   다이어트 제품부터 뷰티제품까지 다양한 제품공구 흡족해요^^      5              0
# 51  아무리 찾아도 없었던 화장품 제품이 여기서 공구를 하고 있다니요!!>< 정말 앞으로...      5              0
# 52  다이어트 식품 뷰티제품 등등 제가 찾던 제품들이 진짜 공구로 다 열리고 있더라구요 ...      5              0
# 53         제가 원래 쓰려고 했던 화장품 여기서 공구로 때리더라구요~ 진짜 개이득이네요      5              0
# 54         기대이상이네요^^ 화장품에 관심이 많은데 다양한 화장품이 많아서 좋아요 ㅎㅎ      5              0
# 55                             진짜 제대로된 화장품만 판매하시네요^0^      5              0
# 56  기획전 그리고 이벤트 많이해서 잘만 하면 좋은가격에 득테 할 수있네요 그리고 요번에...      5              0
# 57  왠만한 쇼핑몰어플중에 제일 최악. 배송도 겁나느리고 받는옷들마다 상태는 최악. 엉덩...      1              1
#
#                      at  year  month  target  \
# 0   2023-11-28 22:16:36  2023     11       1
# 1   2023-11-19 22:06:54  2023     11       1
# 2   2023-08-26 01:20:20  2023      8       1
# 3   2023-08-02 07:44:25  2023      8       1
# 4   2023-07-31 22:35:40  2023      7       1
# 5   2023-07-16 20:47:32  2023      7       1
# 6   2023-05-27 13:13:30  2023      5       1
# 7   2022-11-21 01:34:19  2022     11       1
# 8   2022-11-12 15:55:42  2022     11       1
# 9   2022-10-24 16:37:58  2022     10       1
# 10  2022-10-11 14:35:21  2022     10       1
# 11  2022-10-02 00:36:47  2022     10       1
# 12  2022-09-20 18:49:14  2022      9       1
# 13  2022-08-20 13:58:30  2022      8       1
# 14  2022-08-13 09:32:13  2022      8       1
# 15  2022-08-08 19:41:02  2022      8       1
# 16  2022-07-24 00:49:48  2022      7       1
# 17  2022-07-18 21:44:00  2022      7       1
# 18  2022-07-08 17:19:23  2022      7       1
# 19  2022-06-29 21:32:29  2022      6       1
# 20  2022-06-23 07:01:41  2022      6       1
# 21  2022-06-19 16:30:27  2022      6       1
# 22  2022-04-27 23:51:41  2022      4       1
# 23  2022-04-01 17:45:58  2022      4       1
# 24  2022-03-22 06:34:27  2022      3       1
# 25  2022-03-11 20:53:43  2022      3       1
# 26  2022-02-27 18:09:30  2022      2       1
# 27  2022-02-18 14:13:20  2022      2       1
# 28  2022-02-13 00:19:31  2022      2       1
# 29  2022-02-11 22:52:30  2022      2       0
# 30  2022-01-30 12:26:52  2022      1       1
# 31  2022-01-12 17:37:01  2022      1       1
# 32  2021-12-14 08:00:33  2021     12       1
# 33  2021-11-11 14:10:38  2021     11       1
# 34  2021-10-19 11:09:46  2021     10       1
# 35  2021-09-26 21:42:41  2021      9       1
# 36  2021-09-18 22:21:20  2021      9       1
# 37  2021-08-27 10:35:34  2021      8       1
# 38  2021-08-13 19:38:38  2021      8       1
# 39  2021-07-17 20:11:28  2021      7       1
# 40  2021-07-17 11:36:22  2021      7       1
# 41  2021-05-06 01:01:38  2021      5       1
# 42  2021-04-07 17:40:48  2021      4       1
# 43  2021-01-29 11:10:50  2021      1       1
# 44  2020-10-05 01:29:57  2020     10       1
# 45  2020-09-06 22:03:17  2020      9       1
# 46  2020-07-15 22:09:14  2020      7       1
# 47  2020-01-22 01:18:51  2020      1       1
# 48  2019-04-25 16:58:29  2019      4       1
# 49  2019-04-22 08:41:24  2019      4       1
# 50  2019-04-16 15:55:46  2019      4       1
# 51  2019-04-02 19:21:02  2019      4       1
# 52  2019-04-01 16:56:10  2019      4       1
# 53  2019-03-26 22:42:12  2019      3       1
# 54  2018-12-24 21:50:12  2018     12       1
# 55  2018-12-16 02:07:54  2018     12       1
# 56  2018-10-28 16:38:21  2018     10       1
# 57  2018-08-02 22:37:56  2018      8       0
#
#                                                morphs
# 0   [친구, 가, 추천, 해서, 이용, 해봤는데, 모든, 제품, 이, 무료, 배송, 이...
# 1   [설치, 한지, 며칠, 안된, 사람, 입니다, ., 솔직히, 쇼핑, 을, 잘, 안,...
# 2   [대한민국, 여자, 들, 필수, 앱, ..., 올, 영, 보다, 화장품, 이, 더,...
# 3                [좋아요, 배송비, 없이, 옷, 이며, 화장품, 다, 살수있네요]
# 4   [진짜, 조아여, 친구, 들, 이, 진짜, 안, 들어가면, 사람, 아니라고, 진짜,...
# 5   [가격, 도, 괜찮고, 잘, 보고, 사면, 좋은, 옷, 들, 많아요, 할인, 도, ...
# 6   [옷, 이, 이쁘고, 다양한, 화장품, 도, 있어, 엄청, 좋아요, !!, 추천, ...
# 7   [너무, 유명해서, 되려, 깔, 마음, 이, 없었는데, 어쩌다, 깔고, 잘, 쓰고,...
# 8   [무료, 배송, 쉽지, 않은데, 대단하네요, ^.^., 항상, 좋은, 물건, 좋은,...
# 9   [고, 2, 때, 부터, 지금, 까지, 계속, 사용, 하던, 유저, 입니다, ., ...
# 10    [주문, 이, 편리해서, 좋구요, 예쁜, 옷, 이나, 화장품, 이, 많아서, 좋아요]
# 11  [쿠폰, 많이, 주고, ,, 이쁜, 옷, 도, 많고, ,, 향수, 랑, 화장품, 등...
# 12  [옷, 도, 다양하고, 화장품, ,, 소품, 등, 도, 살수있어서, 정말, 좋아요, 💖]
# 13  [제, 가, 좋아하는, 옷, 들, ,, 스타일, ,, 문구, ,, 먹거리, ,, 가...
# 14  [무료, 배송, 이, 넘, 조아요, 글구, 옷, 말고도, 문구, 화장품, 등등, 종...
# 15  [진짜, 예쁘, 옷, 도, 많았아서, 저, 하루, 에, 6, 개, 나, 구입, 했잖...
# 16  [아, ~, 고, 냥, 쵝, 오입, 니, 다, 화장품, 부터, 옷, 문, 구류, 등...
# 17  [옷, 뿐, 만, 아니라, 화장품, 이나, 소품, 등등, 도, 팔아서, 정말, 좋아...
# 18  [무료, 배송, 이라서, 진짜, 좋은데, 요, 무료, 인, 만큼, 더럽게, 안, 와...
# 19  [옷, 화장품, 악세사리, 필기, 도구, 집, 인테리어, 등, 생활, 하면서, 사고...
# 20  [너무, 너무, 이쁜, 옷, ,, 학용품, ,, 화장품, 등등, 다양한, 게, 너무...
# 21  [진짜, 에이, 블리, 옷, 도, 팔고, 화장품, 뭐, 가방, 이런거, 다, 팔아서...
# 22                 [화장품, 들, 이, 모여있고, 무료, 배송, 이라, 좋네요]
# 23  [예쁜, 옷, 들, 도, 많고, 화장품, 이나, 장난감, ?, 같은것도, 있어서, ...
# 24  [필통, 옷, 바지, 화장품, 립밤, 도구, 엄청, 많아서, 좋아요, !, 배송, ...
# 25  [옷, 뿐, 만이, 아니라, 거, 전, 제품, ,, 취미, ,, 악기, ,, 화장품...
# 26               [옷, 도, 예쁘고, 화장품, 도, 종류, 가, 많아서, 좋아요]
# 27  [옷, 도, 많고, 화장품, 이나, 물건, 등등, 여러가지, 많아서, 굉장히, 편리...
# 28     [뷰티, 도, 팔고, 쿠폰, 도, 적용, 금액, 이, 낮아, 사용, 하기, 좋아요]
# 29  [이메일, 문, 제, 때문, 에, 기존, 계정, 을, 탈퇴, 하고, 새, 계정, 을...
# 30  [리뷰, 를, 썼었는데, 삭제, 됐네요, ㅠㅠ, 이, 앱, 정말, 정말, 추천, 드...
# 31  [아직, 배송, 안, 받아, 봐서, 모르겠는데, 풀랫폼자체, 는, 매우, 괜춘함, ...
# 32  [앱, 에서, 옷, 뿐, 만이, 아니라, 인스, ,, 스티커, ,, 케이스, ,, ...
# 33  [진짜, 너무, 조하요, ㅜㅜ, 마켓, 도, 많고, 취향, 별로, 가격, 대, ,,...
# 34  [정말, 가성, 비쩌, 는, 곳, 은, 여기, 밖에, 없을듯, 15000원, 짜리를...
# 35  [가성, 비, 좋은, 옷, ,, 화장품, ,, 홈, 데코, 이쁜거, 짱, 많음, ....
# 36  [다, 좋은데, .., 뷰티, 상품, 이, 좀더, 많았으면, 좋겠어요, .., 저,...
# 37  [부모님, 몰래, 화장품, 이나, 옷, 사시, 는, 분, 들, 한테, 강, 추하는,...
# 38  [화장품, 이나, 여러, 옷, 들, 도, 살수, 있어서, 너무, 너무, 좋아요, !...
# 39  [옷, 뿐, 만, 아니라, 다이어리, ,, 이불, ,, 필기구, ,, 화장품, ,,...
# 40  [옷, 이, 예뻐요, ., 그런데, 바람, 이, 불면, 큰일, ^^;;, 좀더, 실...
# 41  [아쉬운, 점, 은, 마켓, 랭킹, 에서, 브랜드, 들어가면, 뷰티, 브랜드, 가,...
# 42  [너무, 좋아요, ., 여기, 에서, 옷, 사서, 예쁘다는, 소리, 많이, 들었습니...
# 43  [무료, 배송, 인, 점, 이, 맘, 에, 들지만, 옷살때, 는, 괜찮다, 생각, ...
# 44  [완전, 애용, 하는, 앱, 이기도, 하고, 이벤트, 도, 많이하고, 쿠폰, 도, ...
# 45  [에이, 블리, 이용, 하면서, 편하고, 좋은데, 진, ~~~, 짜, 아쉬운건, 결...
# 46  [넘, 좋아요, !!, 잘, 쓰고, 있어요, !!, 근데, .., 아쉬운, 점, 은...
# 47  [예쁜, 옷, 들, 과, 좋은, 화장품, 이, 많아서, 짱, 좋은, 거, 같아요, !!]
# 48  [좋아하는, 화장품, 이, 있어서, 찾는, 더, 아무리, 찾아도, 없었는데, 여기있...
# 49  [이렇게, 제, 마음, 에, 쏙, 든, 쇼핑, 어플리케이션, 은, 이, 게, 처음,...
# 50  [다이어트, 제품, 부터, 뷰티, 제품, 까지, 다양한, 제품, 공구, 흡족해요, ^^]
# 51  [아무리, 찾아도, 없었던, 화장품, 제품, 이, 여기, 서, 공구, 를, 하고, ...
# 52  [다이어트, 식품, 뷰티, 제품, 등등, 제, 가, 찾던, 제품, 들, 이, 진짜,...
# 53  [제, 가, 원래, 쓰려고, 했던, 화장품, 여기, 서, 공구, 로, 때리더라구요,...
# 54  [기, 대, 이상, 이네, 요, ^^, 화장품, 에, 관심, 이, 많은데, 다양한,...
# 55            [진짜, 제대로, 된, 화장품, 만, 판매, 하시네요, ^, 0, ^]
# 56  [기획전, 그리고, 이벤트, 많이, 해, 서, 잘만, 하면, 좋은, 가격, 에, 득...
# 57  [왠만한, 쇼핑몰, 어플, 중, 에, 제일, 최악, ., 배송, 도, 겁나느, 리,...

# %% [markdown]
# #### 불용어 제거

# %%
# 불용어 목록
text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
stop_words = text.split(" ")
stop_words
# Out:
# ['~',
#  '~~',
#  '~~~',
#  '~~~~',
#  '~~~~~',
#  '^',
#  '^^',
#  '!',
#  '!!',
#  'ㅜㅜ',
#  '.',
#  '..',
#  ',',
#  ',,',
#  '가',
#  '도',
#  '고',
#  '이나',
#  '요',
#  '아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를',
#  '들면',
#  '예를',
#  '들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수',
#  '없다',
#  '해서는',
#  '안된다',
#  '뿐만',
#  '아니라',
#  '만이',
#  '아니다',
#  '만은',
#  '아니다',
#  '막론하고',
#  '관계없이',
#  '그치지',
#  '않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지',
#  '않다',
#  '따지지',
#  '않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만',
#  '못하다',
#  '하는',
#  '편이',
#  '낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이',
#  '외에',
#  '이',
#  '밖에',
#  '하여야',
#  '비로소',
#  '한다면',
#  '몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할',
#  '생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게',
#  '함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에',
#  '틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해',
#  '말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로',
#  '말하자면',
#  '이와',
#  '반대로',
#  '바꾸어서',
#  '말하면',
#  '바꾸어서',
#  '한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에',
#  '가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한',
#  '까닭에',
#  '하기',
#  '때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에',
#  '따르는',
#  '때가',
#  '되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼',
#  '어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서',
#  '보아',
#  '비추어',
#  '보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지',
#  '않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에',
#  '안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시',
#  '말하자면',
#  '바꿔',
#  '말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른',
#  '방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도',
#  '없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만',
#  '못하다',
#  '하는것이',
#  '낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느',
#  '년도',
#  '라',
#  '해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할',
#  '줄',
#  '안다',
#  '할',
#  '힘이',
#  '있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로',
#  '쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서',
#  '서술한바와같이',
#  '인',
#  '듯하다',
#  '하지',
#  '않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도',
#  '불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지',
#  '않도록',
#  '않기',
#  '위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가',
#  '알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은',
#  '몰랏다',
#  '하는',
#  '김에',
#  '겸사겸사',
#  '하는바',
#  '그런',
#  '까닭에',
#  '한',
#  '이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기',
#  '위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만',
#  '못하다',
#  '하기보다는',
#  '차라리',
#  '하는',
#  '편이',
#  '낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로',
#  '말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지',
#  '않으면',
#  '그렇지',
#  '않다면',
#  '안',
#  '그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수',
#  '없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지',
#  '않도록',
#  '않기',
#  '위해서',
#  '이르기까지',
#  '이',
#  '되다',
#  '로',
#  '인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로',
#  '인하여',
#  '그래서',
#  '이',
#  '때문에',
#  '그러므로',
#  '그런',
#  '까닭에',
#  '알',
#  '수',
#  '있다',
#  '결론을',
#  '낼',
#  '수',
#  '있다',
#  '으로',
#  '인하여',
#  '있다',
#  '어떤것',
#  '관계가',
#  '있다',
#  '관련이',
#  '있다',
#  '연관되다',
#  '어떤것들',
#  '에',
#  '대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면',
#  '할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에',
#  '있다',
#  '에',
#  '달려',
#  '있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와',
#  '같은',
#  '요만큼',
#  '요만한',
#  '것',
#  '얼마',
#  '안',
#  '되는',
#  '것',
#  '이만큼',
#  '이',
#  '정도의',
#  '이렇게',
#  '많은',
#  '것',
#  '이와',
#  '같다',
#  '이때',
#  '이렇구나',
#  '것과',
#  '같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와',
#  '같은',
#  '사람들',
#  '부류의',
#  '사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에',
#  '한하다',
#  '하기만',
#  '하면',
#  '도착하다',
#  '까지',
#  '미치다',
#  '도달하다',
#  '정도에',
#  '이르다',
#  '할',
#  '지경이다',
#  '결과에',
#  '이르다',
#  '관해서는',
#  '여러분',
#  '하고',
#  '있다',
#  '한',
#  '후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에',
#  '종합한것과같이',
#  '총적으로',
#  '보면',
#  '총적으로',
#  '말하면',
#  '총적으로',
#  '대로',
#  '하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할',
#  '따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영',
#  '이',
#  '있',
#  '하',
#  '것',
#  '들',
#  '그',
#  '되',
#  '수',
#  '이',
#  '보',
#  '않',
#  '없',
#  '나',
#  '사람',
#  '주',
#  '아니',
#  '등',
#  '같',
#  '우리',
#  '때',
#  '년',
#  '가',
#  '한',
#  '지',
#  '대하',
#  '오',
#  '말',
#  '일',
#  '그렇',
#  '위하',
#  '때문',
#  '그것',
#  '두',
#  '말하',
#  '알',
#  '그러나',
#  '받',
#  '못하',
#  '일',
#  '그런',
#  '또',
#  '문제',
#  '더',
#  '사회',
#  '많',
#  '그리고',
#  '좋',
#  '크',
#  '따르',
#  '중',
#  '나오',
#  '가지',
#  '씨',
#  '시키',
#  '만들',
#  '지금',
#  '생각하',
#  '그러',
#  '속',
#  '하나',
#  '집',
#  '살',
#  '모르',
#  '적',
#  '월',
#  '데',
#  '자신',
#  '안',
#  '어떤',
#  '내',
#  '내',
#  '경우',
#  '명',
#  '생각',
#  '시간',
#  '그녀',
#  '다시',
#  '이런',
#  '앞',
#  '보이',
#  '번',
#  '나',
#  '다른',
#  '어떻',
#  '여자',
#  '개',
#  '전',
#  '들',
#  '사실',
#  '이렇',
#  '점',
#  '싶',
#  '말',
#  '정도',
#  '좀',
#  '원',
#  '잘',
#  '통하',
#  '놓',
#  '입니다']

# %%
filtered = []
for idx,morphs in enumerate(beauty_filtered['morphs']):
    morphs_new = []
    for word in morphs:
        print(word)
        if word not in stop_words:
            morphs_new.append(word)
            beauty_filtered['morphs'][idx] = morphs_new
        else:
            pass
# Out:
# 친구
# 가
# 추천
# 해서
# 이용
# 해봤는데
# 모든
# 제품
# 이
# 무료
# 배송
# 이고
# 명품
# 도
# 있고
# 여러가지
# 제품
# 들
# 이
# 많아서
# 필요한
# 옷
# 이나
# 화장품
# 등등
# 을
# 살수있어서
# 좋네요
# 😻
# 에이
# 블리
# 추천
# 합니다
# 설치
# 한지
# 며칠
# 안된
# 사람
# 입니다
# .
# 솔직히
# 쇼핑
# 을
# 잘
# 안
# 하다가
# 살
# 게
# 있어서
# 한번
# 깔아
# 본건데
# 아직
# 까진
# 괜찮습니다
# .
# 화장품
# 이건
# 옷
# 이건
# 더
# 다양하게
# 접
# 해서
# 그
# 런가
# 저
# 같은
# 사람
# 입장
# 에서는
# 신세계
# 네
# 요
# .
# 대한민국
# 여자
# 들
# 필수
# 앱
# ...
# 올
# 영
# 보다
# 화장품
# 이
# 더
# 싸고
# 쿠폰
# 도
# 왕창
# 많이
# 뿌려서
# 너무
# 좋아요
# ㅠㅠ
# 에이
# 블리
# 보세라서
# 싫다는
# 사람
# 들
# 도
# 많은데
# 에이블리
# 에
# 브랜드
# 도
# 있는거
# 알아줬으면
# 좋겠어요
# ..
# 리뷰
# 도
# 제
# 또래
# 들
# 이
# 쓴거라서
# 공감
# 되고
# 정말
# 정말
# 활발히
# 달리는
# 앱
# 이라
# 좋아요
# !!
# 좋아요
# 배송비
# 없이
# 옷
# 이며
# 화장품
# 다
# 살수있네요
# 진짜
# 조아여
# 친구
# 들
# 이
# 진짜
# 안
# 들어가면
# 사람
# 아니라고
# 진짜
# 깔아야한
# 다
# 고
# 해서
# 처음
# 깔았었는데
# 로그인
# 간편해서
# 좋았어용
# 그리거
# 처음
# 들어가면
# 2000원
# 주고
# 그거
# 로
# 주문
# 하면
# 또
# 2000
# 원주고
# 할인
# 쿠폰
# 도
# 엄청
# 많고
# 여러
# 미션
# 도
# 많이
# 있어서
# 인터넷
# 쇼핑
# 처음
# 하는
# 저
# 로서
# 는
# 만족합니다
# .
# 옷
# 들
# 도
# 이쁜거
# 많고
# 화장품
# 악세서리
# 간식
# 등등
# 여러
# 종류
# 에
# 물건
# 이
# 많아
# 구경
# 하다
# 보면
# 시간
# 후딱
# 가
# 기도
# 하고
# ㅎ
# 옷
# 이랑
# 악
# 서리
# 간식
# 이
# 거
# 다
# 싸고
# 싼거에다가
# 할인
# 쿠폰
# 이랑
# 이
# 것
# 저
# 것
# 넣다
# 보면
# 2000
# 원
# 으로
# 사야하던게
# 0
# 원
# 이
# 되있습니다
# 진짜
# 처음
# 에
# 이
# 거
# 보고
# 눈물
# 흘릴
# 뻔
# 또
# 씨앗
# 심어서
# 포인트
# (?)
# 암튼
# 그거
# 주는것도
# 있고
# 돼지
# (?)
# 같은거
# 밥
# 주는것도
# 있고
# 여러가지
# 겜
# 같은것도
# 있어서
# 아주
# 기부
# 니
# 좋습니다
# .
# 저
# 는
# 참고
# 로
# 초
# 짜
# 때
# 무료
# 로
# 반지
# 2
# 개
# 샀어여
# (
# ㅎ
# )
# 토스
# 도
# 가능해서
# 편리하고
# 인터넷
# 쇼핑
# 앱
# 치고
# 아주
# 잼있게
# 사용
# 하고있습니다
# 열
# 분
# 고민
# 하기전에
# 까시고
# 고민
# 하십
# 쇼
# \(^^)/
# 아
# 참
# 열
# 분
# 포인트
# 그거
# 모으는거는
# 광고
# 쪼오오끔
# 있어여
# <(^^)/
# 가격
# 도
# 괜찮고
# 잘
# 보고
# 사면
# 좋은
# 옷
# 들
# 많아요
# 할인
# 도
# 자주
# 해주고요
# 근데
# 상품
# 정보
# 설명
# 이
# 안
# 뜨는
# 오류
# 가
# 자주
# 발생
# 해요
# 저만
# 그런
# 걸
# 까요
# 화장품
# 보려고
# 들어왔는데
# 위
# 에
# 설명
# 조금
# 있다가
# 뚝
# 끊기고
# 좀
# 이상하네요
# 그리고
# 웨이
# 크
# 메이크
# 제발
# 입점
# ..
# 안될까
# 요
# 😢
# 옷
# 이
# 이쁘고
# 다양한
# 화장품
# 도
# 있어
# 엄청
# 좋아요
# !!
# 추천
# 합니당
# 너무
# 유명해서
# 되려
# 깔
# 마음
# 이
# 없었는데
# 어쩌다
# 깔고
# 잘
# 쓰고
# 있어요
# .
# 단점
# 이
# 라면
# 옷
# 들
# 은
# 가격
# 에
# 비해
# 괜찮은
# 상품
# 이
# 많은데
# 화장품
# 같은것
# 들은
# 다른
# 앱
# 이나
# 구
# 매
# 처
# 들
# 에
# 비해
# 비싸요
# 무료
# 배송
# 쉽지
# 않은데
# 대단하네요
# ^.^.
# 항상
# 좋은
# 물건
# 좋은
# 화장품
# 편리하게
# 찾을수
# 있어서
# 좋아요
# !
# 배송
# 도
# 빠르고
# 문의
# 하면
# 세상
# 친절하게
# 답변
# 해줘여
# !
# 앱슬때
# 별문제
# 되지
# 는
# 않네여
# ..
# 고
# 2
# 때
# 부터
# 지금
# 까지
# 계속
# 사용
# 하던
# 유저
# 입니다
# .
# 무료
# 배송
# 에다가
# 이쁜
# 옷
# 들
# ,
# 화장품
# 등등
# 맘
# 에
# 드는게
# 많아서
# 진짜
# 잘쓰고있었습니다
# .
# 그런데
# 속옷
# 을
# 시켰는데
# 품절
# 되서
# 주문
# 이
# 취소
# 됬어요
# .
# 9월
# 29일
# 쯤에
# 취소
# 된데
# 아직도
# 취소
# 진행중
# 이네
# 요
# ?
# 다른건
# 취소
# 됬을
# 때
# 바로바로
# 입금
# 되고
# 좋았는데
# 아
# 소마
# 라는
# 상품
# 판매
# 쪽
# 은
# 아직
# 까지도
# 취소
# 진행중
# 이내
# 요
# ;;
# 거기
# 만
# 그러는
# 건지
# ,,,
# 취소
# 진행
# 해놓고
# 입금
# 도
# 안되고
# ,
# 계속
# 취소
# 진행중
# ..
# ㅋㅋ
# ;;;
# 어이
# 가
# 없네요
# .
# 예전
# 에
# 쓰던
# 에이
# 블리
# 계정
# 을
# 읽어
# 버려서
# VIP
# 가
# 아닌데
# 예전
# 에
# 쓰던
# 계정은
# VVIP
# 가
# 됬을만큼
# 많이
# 구매
# 하고
# 사용
# 하면서
# 좋은
# 리뷰
# 도
# 많이
# 남겼습니다
# .
# 믿으면서
# 쓰던
# 쇼핑
# 어플
# 에서
# 상품
# 여러
# 게
# 취소
# 한
# 것
# 도
# 아니고
# 상품
# 하나
# 가
# 취소
# 진행
# 된
# 걸
# 제대로
# 안
# 하다니요
# ,,,
# 좀
# 많이
# 실망
# 스럽네요
# .
# 품절
# 되서
# 취소
# 된게
# 아직
# 까지
# 취소
# 진행중
# 이라
# ...
# ㅋㅋ
# ,,,
# 생각
# 할수록
# 어이없네
# ㅋㅋ
# ;;;
# 주문
# 이
# 편리해서
# 좋구요
# 예쁜
# 옷
# 이나
# 화장품
# 이
# 많아서
# 좋아요
# 쿠폰
# 많이
# 주고
# ,
# 이쁜
# 옷
# 도
# 많고
# ,
# 향수
# 랑
# 화장품
# 등
# 도
# 있어서
# 넘
# 좋아요
# 😄
# 에이블리
# 에서
# 아직
# 많이
# 구매
# 해
# 보진
# 않았지만
# ..
# 좋은
# 앱
# 이에요
# ❤
# 옷
# 도
# 다양하고
# 화장품
# ,
# 소품
# 등
# 도
# 살수있어서
# 정말
# 좋아요
# 💖
# 제
# 가
# 좋아하는
# 옷
# 들
# ,
# 스타일
# ,
# 문구
# ,
# 먹거리
# ,
# 가방
# ,
# 화장품
# 이
# 많아요
# 근데
# 조금
# 싼
# 티
# 가
# 나
# 는
# 옷
# ,
# 실밥
# 이
# 나온
# 옷
# 들
# 이
# 있지만
# 추천
# 드립니다
# 5
# 점
# 드릴게요
# 무료
# 배송
# 이
# 넘
# 조아요
# 글구
# 옷
# 말고도
# 문구
# 화장품
# 등등
# 종류
# 가
# 많아서
# 다른
# 앱
# 안
# 써도
# 되서
# 편리합니다
# 이벤트
# 도
# 많고
# 근데
# 배송
# 이
# 살짝
# 느리고
# 오류
# 가
# 있네요
# ㅠ
# 어제
# 도착
# 인데
# 오늘
# 도착
# 하고
# ㅠ
# 진짜
# 예쁘
# 옷
# 도
# 많았아서
# 저
# 하루
# 에
# 6
# 개
# 나
# 구입
# 했잖아요
# ㅠㅠㅠ
# 케이스
# 있고요
# 옷
# 있고요
# 화장품
# 있구요
# 주얼리
# 있고요
# 징
# 짜개
# 마나
# 여
# 편의점
# 에서도
# 구입
# 할수
# 있구
# ㅠㅠㅠ
# 징
# 짜
# 사랑
# 해
# 에블리
# ㅠㅠㅠ
# 💕💕💕
# 아
# ~
# 고
# 냥
# 쵝
# 오입
# 니
# 다
# 화장품
# 부터
# 옷
# 문
# 구류
# 등등
# 다
# ~
# 여기
# 서
# 사면
# 되요
# 쿠팡
# 보다
# 좋음
# ㄹㅇ
# 먹을것도
# 여기
# 서
# 팔면
# ㄹㅇ
# 쿠팡
# 압도
# 함
# 옷
# 뿐
# 만
# 아니라
# 화장품
# 이나
# 소품
# 등등
# 도
# 팔아서
# 정말
# 좋아요
# .
# 근데
# 가끔
# 렉
# 이
# 걸려요
# 무료
# 배송
# 이라서
# 진짜
# 좋은데
# 요
# 무료
# 인
# 만큼
# 더럽게
# 안
# 와요
# 진짜
# 3일
# 에
# 시켰는데
# 입
# 고지연
# 문자
# 3
# 번
# 이나
# 왔어요
# 이
# 젠
# 놀랍지도
# 않고
# 20일
# 이후
# 입고
# 예
# 상이
# 라네
# 요
# ?^^
# 23일
# 에
# 약속
# 있는데
# 20일
# 전
# 에
# 시킨
# 걸
# 3일
# 전
# 에
# 받아
# 볼
# 수
# 있다니
# 정말
# ^
# v
# ^..
# 더
# 변동
# 돼서
# 약
# 속
# 날짜
# 에
# 옷
# 안
# 오면
# 저
# 진짜
# 에이
# 블리
# 회사
# 화장실
# 에다
# 똥
# 싸고
# 물
# 안
# 내릴
# 거
# 예요
# 빨
# 리좀
# 보내주세요
# ㅠㅠㅍㅍ
# 옷
# 화장품
# 악세사리
# 필기
# 도구
# 집
# 인테리어
# 등
# 생활
# 하면서
# 사고싶은
# 이쁘
# 장한
# 물건
# 들
# 을
# 살
# 수
# 있고
# 1
# 개
# 1
# 개
# 살때
# 마다
# 포인트
# 가
# 적립
# 되고
# 쿠폰
# 도
# 거의
# 맨날
# 준다고
# 볼
# 수
# 있습니다
# .
# 이벤트
# 도
# 있고
# 편의점
# 에서
# 현금
# 으로
# 계산
# 할
# 수도
# 있습니다
# .
# 너무
# 너무
# 이쁜
# 옷
# ,
# 학용품
# ,
# 화장품
# 등등
# 다양한
# 게
# 너무나도
# 많은
# 데
# 다
# 색도
# 여러가지
# 여서
# 너무
# 마음
# 에
# 들어요
# .
# ᐟ
# 무엇
# 보다도
# 배송
# 시간
# 이
# 3~4일
# 정도
# 는
# 걸릴
# 줄
# 알
# 고
# 걱정
# 했는데
# 다행히도
# 2일
# 걸려서
# 너무
# 기뻤어요
# ..
# ㅠㅜ
# 리뷰
# 쓰는
# 걸
# 깜빡
# 해서
# 늦게라도
# 써
# 봐요
# .
# ᐟ
# 여러분
# 들
# 이
# 거
# 꼭꼭
# 설치
# 하세요
# !
# 진짜
# 로
# 강추
# 드려요
# ..!
# 진짜
# 저만
# 알
# 고
# 싶은
# 앱
# 중
# 하나
# 입니다
# ..
# 폰
# 케이스
# 도
# 있구
# 킥
# 배송
# 도
# 있어요
# 당장
# 설치
# 해야
# 겠죠
# ?
# 쿠폰
# 팩
# 도
# 무지막지
# 하게
# 준다니깐
# 요
# ?
# 꼭꼭
# 설치
# 부탁
# 드려
# 염
# 진짜
# 에이
# 블리
# 옷
# 도
# 팔고
# 화장품
# 뭐
# 가방
# 이런거
# 다
# 팔아서
# 진짜
# 개편
# 하고
# 개
# 좋은데
# 진짜
# 딱
# 하나
# 아쉬운게
# 있다면
# 무
# 통장
# 입금
# 을
# 제
# 가
# 할라
# 해
# 두
# 제
# 꺼
# 가
# 새마을금고
# 여서
# 입금
# 이
# 안되고
# 편의점
# 결제
# 만해
# 야
# 한다는
# 게
# 넘
# 아쉬워요
# ㅠㅠ
# 이런
# 점
# 만
# 고려
# 해주시면
# 진짜
# 저
# vip
# 에서
# vvip
# 되도록
# 할게요
# 맨날
# 편의점
# 드나드는거나
# 직원
# 분들
# 이
# 모르시는
# 경우
# 가
# 많으셔서
# 새마을금고
# 도
# 입금
# 가능하게
# 해주세용
# ㅇ
# ㅠㅠ
# 화장품
# 들
# 이
# 모여있고
# 무료
# 배송
# 이라
# 좋네요
# 예쁜
# 옷
# 들
# 도
# 많고
# 화장품
# 이나
# 장난감
# ?
# 같은것도
# 있어서
# 좋아요
# 또한
# 빠른
# 배송
# 이
# 있어서
# 좋은
# 거
# 같네요
# !
# 필통
# 옷
# 바지
# 화장품
# 립밤
# 도구
# 엄청
# 많아서
# 좋아요
# !
# 배송
# 도
# 빨라요
# !!
# 무료
# 배송
# 😆😎
# 옷
# 뿐
# 만이
# 아니라
# 거
# 전
# 제품
# ,
# 취미
# ,
# 악기
# ,
# 화장품
# ,
# 악세서리
# ,
# 신발
# ,
# 모자
# 등등
# 다양한
# 물건
# 들
# 을
# 파는
# 앱
# 이
# 여서
# 좋은
# 것
# 같아요
# 다만
# 단점
# 이
# 있다면
# 조금
# 비싸다는
# 점
# ?
# 다른
# 앱
# 사이트
# 에서
# 찾아보면
# 더
# 싼
# 물건
# 이
# 굉장히
# 많아요
# 이
# 앱
# 사용
# 하실
# 때
# 다른
# 사이트
# 에서도
# 잘
# 알아보시고
# 사용
# 하시는게
# 좋을것
# 같아요
# 옷
# 도
# 예쁘고
# 화장품
# 도
# 종류
# 가
# 많아서
# 좋아요
# 옷
# 도
# 많고
# 화장품
# 이나
# 물건
# 등등
# 여러가지
# 많아서
# 굉장히
# 편리해서
# 좋게
# 쓰고있
# 습
# 니당
# !!
# 거기
# 다가
# 쿠폰
# 도
# 한번
# 씩
# 후
# 하게
# 줘서
# 저렴하게
# 잘
# 쓸
# 때
# 도
# 있고요
# 👍😊
# 뷰티
# 도
# 팔고
# 쿠폰
# 도
# 적용
# 금액
# 이
# 낮아
# 사용
# 하기
# 좋아요
# 이메일
# 문
# 제
# 때문
# 에
# 기존
# 계정
# 을
# 탈퇴
# 하고
# 새
# 계정
# 을
# 만들려고
# 했는데
# ,
# 재
# 가입
# 할
# 때
# 전화번호
# 입력
# 하고
# 인증
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/4092838277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beauty_filtered['morphs'][idx] = morphs_new

# %%
beauty_filtered
# Out:
#                                               content  score  thumbsUpCount  \
# 0   친구가 추천해서 이용해봤는데 모든제품이 무료배송이고 명품도 있고 여러가지 제품들이 ...      5              0
# 1   설치한지 며칠 안된 사람입니다. 솔직히 쇼핑을 잘 안 하다가 살게 있어서 한번 깔아...      5              0
# 2   대한민국 여자들 필수앱... 올영보다 화장품이 더 싸고 쿠폰도 왕창 많이 뿌려서 너...      5              0
# 3                           좋아요 배송비없이 옷이며 화장품 다 살수있네요      5              0
# 4   진짜 조아여 친구들이 진짜 안들어가면 사람아니라고 진짜 깔아야한다고 해서 처음 깔았...      5              0
# 5   가격도 괜찮고 잘 보고 사면 좋은옷들 많아요 할인도 자주 해주고요 근데 상품정보 설...      3              0
# 6                   옷이 이쁘고 다양한 화장품도 있어 엄청 좋아요!! 추천합니당      5              0
# 7   너무 유명해서 되려 깔 마음이 없었는데 어쩌다 깔고 잘 쓰고 있어요. 단점이라면 옷...      4              0
# 8   무료배송 쉽지않은데 대단하네요^.^. 항상 좋은 물건 좋은 화장품 편리하게 찾을수 ...      5              1
# 9   고2때부터 지금까지 계속 사용하던 유저입니다. 무료배송에다가 이쁜옷들,화장품 등등 ...      3             38
# 10                    주문이 편리해서 좋구요 예쁜옷이나 화장품이 많아서 좋아요      5              0
# 11  쿠폰 많이 주고, 이쁜 옷도 많고, 향수랑 화장품 등도 있어서 넘 좋아요😄 에이블리...      5              0
# 12                   옷도 다양하고 화장품,소품 등도 살수있어서 정말 좋아요 💖      5              0
# 13  제가 좋아하는 옷들,스타일,문구,먹거리,가방,화장품이 많아요 근데 조금 싼티가 나는...      5              0
# 14  무료 배송 이 넘조아요 글구 옷 말고도 문구 화장품 등등 종류가많아서 다른앱 안써도...      4              0
# 15  진짜 예쁘 옷도 많았아서 저 하루에 6개나 구입했잖아요ㅠㅠㅠ 케이스 있고요 옷있고요...      5              0
# 16  아~ 고냥 쵝오입니다 화장품부터 옷 문구류 등등 다~ 여기서 사면 되요 쿠팡보다 좋...      5              0
# 17        옷뿐만 아니라 화장품이나 소품등등도 팔아서 정말 좋아요. 근데 가끔 렉이걸려요      4              0
# 18  무료배송이라서 진짜 좋은데요 무료인만큼 더럽게 안 와요 진짜 3일에 시켰는데 입고지...      3              0
# 19  옷 화장품 악세사리 필기도구 집 인테리어 등 생활하면서 사고싶은 이쁘장한 물건들을 ...      4              0
# 20  너무너무 이쁜 옷, 학용품, 화장품 등등 다양한 게 너무나도 많은 데다 색도 여러가...      5             22
# 21  진짜 에이블리 옷도 팔고 화장품 뭐 가방 이런거 다 팔아서 진짜 개편하고 개좋은데 ...      4              1
# 22                              화장품들이 모여있고 무료배송이라 좋네요      4              0
# 23  예쁜옷들도 많고 화장품이나 장난감?같은것도 있어서좋아요 또한 빠른배송이 있어서 좋은...      5              0
# 24    필통 옷 바지 화장품 립밤 도구 엄청 많아서 좋아요! 배송도 빨라요!! 무료 배송😆😎      5              0
# 25  옷 뿐만이 아니라 거전제품, 취미, 악기, 화장품, 악세서리, 신발, 모자 등등 다...      3             22
# 26                            옷도 예쁘고 화장품도 종류가 많아서 좋아요      5              0
# 27  옷도 많고 화장품이나 물건등등 여러가지 많아서 굉장히 편리해서 좋게 쓰고있습니당 !...      5              0
# 28                       뷰티도 팔고 쿠폰도 적용금액이 낮아 사용하기 좋아요      4              0
# 29  이메일 문제때문에 기존 계정을 탈퇴하고 새 계정을 만들려고 했는데, 재가입 할 때 ...      2              0
# 30  리뷰를 썼었는데 삭제 됐네요ㅠㅠ 이 앱 정말정말 추천드려요 10, 20대 여성분이고...      5             44
# 31  아직배송안받아봐서 모르겠는데 풀랫폼자체는 매우 괜춘함. 옷뿐아니라 뷰티템들도 쉽게 ...      5              0
# 32  앱에서 옷 뿐만이 아니라 인스,스티커,케이스,화장품 등등 팔아서 좋은것 같애요!! ...      5             11
# 33  진짜 너무 조하요ㅜㅜ 마켓도 많고 취향별로 가격대,색,나이,키 등 많은 키워드가 있...      5              5
# 34  정말 가성비쩌는곳은 여기밖에없을듯 15000원짜리를 6처넌에 파는곳이 또 어디있을까...      5              0
# 35                      가성비 좋은 옷,화장품, 홈데코 이쁜거 짱 많음..♡      5              0
# 36  다좋은데..뷰티상품이 좀더 많았으면 좋겠어요.. 저는 진짜진짜 숯비누 사고싶은데 없...      4              1
# 37  부모님 몰래 화장품이나 옷 사시는분들한테 강추하는 앱입니다!쿠폰도 진짜 많고 예쁜 ...      5             24
# 38  화장품이나 여러 옷들도 살수 있어서 너무너무 좋아요! 근데 마켓들이 의외로 제가 생...      4             95
# 39  옷 뿐만 아니라 다이어리, 이불, 필기구, 화장품 , 악세사리 등 여러가지가 있어서...      5             41
# 40  옷이 예뻐요. 그런데 바람이 불면 큰일 ^^;; 좀더 실용성 있게 만들어 주시고 두...      4             16
# 41  아쉬운점은 마켓랭킹에서 브랜드 들어가면 뷰티브랜드가 너무 많아서 본질인 옷브랜드가 ...      3              1
# 42  너무 좋아요. 여기에서 옷사서 예쁘다는 소리 많이 들었습니다 ㅎㅎ 그리고 요즘 화장...      5              1
# 43  무료배송인 점이 맘에들지만 옷살때는 괜찮다 생각했지만 옷이아닌 악세사리나 화장품 등...      4              0
# 44  완전 애용하는 앱이기도 하고 이벤트도 많이하고 쿠폰도 계속 주시고 정말 잘 사용하고...      4             45
# 45  에이블리 이용하면서 편하고 좋은데 진~~~짜 아쉬운건 결제수단에 편의점결제도 넣어주...      5            189
# 46  넘좋아요!!잘 쓰고 있어요!!근데..아쉬운점은..리뷰가많이 없다는점..?그리고 렉이...      5             56
# 47                     예쁜 옷들과 좋은 화장품이 많아서 짱 좋은거 같아요!!      5              0
# 48       좋아하는 화장품이 있어서 찾는더 아무리 찾아도 없었는데 여기있었네요ㅠㅠ 다행이다      5              0
# 49  이렇게 제마음에 쏙든 쇼핑 어플리케이션은 이게 처음입니다 . 제 언니도 마찬가지로 ...      5              9
# 50                   다이어트 제품부터 뷰티제품까지 다양한 제품공구 흡족해요^^      5              0
# 51  아무리 찾아도 없었던 화장품 제품이 여기서 공구를 하고 있다니요!!>< 정말 앞으로...      5              0
# 52  다이어트 식품 뷰티제품 등등 제가 찾던 제품들이 진짜 공구로 다 열리고 있더라구요 ...      5              0
# 53         제가 원래 쓰려고 했던 화장품 여기서 공구로 때리더라구요~ 진짜 개이득이네요      5              0
# 54         기대이상이네요^^ 화장품에 관심이 많은데 다양한 화장품이 많아서 좋아요 ㅎㅎ      5              0
# 55                             진짜 제대로된 화장품만 판매하시네요^0^      5              0
# 56  기획전 그리고 이벤트 많이해서 잘만 하면 좋은가격에 득테 할 수있네요 그리고 요번에...      5              0
# 57  왠만한 쇼핑몰어플중에 제일 최악. 배송도 겁나느리고 받는옷들마다 상태는 최악. 엉덩...      1              1
#
#                      at  year  month  target  \
# 0   2023-11-28 22:16:36  2023     11       1
# 1   2023-11-19 22:06:54  2023     11       1
# 2   2023-08-26 01:20:20  2023      8       1
# 3   2023-08-02 07:44:25  2023      8       1
# 4   2023-07-31 22:35:40  2023      7       1
# 5   2023-07-16 20:47:32  2023      7       1
# 6   2023-05-27 13:13:30  2023      5       1
# 7   2022-11-21 01:34:19  2022     11       1
# 8   2022-11-12 15:55:42  2022     11       1
# 9   2022-10-24 16:37:58  2022     10       1
# 10  2022-10-11 14:35:21  2022     10       1
# 11  2022-10-02 00:36:47  2022     10       1
# 12  2022-09-20 18:49:14  2022      9       1
# 13  2022-08-20 13:58:30  2022      8       1
# 14  2022-08-13 09:32:13  2022      8       1
# 15  2022-08-08 19:41:02  2022      8       1
# 16  2022-07-24 00:49:48  2022      7       1
# 17  2022-07-18 21:44:00  2022      7       1
# 18  2022-07-08 17:19:23  2022      7       1
# 19  2022-06-29 21:32:29  2022      6       1
# 20  2022-06-23 07:01:41  2022      6       1
# 21  2022-06-19 16:30:27  2022      6       1
# 22  2022-04-27 23:51:41  2022      4       1
# 23  2022-04-01 17:45:58  2022      4       1
# 24  2022-03-22 06:34:27  2022      3       1
# 25  2022-03-11 20:53:43  2022      3       1
# 26  2022-02-27 18:09:30  2022      2       1
# 27  2022-02-18 14:13:20  2022      2       1
# 28  2022-02-13 00:19:31  2022      2       1
# 29  2022-02-11 22:52:30  2022      2       0
# 30  2022-01-30 12:26:52  2022      1       1
# 31  2022-01-12 17:37:01  2022      1       1
# 32  2021-12-14 08:00:33  2021     12       1
# 33  2021-11-11 14:10:38  2021     11       1
# 34  2021-10-19 11:09:46  2021     10       1
# 35  2021-09-26 21:42:41  2021      9       1
# 36  2021-09-18 22:21:20  2021      9       1
# 37  2021-08-27 10:35:34  2021      8       1
# 38  2021-08-13 19:38:38  2021      8       1
# 39  2021-07-17 20:11:28  2021      7       1
# 40  2021-07-17 11:36:22  2021      7       1
# 41  2021-05-06 01:01:38  2021      5       1
# 42  2021-04-07 17:40:48  2021      4       1
# 43  2021-01-29 11:10:50  2021      1       1
# 44  2020-10-05 01:29:57  2020     10       1
# 45  2020-09-06 22:03:17  2020      9       1
# 46  2020-07-15 22:09:14  2020      7       1
# 47  2020-01-22 01:18:51  2020      1       1
# 48  2019-04-25 16:58:29  2019      4       1
# 49  2019-04-22 08:41:24  2019      4       1
# 50  2019-04-16 15:55:46  2019      4       1
# 51  2019-04-02 19:21:02  2019      4       1
# 52  2019-04-01 16:56:10  2019      4       1
# 53  2019-03-26 22:42:12  2019      3       1
# 54  2018-12-24 21:50:12  2018     12       1
# 55  2018-12-16 02:07:54  2018     12       1
# 56  2018-10-28 16:38:21  2018     10       1
# 57  2018-08-02 22:37:56  2018      8       0
#
#                                                morphs
# 0   [친구, 추천, 해서, 이용, 해봤는데, 모든, 제품, 무료, 배송, 이고, 명품,...
# 1   [설치, 한지, 며칠, 안된, 솔직히, 쇼핑, 하다가, 게, 있어서, 한번, 깔아,...
# 2   [대한민국, 필수, 앱, ..., 올, 보다, 화장품, 싸고, 쿠폰, 왕창, 많이,...
# 3                [좋아요, 배송비, 없이, 옷, 이며, 화장품, 다, 살수있네요]
# 4   [진짜, 조아여, 친구, 진짜, 들어가면, 아니라고, 진짜, 깔아야한, 다, 해서,...
# 5   [가격, 괜찮고, 보고, 사면, 좋은, 옷, 많아요, 할인, 자주, 해주고요, 근데...
# 6            [옷, 이쁘고, 다양한, 화장품, 있어, 엄청, 좋아요, 추천, 합니당]
# 7   [너무, 유명해서, 되려, 깔, 마음, 없었는데, 어쩌다, 깔고, 쓰고, 있어요, ...
# 8   [무료, 배송, 쉽지, 않은데, 대단하네요, ^.^., 항상, 좋은, 물건, 좋은,...
# 9   [2, 계속, 사용, 하던, 유저, 무료, 배송, 에다가, 이쁜, 옷, 화장품, 맘...
# 10              [주문, 편리해서, 좋구요, 예쁜, 옷, 화장품, 많아서, 좋아요]
# 11  [쿠폰, 많이, 주고, 이쁜, 옷, 많고, 향수, 랑, 화장품, 있어서, 넘, 좋아...
# 12              [옷, 다양하고, 화장품, 소품, 살수있어서, 정말, 좋아요, 💖]
# 13  [좋아하는, 옷, 스타일, 문구, 먹거리, 가방, 화장품, 많아요, 근데, 싼, 티...
# 14  [무료, 배송, 넘, 조아요, 글구, 옷, 말고도, 문구, 화장품, 종류, 많아서,...
# 15  [진짜, 예쁘, 옷, 많았아서, 하루, 6, 구입, 했잖아요, ㅠㅠㅠ, 케이스, 있...
# 16  [냥, 쵝, 오입, 니, 다, 화장품, 옷, 문, 구류, 다, 서, 사면, 되요, ...
# 17      [옷, 뿐, 화장품, 소품, 팔아서, 정말, 좋아요, 근데, 가끔, 렉, 걸려요]
# 18  [무료, 배송, 이라서, 진짜, 좋은데, 무료, 더럽게, 와요, 진짜, 3일, 시켰...
# 19  [옷, 화장품, 악세사리, 필기, 도구, 인테리어, 생활, 사고싶은, 이쁘, 장한,...
# 20  [너무, 너무, 이쁜, 옷, 학용품, 화장품, 다양한, 게, 너무나도, 다, 색도,...
# 21  [진짜, 에이, 블리, 옷, 팔고, 화장품, 뭐, 가방, 이런거, 다, 팔아서, 진...
# 22                       [화장품, 모여있고, 무료, 배송, 이라, 좋네요]
# 23  [예쁜, 옷, 많고, 화장품, 장난감, ?, 같은것도, 있어서, 좋아요, 빠른, 배...
# 24  [필통, 옷, 바지, 화장품, 립밤, 도구, 엄청, 많아서, 좋아요, 배송, 빨라요...
# 25  [옷, 뿐, 거, 제품, 취미, 악기, 화장품, 악세서리, 신발, 모자, 다양한, ...
# 26                        [옷, 예쁘고, 화장품, 종류, 많아서, 좋아요]
# 27  [옷, 많고, 화장품, 물건, 여러가지, 많아서, 굉장히, 편리해서, 좋게, 쓰고있...
# 28                  [뷰티, 팔고, 쿠폰, 적용, 금액, 낮아, 사용, 좋아요]
# 29  [이메일, 문, 기존, 계정, 탈퇴, 새, 계정, 만들려고, 했는데, 재, 가입, ...
# 30  [리뷰, 썼었는데, 삭제, 됐네요, ㅠㅠ, 앱, 정말, 정말, 추천, 드려요, 10...
# 31  [아직, 배송, 받아, 봐서, 모르겠는데, 풀랫폼자체, 는, 매우, 괜춘함, 옷, ...
# 32  [앱, 옷, 뿐, 인스, 스티커, 케이스, 화장품, 팔아서, 좋은, 애, 그리구, ...
# 33  [진짜, 너무, 조하요, 마켓, 많고, 취향, 별로, 가격, 대, 색, 나이, 키,...
# 34  [정말, 가성, 비쩌, 는, 곳, 은, 없을듯, 15000원, 짜리를, 6, 처넌,...
# 35          [가성, 비, 좋은, 옷, 화장품, 홈, 데코, 이쁜거, 짱, 많음, ♡]
# 36  [다, 좋은데, 뷰티, 상품, 좀더, 많았으면, 좋겠어요, 는, 진짜진짜, 숯, 비...
# 37  [부모님, 몰래, 화장품, 옷, 사시, 는, 분, 한테, 강, 추하는, 앱, 쿠폰,...
# 38  [화장품, 여러, 옷, 살수, 있어서, 너무, 너무, 좋아요, 근데, 마켓, 의외로...
# 39  [옷, 뿐, 다이어리, 이불, 필기구, 화장품, 악세사리, 여러가지, 있어서, 너무...
# 40  [옷, 예뻐요, 바람, 불면, 큰일, ^^;;, 좀더, 실용, 성, 있게, 만들어,...
# 41  [아쉬운, 은, 마켓, 랭킹, 브랜드, 들어가면, 뷰티, 브랜드, 너무, 많아서, ...
# 42  [너무, 좋아요, 옷, 사서, 예쁘다는, 소리, 많이, 들었습니다, ㅎㅎ, 요즘, ...
# 43  [무료, 배송, 맘, 들지만, 옷살때, 는, 괜찮다, 했지만, 옷, 아닌, 악세사리...
# 44  [완전, 애용, 앱, 이기도, 이벤트, 많이하고, 쿠폰, 계속, 주시, 정말, 사용...
# 45  [에이, 블리, 이용, 편하고, 좋은데, 진, 짜, 아쉬운건, 결제, 수단, 편의점...
# 46  [넘, 좋아요, 쓰고, 있어요, 근데, 아쉬운, 은, 리뷰, 많이, 없다는, ..?...
# 47               [예쁜, 옷, 좋은, 화장품, 많아서, 짱, 좋은, 거, 같아요]
# 48  [좋아하는, 화장품, 있어서, 찾는, 아무리, 찾아도, 없었는데, 여기있었네요, ㅠ...
# 49  [마음, 쏙, 든, 쇼핑, 어플리케이션, 은, 게, 처음, 언니, 마찬가지, 쇼핑,...
# 50              [다이어트, 제품, 뷰티, 제품, 다양한, 제품, 공구, 흡족해요]
# 51  [아무리, 찾아도, 없었던, 화장품, 제품, 서, 공구, 있다니요, !!><, 정말...
# 52  [다이어트, 식품, 뷰티, 제품, 찾던, 제품, 진짜, 공구, 다, 열리고, 있더라...
# 53     [원래, 쓰려고, 했던, 화장품, 서, 공구, 때리더라구요, 진짜, 개이득, 이네]
# 54   [기, 대, 이네, 화장품, 관심, 많은데, 다양한, 화장품, 많아서, 좋아요, ㅎㅎ]
# 55                     [진짜, 제대로, 된, 화장품, 판매, 하시네요, 0]
# 56  [기획전, 이벤트, 많이, 해, 서, 잘만, 좋은, 가격, 득테, 있네요, 좋아하는...
# 57  [왠만한, 쇼핑몰, 어플, 제일, 최악, 배송, 겁나느, 리, 받는, 옷, 마다, ...

# %% [markdown]
# #### DTM 생성

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

cv = CountVectorizer()

beauty_filtered['morphs2'] = beauty_filtered['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
dtm = cv.fit_transform(beauty_filtered['morphs2'])
dtm
# Out:
# <58x760 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1242 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### 모델 학습

# %%
from sklearn.model_selection import train_test_split

x = dtm
y = beauty_filtered['target']

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping


model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# model.fit(X_train.A, y_train, epochs=10)

history = model.fit(X_train.A, y_train, epochs=100, validation_split=0.1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 680ms/step - loss: 0.6538 - accuracy: 0.6585 - val_loss: 0.6482 - val_accuracy: 0.8000
# Epoch 2/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6347 - accuracy: 0.7073 - val_loss: 0.6392 - val_accuracy: 0.8000
# Epoch 3/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6181 - accuracy: 0.7317 - val_loss: 0.6306 - val_accuracy: 0.8000
# Epoch 4/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6028 - accuracy: 0.7561 - val_loss: 0.6222 - val_accuracy: 0.8000
# Epoch 5/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5876 - accuracy: 0.7805 - val_loss: 0.6140 - val_accuracy: 0.8000
# Epoch 6/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5728 - accuracy: 0.8293 - val_loss: 0.6061 - val_accuracy: 0.8000
# Epoch 7/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5592 - accuracy: 0.8293 - val_loss: 0.5984 - val_accuracy: 0.8000
# Epoch 8/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5461 - accuracy: 0.8537 - val_loss: 0.5908 - val_accuracy: 0.8000
# Epoch 9/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5332 - accuracy: 0.8780 - val_loss: 0.5834 - val_accuracy: 0.8000
# Epoch 10/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5211 - accuracy: 0.8780 - val_loss: 0.5762 - val_accuracy: 0.8000
# Epoch 11/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5093 - accuracy: 0.8780 - val_loss: 0.5691 - val_accuracy: 0.8000
# Epoch 12/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4979 - accuracy: 0.9024 - val_loss: 0.5623 - val_accuracy: 0.8000
# Epoch 13/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4871 - accuracy: 0.9268 - val_loss: 0.5555 - val_accuracy: 0.8000
# Epoch 14/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4761 - accuracy: 0.9512 - val_loss: 0.5488 - val_accuracy: 0.8000
# Epoch 15/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4664 - accuracy: 0.9512 - val_loss: 0.5423 - val_accuracy: 0.8000
# Epoch 16/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4565 - accuracy: 0.9512 - val_loss: 0.5359 - val_accuracy: 0.8000
# Epoch 17/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4469 - accuracy: 0.9512 - val_loss: 0.5298 - val_accuracy: 0.8000
# Epoch 18/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4378 - accuracy: 0.9756 - val_loss: 0.5239 - val_accuracy: 0.8000
# Epoch 19/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4290 - accuracy: 0.9756 - val_loss: 0.5182 - val_accuracy: 0.8000
# Epoch 20/100
# 2/2 [==============================] - 0s 258ms/step - loss: 0.4202 - accuracy: 0.9756 - val_loss: 0.5125 - val_accuracy: 0.8000
# Epoch 21/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4121 - accuracy: 0.9756 - val_loss: 0.5070 - val_accuracy: 0.8000
# Epoch 22/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4043 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.8000
# Epoch 23/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3963 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.8000
# Epoch 24/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3889 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8000
# Epoch 25/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3816 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.8000
# Epoch 26/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3746 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.8000
# Epoch 27/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3677 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.8000
# Epoch 28/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3613 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.8000
# Epoch 29/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3549 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.8000
# Epoch 30/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3487 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8000
# Epoch 31/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3429 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.8000
# Epoch 32/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3372 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8000
# Epoch 33/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3315 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8000
# Epoch 34/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3262 - accuracy: 1.0000 - val_loss: 0.4485 - val_accuracy: 0.8000
# Epoch 35/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3210 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.8000
# Epoch 36/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3159 - accuracy: 1.0000 - val_loss: 0.4410 - val_accuracy: 0.8000
# Epoch 37/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3110 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.8000
# Epoch 38/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3061 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8000
# Epoch 39/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3015 - accuracy: 1.0000 - val_loss: 0.4302 - val_accuracy: 0.8000
# Epoch 40/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2970 - accuracy: 1.0000 - val_loss: 0.4267 - val_accuracy: 0.8000
# Epoch 41/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2925 - accuracy: 1.0000 - val_loss: 0.4233 - val_accuracy: 0.8000
# Epoch 42/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2882 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.8000
# Epoch 43/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2840 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.8000
# Epoch 44/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2798 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.8000
# Epoch 45/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2757 - accuracy: 1.0000 - val_loss: 0.4099 - val_accuracy: 0.8000
# Epoch 46/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2718 - accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.8000
# Epoch 47/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2679 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.8000
# Epoch 48/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2641 - accuracy: 1.0000 - val_loss: 0.4006 - val_accuracy: 0.8000
# Epoch 49/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2605 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.8000
# Epoch 50/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2569 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.8000
# Epoch 51/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2534 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.8000
# Epoch 52/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2501 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.8000
# Epoch 53/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2467 - accuracy: 1.0000 - val_loss: 0.3868 - val_accuracy: 0.8000
# Epoch 54/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2435 - accuracy: 1.0000 - val_loss: 0.3841 - val_accuracy: 0.8000
# Epoch 55/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2403 - accuracy: 1.0000 - val_loss: 0.3814 - val_accuracy: 0.8000
# Epoch 56/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2372 - accuracy: 1.0000 - val_loss: 0.3788 - val_accuracy: 0.8000
# Epoch 57/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2341 - accuracy: 1.0000 - val_loss: 0.3763 - val_accuracy: 1.0000
# Epoch 58/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.2312 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 1.0000
# Epoch 59/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2282 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 1.0000
# Epoch 60/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2254 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 1.0000
# Epoch 61/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2226 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 1.0000
# Epoch 62/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2199 - accuracy: 1.0000 - val_loss: 0.3644 - val_accuracy: 1.0000
# Epoch 63/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2172 - accuracy: 1.0000 - val_loss: 0.3621 - val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2146 - accuracy: 1.0000 - val_loss: 0.3598 - val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2120 - accuracy: 1.0000 - val_loss: 0.3576 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2094 - accuracy: 1.0000 - val_loss: 0.3554 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2070 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2045 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2021 - accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1998 - accuracy: 1.0000 - val_loss: 0.3469 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1975 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1953 - accuracy: 1.0000 - val_loss: 0.3430 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1931 - accuracy: 1.0000 - val_loss: 0.3410 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1910 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1890 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1869 - accuracy: 1.0000 - val_loss: 0.3353 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1850 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1830 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1811 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1793 - accuracy: 1.0000 - val_loss: 0.3281 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1775 - accuracy: 1.0000 - val_loss: 0.3263 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1756 - accuracy: 1.0000 - val_loss: 0.3246 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1739 - accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1721 - accuracy: 1.0000 - val_loss: 0.3212 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1703 - accuracy: 1.0000 - val_loss: 0.3196 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1687 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.3163 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1653 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1637 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1621 - accuracy: 1.0000 - val_loss: 0.3117 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1605 - accuracy: 1.0000 - val_loss: 0.3101 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1590 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1575 - accuracy: 1.0000 - val_loss: 0.3072 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1559 - accuracy: 1.0000 - val_loss: 0.3057 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1545 - accuracy: 1.0000 - val_loss: 0.3042 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1530 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1516 - accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1502 - accuracy: 1.0000 - val_loss: 0.2999 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1488 - accuracy: 1.0000 - val_loss: 0.2985 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1474 - accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 1.0000

# %% [markdown]
# #### 모델 검증

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
plt.clf()       #그래프 초기화

epochs = range(1, len(acc)+1)
plt.plot(epochs, acc, label='Training Accuracy', color='darkseagreen')
plt.plot(epochs, val_acc, label='Validation Accuracy', color='darkgreen')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
plt.clf()       #그래프 초기화

epochs = range(1, len(acc)+1)
plt.plot(epochs, loss, label='Training Loss', color='darkseagreen')
plt.plot(epochs, val_loss, label='Validation Loss', color='darkgreen')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #### 최종 모델 선택

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.fit(X_train.A, y_train, epochs=20)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 1s 249ms/step - loss: 0.6945 - accuracy: 0.4783
# Epoch 2/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6759 - accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6572 - accuracy: 0.5435
# Epoch 4/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6406 - accuracy: 0.6087
# Epoch 5/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6236 - accuracy: 0.6739
# Epoch 6/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6084 - accuracy: 0.7174
# Epoch 7/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5934 - accuracy: 0.7609
# Epoch 8/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5791 - accuracy: 0.7826
# Epoch 9/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5651 - accuracy: 0.8261
# Epoch 10/20
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5516 - accuracy: 0.8696
# Epoch 11/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5389 - accuracy: 0.8913
# Epoch 12/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.9348
# Epoch 13/20
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5145 - accuracy: 0.9565
# Epoch 14/20
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5032 - accuracy: 0.9565
# Epoch 15/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4923 - accuracy: 0.9783
# Epoch 16/20
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4818 - accuracy: 0.9783
# Epoch 17/20
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4714 - accuracy: 0.9783
# Epoch 18/20
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4614 - accuracy: 0.9783
# Epoch 19/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4523 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4431 - accuracy: 1.0000

# %% [markdown]
# ## 2020~ 리뷰 분석

# %% [markdown]
# ### 데이터 준비

# %%
import pandas as pd

yearly = pd.read_csv('./data/ably_yearly.csv')
yearly.head()
# Out:
#                                              content  score  thumbsUpCount  \
# 0                                      ( ´͈ ᵕ `͈ )◞♡      5              0
# 1  구매했는데 배송 안되길래 봤더니 취소 진행중이더라구요?? 아니 품절된 상품이면 구매...      1              0
# 2                            품질 좋고 가격 저렴해요 가성비 멋져버려요      5              0
# 3                            40대에도 쇼핑할수있는 폭이 넓어 좋습니다      5              0
# 4                                                좋아용      5              0
#
#                     at  year  month  target
# 0  2023-12-27 10:26:27  2023     12       1
# 1  2023-12-27 08:52:56  2023     12       0
# 2  2023-12-26 22:49:53  2023     12       1
# 3  2023-12-26 21:13:51  2023     12       1
# 4  2023-12-26 16:39:20  2023     12       1

# %% [markdown]
# ### 전처리

# %%
yearly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21936 entries, 0 to 21935
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        21936 non-null  object
#  1   score          21936 non-null  int64
#  2   thumbsUpCount  21936 non-null  int64
#  3   at             21936 non-null  object
#  4   year           21936 non-null  int64
#  5   month          21936 non-null  int64
#  6   target         21936 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# * 2020년 이후 리뷰만 필터링

# %%
yearly_filtered = yearly[yearly['year'] >= 2020]
yearly_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16005 entries, 0 to 16004
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        16005 non-null  object
#  1   score          16005 non-null  int64
#  2   thumbsUpCount  16005 non-null  int64
#  3   at             16005 non-null  object
#  4   year           16005 non-null  int64
#  5   month          16005 non-null  int64
#  6   target         16005 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1000.3+ KB

# %% [markdown]
# #### 토큰화

# %%
from konlpy.tag import Okt
okt = Okt()

yearly_filtered['morphs'] = [okt.morphs(content) for content in yearly_filtered['content']]
yearly_filtered
# Out:
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/1356793752.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_filtered['morphs'] = [okt.morphs(content) for content in yearly_filtered['content']]
#                                                  content  score  \
# 0                                          ( ´͈ ᵕ `͈ )◞♡      5
# 1      구매했는데 배송 안되길래 봤더니 취소 진행중이더라구요?? 아니 품절된 상품이면 구매...      1
# 2                                품질 좋고 가격 저렴해요 가성비 멋져버려요      5
# 3                                40대에도 쇼핑할수있는 폭이 넓어 좋습니다      5
# 4                                                    좋아용      5
# ...                                                  ...    ...
# 16000                                                 감사      5
# 16001                                               굿입니다      4
# 16002                       옷도예쁘고.우선받아봐야알겠지만.한눈에볼수있어서좋아요      4
# 16003                                                조아요      5
# 16004  아니...할인쿠폰은 이해하는데 왜 포인트까지 이따구로 했는지... 원가의 10퍼까지...      1
#
#        thumbsUpCount                   at  year  month  target  \
# 0                  0  2023-12-27 10:26:27  2023     12       1
# 1                  0  2023-12-27 08:52:56  2023     12       0
# 2                  0  2023-12-26 22:49:53  2023     12       1
# 3                  0  2023-12-26 21:13:51  2023     12       1
# 4                  0  2023-12-26 16:39:20  2023     12       1
# ...              ...                  ...   ...    ...     ...
# 16000              0  2020-01-01 03:41:37  2020      1       1
# 16001              0  2020-01-01 03:27:01  2020      1       1
# 16002              0  2020-01-01 02:44:32  2020      1       1
# 16003              0  2020-01-01 02:13:58  2020      1       1
# 16004              0  2020-01-01 01:29:51  2020      1       0
#
#                                                   morphs
# 0                                [(, ´͈, ᵕ, `, ͈, ), ◞♡]
# 1      [구매, 했는데, 배송, 안되길래, 봤더니, 취소, 진행중, 이, 더라구요, ??,...
# 2                     [품질, 좋고, 가격, 저렴해요, 가성, 비, 멋져, 버려요]
# 3                    [40, 대에도, 쇼핑, 할수있는, 폭, 이, 넓어, 좋습니다]
# 4                                                  [좋아용]
# ...                                                  ...
# 16000                                               [감사]
# 16001                                           [굿, 입니다]
# 16002  [옷, 도, 예쁘고, ., 우선, 받아, 봐야, 알겠지만, ., 한눈, 에, 볼수있...
# 16003                                              [조아요]
# 16004  [아니, ..., 할인, 쿠폰, 은, 이해, 하는데, 왜, 포인트, 까지, 이따, ...
#
# [16005 rows x 8 columns]

# %% [markdown]
# #### 불용어 처리

# %%
# 불용어 목록
text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
stop_words = text.split(" ")
stop_words
# Out:
# ['~',
#  '~~',
#  '~~~',
#  '~~~~',
#  '~~~~~',
#  '^',
#  '^^',
#  '!',
#  '!!',
#  'ㅜㅜ',
#  '.',
#  '..',
#  ',',
#  ',,',
#  '가',
#  '도',
#  '고',
#  '이나',
#  '요',
#  '아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를',
#  '들면',
#  '예를',
#  '들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수',
#  '없다',
#  '해서는',
#  '안된다',
#  '뿐만',
#  '아니라',
#  '만이',
#  '아니다',
#  '만은',
#  '아니다',
#  '막론하고',
#  '관계없이',
#  '그치지',
#  '않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지',
#  '않다',
#  '따지지',
#  '않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만',
#  '못하다',
#  '하는',
#  '편이',
#  '낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이',
#  '외에',
#  '이',
#  '밖에',
#  '하여야',
#  '비로소',
#  '한다면',
#  '몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할',
#  '생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게',
#  '함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에',
#  '틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해',
#  '말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로',
#  '말하자면',
#  '이와',
#  '반대로',
#  '바꾸어서',
#  '말하면',
#  '바꾸어서',
#  '한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에',
#  '가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한',
#  '까닭에',
#  '하기',
#  '때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에',
#  '따르는',
#  '때가',
#  '되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼',
#  '어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서',
#  '보아',
#  '비추어',
#  '보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지',
#  '않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에',
#  '안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시',
#  '말하자면',
#  '바꿔',
#  '말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른',
#  '방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도',
#  '없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만',
#  '못하다',
#  '하는것이',
#  '낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느',
#  '년도',
#  '라',
#  '해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할',
#  '줄',
#  '안다',
#  '할',
#  '힘이',
#  '있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로',
#  '쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서',
#  '서술한바와같이',
#  '인',
#  '듯하다',
#  '하지',
#  '않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도',
#  '불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지',
#  '않도록',
#  '않기',
#  '위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가',
#  '알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은',
#  '몰랏다',
#  '하는',
#  '김에',
#  '겸사겸사',
#  '하는바',
#  '그런',
#  '까닭에',
#  '한',
#  '이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기',
#  '위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만',
#  '못하다',
#  '하기보다는',
#  '차라리',
#  '하는',
#  '편이',
#  '낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로',
#  '말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지',
#  '않으면',
#  '그렇지',
#  '않다면',
#  '안',
#  '그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수',
#  '없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지',
#  '않도록',
#  '않기',
#  '위해서',
#  '이르기까지',
#  '이',
#  '되다',
#  '로',
#  '인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로',
#  '인하여',
#  '그래서',
#  '이',
#  '때문에',
#  '그러므로',
#  '그런',
#  '까닭에',
#  '알',
#  '수',
#  '있다',
#  '결론을',
#  '낼',
#  '수',
#  '있다',
#  '으로',
#  '인하여',
#  '있다',
#  '어떤것',
#  '관계가',
#  '있다',
#  '관련이',
#  '있다',
#  '연관되다',
#  '어떤것들',
#  '에',
#  '대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면',
#  '할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에',
#  '있다',
#  '에',
#  '달려',
#  '있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와',
#  '같은',
#  '요만큼',
#  '요만한',
#  '것',
#  '얼마',
#  '안',
#  '되는',
#  '것',
#  '이만큼',
#  '이',
#  '정도의',
#  '이렇게',
#  '많은',
#  '것',
#  '이와',
#  '같다',
#  '이때',
#  '이렇구나',
#  '것과',
#  '같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와',
#  '같은',
#  '사람들',
#  '부류의',
#  '사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에',
#  '한하다',
#  '하기만',
#  '하면',
#  '도착하다',
#  '까지',
#  '미치다',
#  '도달하다',
#  '정도에',
#  '이르다',
#  '할',
#  '지경이다',
#  '결과에',
#  '이르다',
#  '관해서는',
#  '여러분',
#  '하고',
#  '있다',
#  '한',
#  '후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에',
#  '종합한것과같이',
#  '총적으로',
#  '보면',
#  '총적으로',
#  '말하면',
#  '총적으로',
#  '대로',
#  '하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할',
#  '따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영',
#  '이',
#  '있',
#  '하',
#  '것',
#  '들',
#  '그',
#  '되',
#  '수',
#  '이',
#  '보',
#  '않',
#  '없',
#  '나',
#  '사람',
#  '주',
#  '아니',
#  '등',
#  '같',
#  '우리',
#  '때',
#  '년',
#  '가',
#  '한',
#  '지',
#  '대하',
#  '오',
#  '말',
#  '일',
#  '그렇',
#  '위하',
#  '때문',
#  '그것',
#  '두',
#  '말하',
#  '알',
#  '그러나',
#  '받',
#  '못하',
#  '일',
#  '그런',
#  '또',
#  '문제',
#  '더',
#  '사회',
#  '많',
#  '그리고',
#  '좋',
#  '크',
#  '따르',
#  '중',
#  '나오',
#  '가지',
#  '씨',
#  '시키',
#  '만들',
#  '지금',
#  '생각하',
#  '그러',
#  '속',
#  '하나',
#  '집',
#  '살',
#  '모르',
#  '적',
#  '월',
#  '데',
#  '자신',
#  '안',
#  '어떤',
#  '내',
#  '내',
#  '경우',
#  '명',
#  '생각',
#  '시간',
#  '그녀',
#  '다시',
#  '이런',
#  '앞',
#  '보이',
#  '번',
#  '나',
#  '다른',
#  '어떻',
#  '여자',
#  '개',
#  '전',
#  '들',
#  '사실',
#  '이렇',
#  '점',
#  '싶',
#  '말',
#  '정도',
#  '좀',
#  '원',
#  '잘',
#  '통하',
#  '놓',
#  '입니다']

# %%
stop_words_set = set(stop_words)
yearly_filtered['morphs'] = [
    [word for word in morphs if word not in stop_words_set]
    for morphs in yearly_filtered['morphs']
]
# Out:
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/481170780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_filtered['morphs'] = [

# %% [markdown]
# #### DTM

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

cv = CountVectorizer()

yearly_filtered['morphs'] = yearly_filtered['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
dtm = cv.fit_transform(yearly_filtered['morphs'])
dtm
# Out:
# /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/ipykernel_995/936669968.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_filtered['morphs'] = yearly_filtered['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
# <16005x17119 sparse matrix of type '<class 'numpy.int64'>'
# 	with 124627 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 모델 학습

# %%
from sklearn.model_selection import train_test_split

x = dtm
y = yearly_filtered['target']

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping


model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train.A, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 321/321 [==============================] - 5s 14ms/step - loss: 0.5648 - accuracy: 0.8834 - val_loss: 0.4760 - val_accuracy: 0.8907
# Epoch 2/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.4134 - accuracy: 0.9066 - val_loss: 0.3822 - val_accuracy: 0.8973
# Epoch 3/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.3314 - accuracy: 0.9181 - val_loss: 0.3274 - val_accuracy: 0.9008
# Epoch 4/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.2793 - accuracy: 0.9247 - val_loss: 0.2927 - val_accuracy: 0.9043
# Epoch 5/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.2434 - accuracy: 0.9311 - val_loss: 0.2694 - val_accuracy: 0.9067
# Epoch 6/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.2171 - accuracy: 0.9355 - val_loss: 0.2530 - val_accuracy: 0.9051
# Epoch 7/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.1971 - accuracy: 0.9401 - val_loss: 0.2412 - val_accuracy: 0.9063
# Epoch 8/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.1813 - accuracy: 0.9432 - val_loss: 0.2325 - val_accuracy: 0.9082
# Epoch 9/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.1685 - accuracy: 0.9465 - val_loss: 0.2262 - val_accuracy: 0.9075
# Epoch 10/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.1580 - accuracy: 0.9498 - val_loss: 0.2214 - val_accuracy: 0.9086
# Epoch 11/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.1490 - accuracy: 0.9512 - val_loss: 0.2178 - val_accuracy: 0.9102
# Epoch 12/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.1413 - accuracy: 0.9527 - val_loss: 0.2150 - val_accuracy: 0.9110
# Epoch 13/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.1346 - accuracy: 0.9542 - val_loss: 0.2130 - val_accuracy: 0.9110
# Epoch 14/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.1286 - accuracy: 0.9561 - val_loss: 0.2115 - val_accuracy: 0.9098
# Epoch 15/20
# 321/321 [==============================] - 2s 7ms/step - loss: 0.1233 - accuracy: 0.9577 - val_loss: 0.2104 - val_accuracy: 0.9094
# Epoch 16/20
# 321/321 [==============================] - 2s 7ms/step - loss: 0.1185 - accuracy: 0.9591 - val_loss: 0.2096 - val_accuracy: 0.9098
# Epoch 17/20
# 321/321 [==============================] - 1s 4ms/step - loss: 0.1141 - accuracy: 0.9611 - val_loss: 0.2091 - val_accuracy: 0.9098
# Epoch 18/20
# 321/321 [==============================] - 2s 6ms/step - loss: 0.1100 - accuracy: 0.9617 - val_loss: 0.2088 - val_accuracy: 0.9086
# Epoch 19/20
# 321/321 [==============================] - 1s 4ms/step - loss: 0.1063 - accuracy: 0.9635 - val_loss: 0.2086 - val_accuracy: 0.9102
# Epoch 20/20
# 321/321 [==============================] - 2s 5ms/step - loss: 0.1028 - accuracy: 0.9643 - val_loss: 0.2087 - val_accuracy: 0.9102

# %% [markdown]
# #### 모델 검증

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

fig, axes = plt.subplots(ncols=2, figsize=(12, 4))
epochs = range(1, len(acc)+1)
axes[0].plot(epochs, acc, label='Training Accuracy', color='darkseagreen')
axes[0].plot(epochs, val_acc, label='Validation Accuracy', color='darkgreen')
axes[0].set_title('Training and Validation Accuracy')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, label='Training Loss', color='darkseagreen')
axes[1].plot(epochs, val_loss, label='Validation Loss', color='darkgreen')
axes[1].set_title('Training and Validation Loss')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 최종 모델 선택

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.fit(X_train.A, y_train, epochs=5,validation_split=0.2)
# Out:
# Epoch 1/5
# 321/321 [==============================] - 3s 8ms/step - loss: 0.5693 - accuracy: 0.8786 - val_loss: 0.4784 - val_accuracy: 0.8934
# Epoch 2/5
# 321/321 [==============================] - 1s 4ms/step - loss: 0.4158 - accuracy: 0.9079 - val_loss: 0.3831 - val_accuracy: 0.8965
# Epoch 3/5
# 321/321 [==============================] - 2s 5ms/step - loss: 0.3332 - accuracy: 0.9178 - val_loss: 0.3282 - val_accuracy: 0.9039
# Epoch 4/5
# 321/321 [==============================] - 1s 4ms/step - loss: 0.2806 - accuracy: 0.9259 - val_loss: 0.2932 - val_accuracy: 0.9043
# Epoch 5/5
# 321/321 [==============================] - 2s 5ms/step - loss: 0.2444 - accuracy: 0.9304 - val_loss: 0.2696 - val_accuracy: 0.9063

# %% [markdown]
# ## 대규모 데이터로 훈련시킨 모델로 뷰티 언급 리뷰 감성분석

# %% [markdown]
# ### 전처리 및 토큰화 함수로 정리하기

# %% [markdown]
# #### 데이터셋 정리

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

okt = Okt()

# %%
beauty_df = pd.read_csv('./data/ably_beauty_filtered.csv')
yearly_df = pd.read_csv('./data/ably_yearly.csv')

# %%
beauty_df = beauty_df[['content','target']]
yearly_df = yearly_df[['content','target']]

# %%
# 2020년 이후 리뷰 전체에서 뷰티 언급 리뷰 제거
print(len(yearly_df))
yearly_df = yearly_df[~yearly_df['content'].isin(beauty_df['content'])]
print(len(yearly_df))
# Out:
# 21936
# 21878

# %%
def tokenize(dataFrame):
    dataFrame['morphs'] = [okt.morphs(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer(max_features=800)
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)   
    return dataFrame,dtm

beauty_preprocessed, beauty_dtm = data_preprocessing(beauty_df)
yearly_preprocessed, yearly_dtm = data_preprocessing(yearly_df)

# %% [markdown]
# ### 머신러닝

# %%
X_train = yearly_dtm
y_train = yearly_preprocessed['target']
X_test = beauty_dtm
y_test = beauty_preprocessed['target']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping


model = Sequential()
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train.A, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 547/547 [==============================] - 3s 3ms/step - loss: 0.5199 - accuracy: 0.8773 - val_loss: 0.4479 - val_accuracy: 0.8515
# Epoch 2/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.3557 - accuracy: 0.9057 - val_loss: 0.3660 - val_accuracy: 0.8604
# Epoch 3/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2860 - accuracy: 0.9109 - val_loss: 0.3268 - val_accuracy: 0.8663
# Epoch 4/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2491 - accuracy: 0.9141 - val_loss: 0.3057 - val_accuracy: 0.8672
# Epoch 5/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2272 - accuracy: 0.9160 - val_loss: 0.2933 - val_accuracy: 0.8679
# Epoch 6/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2133 - accuracy: 0.9178 - val_loss: 0.2859 - val_accuracy: 0.8697
# Epoch 7/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2039 - accuracy: 0.9196 - val_loss: 0.2811 - val_accuracy: 0.8716
# Epoch 8/20
# 547/547 [==============================] - 2s 3ms/step - loss: 0.1973 - accuracy: 0.9207 - val_loss: 0.2774 - val_accuracy: 0.8725
# Epoch 9/20
# 547/547 [==============================] - 1s 3ms/step - loss: 0.1923 - accuracy: 0.9217 - val_loss: 0.2745 - val_accuracy: 0.8732
# Epoch 10/20
# 547/547 [==============================] - 2s 3ms/step - loss: 0.1883 - accuracy: 0.9231 - val_loss: 0.2723 - val_accuracy: 0.8743
# Epoch 11/20
# 547/547 [==============================] - 2s 3ms/step - loss: 0.1850 - accuracy: 0.9246 - val_loss: 0.2701 - val_accuracy: 0.8752
# Epoch 12/20
# 547/547 [==============================] - 1s 3ms/step - loss: 0.1822 - accuracy: 0.9249 - val_loss: 0.2682 - val_accuracy: 0.8761
# Epoch 13/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.9259 - val_loss: 0.2667 - val_accuracy: 0.8757
# Epoch 14/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1778 - accuracy: 0.9262 - val_loss: 0.2653 - val_accuracy: 0.8775
# Epoch 15/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1760 - accuracy: 0.9276 - val_loss: 0.2644 - val_accuracy: 0.8796
# Epoch 16/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1744 - accuracy: 0.9278 - val_loss: 0.2634 - val_accuracy: 0.8807
# Epoch 17/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1730 - accuracy: 0.9285 - val_loss: 0.2626 - val_accuracy: 0.8807
# Epoch 18/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1717 - accuracy: 0.9294 - val_loss: 0.2621 - val_accuracy: 0.8812
# Epoch 19/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1705 - accuracy: 0.9294 - val_loss: 0.2618 - val_accuracy: 0.8816
# Epoch 20/20
# 547/547 [==============================] - 1s 2ms/step - loss: 0.1695 - accuracy: 0.9299 - val_loss: 0.2612 - val_accuracy: 0.8814

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

fig, axes = plt.subplots(ncols=2, figsize=(12, 4))
epochs = range(1, len(acc)+1)

axes[0].plot(epochs, acc, label='Training Accuracy', color='darkseagreen')
axes[0].plot(epochs, val_acc, label='Validation Accuracy', color='darkgreen')
axes[0].set_title('Training and Validation Accuracy')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, label='Training Loss', color='darkseagreen')
axes[1].plot(epochs, val_loss, label='Validation Loss', color='darkgreen')
axes[1].set_title('Training and Validation Loss')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 최종 모델 선택

# %%
final_model = Sequential()
final_model.add(Dense(1,activation='sigmoid'))
final_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

final_model.fit(X_train.A, y_train, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 547/547 [==============================] - 2s 2ms/step - loss: 0.5208 - accuracy: 0.8776 - val_loss: 0.4496 - val_accuracy: 0.8476
# Epoch 2/5
# 547/547 [==============================] - 1s 2ms/step - loss: 0.3564 - accuracy: 0.9051 - val_loss: 0.3665 - val_accuracy: 0.8581
# Epoch 3/5
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2865 - accuracy: 0.9100 - val_loss: 0.3267 - val_accuracy: 0.8643
# Epoch 4/5
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2493 - accuracy: 0.9130 - val_loss: 0.3052 - val_accuracy: 0.8668
# Epoch 5/5
# 547/547 [==============================] - 1s 2ms/step - loss: 0.2274 - accuracy: 0.9156 - val_loss: 0.2929 - val_accuracy: 0.8675

# %%
final_model.save('./data/final_model_20231228.h5')
# Out:
# /Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model
final_model = load_model('./data/final_model_20231228.h5')

# %%
import tensorflow as tf
from scipy.sparse import csr_matrix

def convert_sparse_matrix_to_sparse_tensor(sparse_matrix):
    coo = sparse_matrix.tocoo()
    indices = tf.constant(list(zip(coo.row, coo.col)), dtype=tf.int64)
    values = tf.constant(coo.data, dtype=tf.float32)
    shape = tf.constant(coo.shape, dtype=tf.int64)
    return tf.SparseTensor(indices, values, shape)

# %%
beauty_sparse = convert_sparse_matrix_to_sparse_tensor(beauty_dtm)
yearly_sparse = convert_sparse_matrix_to_sparse_tensor(yearly_dtm)

beauty_sparse = tf.sparse.reorder(beauty_sparse)
yearly_sparse = tf.sparse.reorder(yearly_sparse)

# %%
X_test = beauty_sparse
y_test = beauty_preprocessed['target']

# %%
type(beauty_dtm)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
# Convert sparse tensor to dense tensor
X_test_dense = tf.sparse.to_dense(X_test)

# Ensure y_test is in a suitable format, e.g., NumPy array
y_test_numpy = y_test.values

# Evaluate the model
loss_and_metrics = model.evaluate(X_test_dense, y_test_numpy, batch_size=32)

print('## evaluation loss and_metrics ##')
print(loss_and_metrics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 8
#       5 y_test_numpy = y_test.values
#       7 # Evaluate the model
# ----> 8 loss_and_metrics = model.evaluate(X_test_dense, y_test_numpy, batch_size=32)
#      10 print('## evaluation loss and_metrics ##')
#      11 print(loss_and_metrics)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/y6/tjfrq8vj411cyf6zll2ppq_w0000gn/T/__autograph_generated_file7jsk9dhx.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2066, in test_function  *
#         return step_function(self, iterator)
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2049, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2037, in run_step  **
#         outputs = model.test_step(data)
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1917, in test_step
#         y_pred = self(x, training=False)
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/brielle/anaconda3/lib/python3.11/site-packages/keras/src/engine/input_spec.py", line 280, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'sequential_2' (type Sequential).
#
#     Input 0 of layer "dense_2" is incompatible with the layer: expected axis -1 of input shape to have value 800, but received input with shape (None, 759)
#
#     Call arguments received by layer 'sequential_2' (type Sequential):
#       • inputs=tf.Tensor(shape=(None, 759), dtype=float32)
#       • training=False
#       • mask=None
