# %% [markdown]
# # 리뷰 데이터 수집

# %%
# https://play.google.com/store/apps/details?id=com.cjoshppingphone&hl=ko-KR

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.cjoshppingphone",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST,
                      count=50000)

# %%
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
import numpy as np
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    raw_df.to_csv(f'./data/{name}_raw.csv',index=False)
    df.to_csv(f'./data/{name}_df.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'cjonstyle_test')

# %%
df.sort_values('at',ascending=False)
# Out:
#                                                  content  score  \
# 15312                                           계속 실행 불가      1
# 7081                                                빠른배송      5
# 7078                             배송 빠르고 주의사항 첨부까지 잘지켜줍니다      5
# 19     택배도 적정시기에 잘 보내주셨고, 포근하니 부러운 색상이라 맘에 들어요. 다만 좀 ...      4
# 7083                                                 좋아요      5
# ...                                                  ...    ...
# 14355                             전보다예뻐지고 상품을. 찾기도 편해졌네요      5
# 14358                   업뎃하고 더 좋아졌어요♥특히 방송볼수있어서 너무 좋아요ㅎㅎ      5
# 14356                                   이전 앱보다 더 산뜻해졌네요!      4
# 14357  장바구니 오류! 주문삭제도 안되고 선택주문도 안되고.... 일단 장바구니에 담은건 ...      3
# 14359                                        여러가지물건보니좋아요      4
#
#        thumbsUpCount                  at
# 15312              0 2024-01-03 13:32:40
# 7081               0 2024-01-03 10:42:27
# 7078               0 2024-01-02 23:35:58
# 19                 0 2024-01-02 20:18:01
# 7083               0 2024-01-02 18:20:36
# ...              ...                 ...
# 14355              0 2011-04-28 23:55:30
# 14358              0 2011-04-24 04:30:41
# 14356              0 2011-04-23 09:58:07
# 14357              3 2011-03-22 22:07:57
# 14359              0 2011-02-28 19:30:53
#
# [15704 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15704 entries, 0 to 15703
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15585 non-null  object
#  1   score          15704 non-null  int64
#  2   thumbsUpCount  15704 non-null  int64
#  3   at             15704 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 490.9+ KB

# %%
df['year'] = df['at'].dt.strftime("%Y")
df
# Out:
#                                                  content  score  \
# 0      실용적인 제품이 많이 소개돼서 좋아요~근데 왠지 노출이 많이 되지 못하는 것 같아요...      5
# 1      그동안 블편함을 못느꼈었는데 최근에 너무 이상해요. 상품 클릭하면 상세화면 내용 안...      1
# 2      분명히 앱을 실행한 건데도, 바로가기 적용이 안되어서 혜택 적용(vip즉시할인 등)...      3
# 3      로그인 화면에서 튕기면서 메인페이지로 넘어갑니다. 로그인 자체가 불가능해서 물건 주...      1
# 4      앱에서 상품 볼때 로딩이 너무 느려요. 썸네일 이미지랑 텍스트 로딩이 너무 느리고,...      1
# ...                                                  ...    ...
# 15699                                             좋은것같아요      5
# 15700                                                 賽海      5
# 15701                                              지하철노선      5
# 15702                                                ...      5
# 15703                                               None      4
#
#        thumbsUpCount                  at  year
# 0                175 2023-10-10 11:23:58  2023
# 1                385 2023-08-12 23:14:26  2023
# 2               1449 2018-10-10 22:04:05  2018
# 3                699 2022-07-07 23:40:08  2022
# 4                693 2022-09-07 15:02:18  2022
# ...              ...                 ...   ...
# 15699              0 2014-11-19 11:31:57  2014
# 15700              0 2022-01-01 08:41:28  2022
# 15701              1 2015-07-06 14:01:04  2015
# 15702              0 2015-08-17 14:11:41  2015
# 15703              0 2014-03-06 13:50:58  2014
#
# [15704 rows x 5 columns]

# %%
df.loc[:][df['year']==2022]
# Out:
# Empty DataFrame
# Columns: [content, score, thumbsUpCount, at, year]
# Index: []

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df['content'].isnull().sum()
# Out:
# 119

# %%
print(df.info())
print()
df.dropna(subset='content',axis=0,inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15704 entries, 0 to 15703
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15585 non-null  object
#  1   score          15704 non-null  int64
#  2   thumbsUpCount  15704 non-null  int64
#  3   at             15704 non-null  datetime64[ns]
#  4   year           15704 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 613.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 15585 entries, 0 to 15702
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15585 non-null  object
#  1   score          15585 non-null  int64
#  2   thumbsUpCount  15585 non-null  int64
#  3   at             15585 non-null  datetime64[ns]
#  4   year           15585 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 730.5+ KB
# None

# %%
def tokenize(dataFrame):
    okt = Okt()
    
    dataFrame['morphs'] = [okt.morphs(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
tokenized = tokenize(df)

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <15585x16370 sparse matrix of type '<class 'numpy.int64'>'
# 	with 97496 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <15585x16370 sparse matrix of type '<class 'numpy.float64'>'
# 	with 97496 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '실용 제품 많이 소개 돼서 좋아요 근데 왠지 노출 많이 되지 못 같아요 채널 많이 넘겨야 만나지는 느낌 TV 보면서 모바일 구매 라서 주어지는 서비스 는 제품 비해 너무 제한 이라는 별로 혜택 느껴지지 않아요,그동안 블편함 못 느꼈었는데 최근 너무 이상해요 상품 클릭 상세 화면 내용 뜨는 빈번 장바구니 넣기 버튼 눌러도 먹통 많아요 앱 진짜 버벅댄다는 느낌 많이 받습니다 결제 빨리 넘어갈 많구요 업데이트 안해 서 건가 싶어서 계속 체크 해보는데 아니고 엄청 답답하네요 해결 해주세요,분명히 앱 실행 건데 바로가기 적용 안되어서 혜택 적용 ( vip 할인 ) 안되는 계속 발생 앱 재실 행해 강제 종료 재실 행해 폰 재부팅 마찬가지 앱 자체 삭제 재 설치 해야만 합니다 .( 해당 오류 수십 겪다 보니 ... 타 사이트 광고 배너 클릭 해 씨제이 몰 사이트 실행 했다가 앱 실행 로는 계속 에러 는 같더군요 기 기 분명 아니에요 예전 기기 사용 시 에도 동일한 계속 있었습니다 타 사이트 이용 하다가 실수 로라 씨제이 몰의 광고 배너 클릭 꼭 오류 발생 걸 확인 앱 재 설치 해왔습니다 정말 불편하고 짜증납니다 앱 개발 팀 꼭 검수 해보고 수정 해주셨으면 좋겠네요 .),로그인 화면 튕기면 서 메인 페이지 넘어갑니다 로그인 자체 불가능해서 물건 주문 못 합니다 어플리케이션 버그 발견 됐다며 폰 앱 강제 종료 시키고 나서 재 접속 했는데도 현상 발생 최근 업데이트 이후 현상 일어난 같은데 버그 수정 하셔 야할듯,앱 상품 볼때 로딩 너무 느려요 썸네일 이미지 랑 텍스트 로딩 너무 느리고 한참 기다려도 이미지 아예 뜨거나 텍스트 없이 나오기도 스 크롤 내릴 첫 두어 번은 괜찮은 듯 리다 터져서 PC 홈페이지 접속 해서 상품 봅니다 한두 아닙니다 개발자 랑 관리자 는 본인 폰 앱 확인 해보는지 ?,꽤 상당 기간 이미지 파일 깨져서 나오지가 상품 상세 페이지 보이지 공백 보입니다 방금 앱 업데이트 했는데도 마찬가지 특히 패션 상품 은 옷 핏 상세 치수 소재 확인 해야 하는데 매우 불편해서 구매 전환 이루어지지가 않네요 해당 부분 스크린 캡처 해 놓았는데 사진 첨부 곳 없어 증상 보여 드리지 못 하는게 안타깝네요 최대한 빨리 개선 해 주세요,220927 안드로이드 버전 12 앱 은 최신 버전 로그인 하려고 캐시 버그 발생 보인다고 얼럿뜨 삭제 앱 시동 하여도 동일 현상 재현 됩니다 모바일 웹 에서는 정상 카카오 톡 알림 톡 통해 앱 동시 앱 종료 앱 시동 했을 재현 됩니다,가장 애용 사이 트입니다 종종 판매 자가 타 사이트 동시 제품 올려서 재고 파악 제대로 되지 않아 주문 결제 연락 서 품절 됐다고 하는데 황당한 몇번 있었네요 재발 방지 방법 은 없는걸 까요 ? 불량 교환 맞 교환 가능했음 좋겠어요 반품 검수 배송 받기까지 너무 걸려요 불량 이라 고객 한테 불편 줬음 반품 교환 땐 배송 간편해야 않나요 ? 경험 의한 건의 사항,구매 앱 는 너무 어려워서 구매 못 있는데 는 앱 통 해야만 여러가지 혜택 주어진다 는 죠 나이 은 스마트 폰 기능 사용 할수 없어요 반 전화 구매 혜택 주어진다고 ? ( 나이 제한 : 65 세 또는 79 세 ) 은 전화 구매 혜택 좋을것 같은데 .......,원래 편의 성과 다양한 혜택 덕분 좋아하던 어플 이었습니다 뉴스 보는 중간 중간 의지 다르게 실행 될 마다 떨어지는 호감 는 기존 장점 잊게 만들고 지워 버릴 없게 만드는 군요 광고 의존 하기보다 쇼핑몰 본연 역할 충실하시길,싸 이즈 는 치수 작은 걸 구입 하세요 품 넉 넉 합니다 화이트 특히 완죤 버핏 이라 66 인데 88 맞을듯 부 해보이는 ?! 올여름 너무 더워 날까 했는데 재질 달라붙지 품 넉넉해서 좋을듯 싶어요 고민 했지만 가격 저렴하고 블랙 ㆍ 블루 블라우스 이뻐서요 특히 더운게 너무 싫어서 시원하게 입으려,로그 인할 마다 비번 새로 설정 해야하는거죠 ? 열 번은 바꿨는데 계속 틀리다고나옵니다 뭐 가문 제입 니까 새로 설정 는 비번 설정 하려면 현재 비번 같다고 뜨고 몇번 확인 계속 틀리다고 나오고 로그 인할 마다 이러는 건지 밑 리뷰 보니 저만 그런것 같지는 않아 큰데 오류 수정 않는지 ... 짜증 넘어서 화가 납니다 어쩌다 로그인 되도 로그인 하려면 비번 틀리다고 나오고 무한 반복 이네 !!! 계시는 겁 니까 ??!!,페북 하다가 불편해서 왔네요 뉴스 기사 볼려 배 보다 배꼽 크다고 기사 보지 못 광고 크게 뜨고 ... x 정확하게 눌러도 무조건 CJ 설치 사이트 넘어가고 꼼수 장난 아니네요 광고 좋지만 기사 가릴 " 광고 클릭 못 " 광고 는 없었으면 좋겠습니다,솔직히 요즘 웹쇼핑 어플 매우 뒤 떨어진다고 한다 1 앱 튕김 심함 이미지 로딩 있음 검색 똑바로 됨 어플 돌아가는 속도 부드럽지 않아 시스템 대충 만들었다 느껴짐 2 꼬박꼬박 붙는 배송비 3 동 제품 인데 타사 사이트 비해 꼭 비쌈 ( 싼 본 없음 😓 ) 4 쿠폰 적용 올 cj 포인트 많이 모아서 생일 쿠폰 주길래 깔았으나 쿠폰 적용 상품 극 소수 뭔 없어서 쿠폰 사용 못 함 ...;; 포인트 쿠폰 막 써서 사는 값 사이트 사는 값 보다 동 품일 비싸면 필요 있나요 ? 너무 뒤 떨어집니다,가격 대 설정 하는거 어렵게 만들어놨어요 ? 움직여도 금액 많이 올라가 버려서 세밀 하게 원하는 가격 대 도저히 맞출 수가 없습니다 그냥 직접 입력 는걸 만들어주세요 사용자 편의 성 고려 너무 못 하네요,목 부분 시 보리 ?? 처리 된 옷 별로 없는데 밑단 어울려 캐 주얼 활용 할것 같습니다 컬러 는 검정 가죽 쟈켓 있다면 색상 도전 좋을듯 합니다 ~^^,홈쇼핑 신발 샀는데 사이즈 업체 측 실수 잘못 배송 반품 신청 했는데 일주일 되도 물건 가져가서 가져가 달라 확인 전화 해서 이틀 뒤 가져감 ᆢ 다시는 씨제이 쇼핑 이용 하고싶지 않음,쿠폰 사용 조건 완화 해줬으면 합니다 가입 할인 쿠폰 준다길래 가입 했더니 5만원 사용 가능 구매 하려는 제품 은 49,900원 ... 쿠폰 사용 불가 이럴 알았으면 가입 했는지 ;; ㅎㅎ 쿠폰 쓴다고 걸 추가 했다가는 배 보다 배꼽 커지네요,평소 66 입는데 55 교환 어깨 부분 은 맞는데 허리 밑 으로는 큰듯 해서 교환 했더니 55 사이즈 맞네요 스판기 있어서 불편하지도 교환 하기를 옷 예뻐요,택배 적정 시기 보내주셨고 포근하니 부러운 색상 이라 맘 들어요 작게 만들어 주었으면 좋겠어요,뺑뺑 는 있는대로 다 돌려놓고는 대상 아니라네 이벤트 는 관리자 끼리 하시길 남아돌지 않아서,처음 사용 나서 전체 쫀쫀해 지는 느낌 들었어요 조작 법도 간단하고 쭉 사용 해 봐야 겠어요,가장 눈 띠 는 목 부분 끈어진것 불량 인데 성의 없이 검사 제대로 보낸 물건 성의 없이 매출 신경 쓰시는것 아닌가요 ?!!! CJ 홈쇼핑 기분 좋은 쇼핑 할수있어으면 좋겠습니다 ~~^^,색감 좋구 가볍구요 보다도 수납 공간 넉넉해서 다 쳐놓구 가방 들고 다닙니다 적극 추천 합니다,홈쇼핑 이라기 엔 너무 훌륭하고 엣지 있는 상품 가득해요 CJ 상품 은 절대 믿고 만족합니다 ♡,갑자기 앱 실행 안됨 메인 화면 까지는 들어가 지는데 상품 클릭 면 하얀 화면 끝 검색 하려 돋보기 클릭 그냥 하얀 화면 끝 지웠다 깔아도 며칠 째 메인 화면 스크롤 가능하네요 무것 안되요 검색 불가능 걸 까요,몸 많이 건조하고 가려운 증상 좋은 같인요 향 은은하게 솔솔 풍겨 향수 는 필요없을것 같아요,필터 링 좀더 세밀 하게 바꾸었으면 좋겠습니다 상품 은 만족,오늘 처음 사용 했는데 얼굴 밝고 업 된것 같아요 비싸게 산 열심히 관리 해서 예뻐지고싶네요,원래 머릿수 적은 편 인데 나이 먹으면 적어지고 피부 탄력 떨어지는게 일반 인데 는 콜라겐 꾸준히 먹어서 인지 피부 좋아지고 모발 풍 성해진 걸 스스로 느껴요 완전 강추,엄청 빠른 배송 보들보들하니 좋고 씻고 사용 된다고 하네요 킹 사서 크게 사용 할려고 샀어요 포토 리뷰 쓰면 퀸 패드 한장 준다는데 엄청 좋은 기횟거 같아요,가볍고 색상 싸이 즈 만족합니다 요즘 날씨 겨울 무난 히 입을듯 합니다 주머니 양쪽 지퍼 없어서 아쉽지만 그러데로 상품 은 맘에듭니 다,FILA 옷 두툼 카라 기모 부드러우며 고급스럽습니다 정사 이즈 배송 빠르고 겨울 기 셔츠 최고,두껍지 않음 착용 감 좋음 보기 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.morphs(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'실용': 22,
#  '제품': 769,
#  '많이': 446,
#  '소개': 57,
#  '돼서': 21,
#  '좋아요': 3260,
#  '근데': 40,
#  '왠지': 10,
#  '노출': 7,
#  '되지': 22,
#  '못': 329,
#  '같아요': 479,
#  '채널': 20,
#  '넘겨야': 1,
#  '만나지는': 1,
#  '느낌': 122,
#  'TV': 19,
#  '보면서': 32,
#  '모바일': 453,
#  '구매': 1077,
#  '라서': 78,
#  '주어지는': 2,
#  '서비스': 79,
#  '는': 651,
#  '비해': 46,
#  '너무': 1372,
#  '제한': 8,
#  '이라는': 16,
#  '별로': 82,
#  '혜택': 296,
#  '느껴지지': 1,
#  '않아요': 50,
#  ',': 14232,
#  '그동안': 15,
#  '블편함': 1,
#  '느꼈었는데': 1,
#  '최근': 26,
#  '이상해요': 3,
#  '상품': 1340,
#  '클릭': 67,
#  '상세': 52,
#  '화면': 250,
#  '내용': 18,
#  '뜨는': 13,
#  '빈번': 3,
#  '장바구니': 42,
#  '넣기': 3,
#  '버튼': 32,
#  '눌러도': 17,
#  '먹통': 22,
#  '많아요': 60,
#  '앱': 1566,
#  '진짜': 209,
#  '버벅댄다는': 1,
#  '받습니다': 1,
#  '결제': 218,
#  '빨리': 148,
#  '넘어갈': 4,
#  '많구요': 6,
#  '업데이트': 277,
#  '안해': 17,
#  '서': 255,
#  '건가': 29,
#  '싶어서': 9,
#  '계속': 424,
#  '체크': 29,
#  '해보는데': 5,
#  '아니고': 48,
#  '엄청': 81,
#  '답답하네요': 8,
#  '해결': 51,
#  '해주세요': 122,
#  '분명히': 5,
#  '실행': 106,
#  '건데': 8,
#  '바로가기': 20,
#  '적용': 68,
#  '안되어서': 7,
#  '(': 57,
#  'vip': 18,
#  '할인': 372,
#  ')': 42,
#  '안되는': 50,
#  '발생': 13,
#  '재실': 2,
#  '행해': 2,
#  '강제': 26,
#  '종료': 38,
#  '폰': 105,
#  '재부팅': 5,
#  '마찬가지': 21,
#  '자체': 56,
#  '삭제': 175,
#  '재': 79,
#  '설치': 308,
#  '해야만': 5,
#  '합니다': 569,
#  '해당': 17,
#  '오류': 190,
#  '수십': 11,
#  '겪다': 1,
#  '보니': 124,
#  '타': 118,
#  '사이트': 92,
#  '광고': 240,
#  '배너': 15,
#  '해': 305,
#  '씨제이': 262,
#  '몰': 231,
#  '했다가': 13,
#  '로는': 16,
#  '에러': 46,
#  '같더군요': 1,
#  '기': 90,
#  '분명': 15,
#  '아니에요': 4,
#  '예전': 41,
#  '기기': 9,
#  '사용': 872,
#  '시': 174,
#  '에도': 127,
#  '동일한': 5,
#  '있었습니다': 2,
#  '이용': 486,
#  '하다가': 34,
#  '실수': 8,
#  '로라': 1,
#  '몰의': 4,
#  '꼭': 128,
#  '걸': 60,
#  '확인': 157,
#  '해왔습니다': 2,
#  '정말': 444,
#  '불편하고': 4,
#  '짜증납니다': 4,
#  '개발': 10,
#  '팀': 7,
#  '검수': 4,
#  '해보고': 24,
#  '수정': 69,
#  '해주셨으면': 4,
#  '좋겠네요': 34,
#  '),': 16,
#  '로그인': 523,
#  '튕기': 11,
#  '면': 184,
#  '메인': 24,
#  '페이지': 90,
#  '넘어갑니다': 4,
#  '불가능해서': 2,
#  '물건': 326,
#  '주문': 683,
#  '어플리케이션': 5,
#  '버그': 15,
#  '발견': 3,
#  '됐다며': 1,
#  '시키고': 3,
#  '나서': 38,
#  '접속': 132,
#  '했는데도': 21,
#  '현상': 17,
#  '이후': 37,
#  '일어난': 1,
#  '같은데': 20,
#  '하셔': 2,
#  '야할듯': 3,
#  '볼때': 10,
#  '로딩': 78,
#  '느려요': 18,
#  '썸네일': 2,
#  '이미지': 27,
#  '랑': 68,
#  '텍스트': 2,
#  '느리고': 28,
#  '한참': 14,
#  '기다려도': 5,
#  '아예': 50,
#  '뜨거나': 2,
#  '없이': 141,
#  '나오기도': 1,
#  '스': 44,
#  '크롤': 17,
#  '내릴': 1,
#  '첫': 62,
#  '두어': 3,
#  '번은': 10,
#  '괜찮은': 30,
#  '듯': 95,
#  '리다': 2,
#  '터져서': 9,
#  'PC': 15,
#  '홈페이지': 15,
#  '해서': 417,
#  '봅니다': 30,
#  '한두': 11,
#  '아닙니다': 7,
#  '개발자': 16,
#  '관리자': 12,
#  '본인': 19,
#  '해보는지': 1,
#  '?,': 240,
#  '꽤': 13,
#  '상당': 1,
#  '기간': 14,
#  '파일': 3,
#  '깨져서': 2,
#  '나오지가': 1,
#  '보이지': 9,
#  '공백': 1,
#  '보입니다': 11,
#  '방금': 13,
#  '특히': 45,
#  '패션': 14,
#  '은': 858,
#  '옷': 220,
#  '핏': 79,
#  '치수': 14,
#  '소재': 59,
#  '해야': 92,
#  '하는데': 190,
#  '매우': 129,
#  '불편해서': 12,
#  '전환': 10,
#  '이루어지지가': 1,
#  '않네요': 28,
#  '부분': 55,
#  '스크린': 3,
#  '캡처': 5,
#  '놓았는데': 1,
#  '사진': 46,
#  '첨부': 12,
#  '곳': 108,
#  '없어': 36,
#  '증상': 5,
#  '보여': 16,
#  '드리지': 1,
#  '하는게': 28,
#  '안타깝네요': 3,
#  '최대한': 2,
#  '개선': 110,
#  '주세요': 35,
#  '220927': 1,
#  '안드로이드': 8,
#  '버전': 33,
#  '12': 3,
#  '최신': 12,
#  '하려고': 49,
#  '캐시': 14,
#  '보인다고': 2,
#  '얼럿뜨': 1,
#  '시동': 2,
#  '하여도': 1,
#  '동일': 8,
#  '재현': 2,
#  '됩니다': 103,
#  '웹': 44,
#  '에서는': 49,
#  '정상': 11,
#  '카카오': 14,
#  '톡': 15,
#  '알림': 124,
#  '통해': 33,
#  '동시': 5,
#  '했을': 13,
#  '가장': 47,
#  '애용': 141,
#  '사이': 19,
#  '트입니다': 3,
#  '종종': 18,
#  '판매': 74,
#  '자가': 1,
#  '올려서': 3,
#  '재고': 21,
#  '파악': 5,
#  '제대로': 54,
#  '않아': 45,
#  '연락': 26,
#  '품절': 39,
#  '됐다고': 14,
#  '황당한': 1,
#  '몇번': 78,
#  '있었네요': 4,
#  '재발': 1,
#  '방지': 3,
#  '방법': 30,
#  '없는걸': 3,
#  '까요': 10,
#  '?': 382,
#  '불량': 5,
#  '교환': 52,
#  '맞': 6,
#  '가능했음': 1,
#  '좋겠어요': 72,
#  '반품': 89,
#  '배송': 793,
#  '받기까지': 1,
#  '걸려요': 5,
#  '이라': 145,
#  '고객': 140,
#  '한테': 44,
#  '불편': 35,
#  '줬음': 2,
#  '땐': 18,
#  '간편해야': 1,
#  '않나요': 6,
#  '경험': 12,
#  '의한': 1,
#  '건의': 4,
#  '사항': 16,
#  '어려워서': 3,
#  '있는데': 57,
#  '통': 22,
#  '여러가지': 41,
#  '주어진다': 1,
#  '죠': 77,
#  '나이': 32,
#  '스마트': 9,
#  '기능': 96,
#  '할수': 156,
#  '없어요': 58,
#  '반': 26,
#  '전화': 50,
#  '주어진다고': 2,
#  ':': 12,
#  '65': 3,
#  '세': 70,
#  '또는': 9,
#  '79': 1,
#  '좋을것': 32,
#  '원래': 13,
#  '편의': 20,
#  '성과': 10,
#  '다양한': 138,
#  '덕분': 24,
#  '좋아하던': 1,
#  '어플': 399,
#  '이었습니다': 4,
#  '뉴스': 6,
#  '보는': 35,
#  '중간': 7,
#  '의지': 2,
#  '다르게': 8,
#  '될': 27,
#  '마다': 114,
#  '떨어지는': 6,
#  '호감': 2,
#  '기존': 34,
#  '장점': 19,
#  '잊게': 1,
#  '만들고': 6,
#  '지워': 10,
#  '버릴': 1,
#  '없게': 7,
#  '만드는': 10,
#  '군요': 2,
#  '의존': 1,
#  '하기보다': 1,
#  '쇼핑몰': 151,
#  '본연': 1,
#  '역할': 1,
#  '충실하시길': 1,
#  '싸': 13,
#  '이즈': 43,
#  '작은': 17,
#  '구입': 412,
#  '하세요': 88,
#  '품': 40,
#  '넉': 4,
#  '화이트': 7,
#  '완죤': 8,
#  '버핏': 2,
#  '66': 11,
#  '인데': 170,
#  '88': 6,
#  '맞을듯': 1,
#  '부': 12,
#  '해보이는': 1,
#  '?!': 9,
#  '올여름': 15,
#  '더워': 3,
#  '날까': 1,
#  '했는데': 355,
#  '재질': 28,
#  '달라붙지': 4,
#  '넉넉해서': 4,
#  '좋을듯': 23,
#  '싶어요': 52,
#  '고민': 53,
#  '했지만': 11,
#  '가격': 489,
#  '저렴하고': 48,
#  '블랙': 19,
#  'ㆍ': 99,
#  '블루': 11,
#  '블라우스': 7,
#  '이뻐서요': 1,
#  '더운게': 1,
#  '싫어서': 1,
#  '시원하게': 23,
#  '입으려': 4,
#  '로그': 33,
#  '인할': 4,
#  '비번': 110,
#  '새로': 41,
#  '설정': 68,
#  '해야하는거죠': 1,
#  '열': 67,
#  '바꿨는데': 3,
#  '틀리다고나옵니다': 1,
#  '뭐': 192,
#  '가문': 2,
#  '제입': 1,
#  '니까': 104,
#  '하려면': 21,
#  '현재': 6,
#  '같다고': 2,
#  '뜨고': 85,
#  '틀리다고': 16,
#  '나오고': 41,
#  '이러는': 4,
#  '건지': 134,
#  '밑': 12,
#  '리뷰': 81,
#  '저만': 20,
#  '그런것': 1,
#  '같지는': 1,
#  '큰데': 3,
#  '않는지': 2,
#  '짜증': 63,
#  '넘어서': 1,
#  '화가': 7,
#  '납니다': 4,
#  '어쩌다': 3,
#  '되도': 5,
#  '무한': 23,
#  '반복': 41,
#  '이네': 129,
#  '!!!': 41,
#  '계시는': 2,
#  '겁': 20,
#  '??!!,': 1,
#  '페북': 5,
#  '왔네요': 8,
#  '기사': 21,
#  '볼려': 3,
#  '배': 20,
#  '보다': 353,
#  '배꼽': 2,
#  '크다고': 1,
#  '보지': 10,
#  '크게': 21,
#  'x': 6,
#  '정확하게': 6,
#  '무조건': 20,
#  'CJ': 316,
#  '넘어가고': 12,
#  '꼼수': 1,
#  '장난': 39,
#  '아니네요': 4,
#  '좋지만': 2,
#  '가릴': 1,
#  '"': 15,
#  '없었으면': 2,
#  '좋겠습니다': 27,
#  '솔직히': 10,
#  '요즘': 109,
#  '웹쇼핑': 2,
#  '뒤': 35,
#  '떨어진다고': 1,
#  '한다': 21,
#  '1': 77,
#  '튕김': 5,
#  '심함': 6,
#  '있음': 33,
#  '검색': 267,
#  '똑바로': 13,
#  '됨': 39,
#  '돌아가는': 1,
#  '속도': 63,
#  '부드럽지': 2,
#  '시스템': 22,
#  '대충': 2,
#  '만들었다': 1,
#  '느껴짐': 1,
#  '2': 55,
#  '꼬박꼬박': 3,
#  '붙는': 4,
#  '배송비': 22,
#  '3': 75,
#  '동': 22,
#  '타사': 12,
#  '비쌈': 4,
#  '싼': 14,
#  '본': 32,
#  '없음': 36,
#  '😓': 1,
#  '4': 36,
#  '쿠폰': 437,
#  '올': 45,
#  'cj': 437,
#  '포인트': 172,
#  '모아서': 4,
#  '생일': 13,
#  '주길래': 2,
#  '깔았으나': 1,
#  '극': 6,
#  '소수': 1,
#  '뭔': 39,
#  '없어서': 52,
#  '함': 118,
#  ';;': 24,
#  '막': 13,
#  '써서': 12,
#  '사는': 31,
#  '값': 17,
#  '품일': 1,
#  '비싸면': 2,
#  '필요': 37,
#  '있나요': 10,
#  '떨어집니다': 2,
#  '대': 128,
#  '하는거': 26,
#  '어렵게': 3,
#  '만들어놨어요': 2,
#  '움직여도': 1,
#  '금액': 26,
#  '올라가': 1,
#  '버려서': 3,
#  '세밀': 3,
#  '하게': 169,
#  '원하는': 48,
#  '도저히': 8,
#  '맞출': 1,
#  '수가': 21,
#  '없습니다': 14,
#  '그냥': 120,
#  '직접': 19,
#  '입력': 64,
#  '는걸': 12,
#  '만들어주세요': 7,
#  '사용자': 29,
#  '성': 110,
#  '고려': 3,
#  '하네요': 116,
#  '목': 21,
#  '보리': 2,
#  '??': 45,
#  '처리': 65,
#  '된': 75,
#  '없는데': 16,
#  '밑단': 3,
#  '어울려': 2,
#  '캐': 6,
#  '주얼': 2,
#  '활용': 37,
#  '할것': 29,
#  '같습니다': 71,
#  '컬러': 14,
#  '검정': 6,
#  '가죽': 7,
#  '쟈켓': 5,
#  '있다면': 8,
#  '색상': 272,
#  '도전': 3,
#  '~^^,': 263,
#  '홈쇼핑': 349,
#  '신발': 22,
#  '샀는데': 26,
#  '사이즈': 129,
#  '업체': 13,
#  '측': 5,
#  '잘못': 23,
#  '신청': 46,
#  '일주일': 13,
#  '가져가서': 2,
#  '가져가': 1,
#  '달라': 17,
#  '이틀': 9,
#  '가져감': 2,
#  'ᆢ': 79,
#  '다시는': 19,
#  '쇼핑': 932,
#  '하고싶지': 1,
#  '않음': 22,
#  '조건': 15,
#  '완화': 3,
#  '해줬으면': 5,
#  '가입': 183,
#  '준다길래': 8,
#  '했더니': 62,
#  '5만원': 8,
#  '가능': 13,
#  '하려는': 2,
#  '49,900원': 1,
#  '불가': 22,
#  '이럴': 3,
#  '알았으면': 1,
#  '했는지': 5,
#  'ㅎㅎ': 187,
#  '쓴다고': 3,
#  '추가': 130,
#  '했다가는': 1,
#  '커지네요': 1,
#  '평소': 55,
#  '입는데': 10,
#  '55': 13,
#  '어깨': 16,
#  '맞는데': 6,
#  '허리': 13,
#  '으로는': 8,
#  '큰듯': 1,
#  '맞네요': 12,
#  '스판기': 2,
#  '있어서': 263,
#  '불편하지도': 2,
#  '하기를': 8,
#  '예뻐요': 155,
#  '택배': 35,
#  '적정': 1,
#  '시기': 8,
#  '보내주셨고': 1,
#  '포근하니': 1,
#  '부러운': 1,
#  '맘': 544,
#  '들어요': 382,
#  '작게': 15,
#  '만들어': 19,
#  '주었으면': 2,
#  '뺑뺑': 3,
#  '있는대로': 1,
#  '다': 605,
#  '돌려놓고는': 1,
#  '대상': 2,
#  '아니라네': 3,
#  '이벤트': 262,
#  '끼리': 2,
#  '하시길': 7,
#  '남아돌지': 1,
#  '않아서': 34,
#  '처음': 173,
#  '전체': 32,
#  '쫀쫀해': 2,
#  '지는': 14,
#  '들었어요': 9,
#  '조작': 6,
#  '법도': 2,
#  '간단하고': 18,
#  '쭉': 20,
#  '봐야': 12,
#  '겠어요': 9,
#  '눈': 47,
#  '띠': 2,
#  '끈어진것': 1,
#  '성의': 4,
#  '검사': 5,
#  '보낸': 1,
#  '매출': 1,
#  '신경': 14,
#  '쓰시는것': 1,
#  '아닌가요': 15,
#  '?!!!': 2,
#  '기분': 141,
#  '좋은': 901,
#  '할수있어으면': 1,
#  '~~^^,': 118,
#  '색감': 24,
#  '좋구': 14,
#  '가볍구요': 1,
#  '보다도': 11,
#  '수납': 4,
#  '공간': 8,
#  '쳐놓구': 1,
#  '가방': 26,
#  '들고': 60,
#  '다닙니다': 3,
#  '적극': 26,
#  '추천': 197,
#  '이라기': 1,
#  '엔': 68,
#  '훌륭하고': 1,
#  '엣지': 13,
#  '있는': 117,
#  '가득해요': 1,
#  '절대': 20,
#  '믿고': 177,
#  '만족합니다': 268,
#  '♡': 119,
#  '갑자기': 54,
#  '안됨': 101,
#  '까지는': 4,
#  '들어가': 21,
#  '지는데': 4,
#  '하얀': 13,
#  '끝': 18,
#  '하려': 25,
#  '돋보기': 1,
#  '지웠다': 17,
#  '깔아도': 37,
#  '며칠': 30,
#  '째': 83,
#  '가능하네요': 4,
#  '무것': 1,
#  '안되요': 58,
#  '불가능': 2,
#  '몸': 34,
#  '건조하고': 2,
#  '가려운': 1,
#  '같인요': 1,
#  '향': 51,
#  '은은하게': 3,
#  '솔솔': 2,
#  '풍겨': 1,
#  '향수': 4,
#  '필요없을것': 1,
#  '필터': 8,
#  '링': 3,
#  '좀더': 35,
#  '바꾸었으면': 1,
#  '만족': 165,
#  '오늘': 124,
#  '얼굴': 65,
#  '밝고': 3,
#  '업': 27,
#  '된것': 3,
#  '비싸게': 4,
#  '산': 15,
#  '열심히': 26,
#  '관리': 76,
#  '예뻐지고싶네요': 1,
#  '머릿수': 1,
#  '적은': 4,
#  '편': 43,
#  '먹으면': 2,
#  '적어지고': 2,
#  '피부': 169,
#  '탄력': 23,
#  '떨어지는게': 1,
#  '일반': 10,
#  '콜라겐': 3,
#  '꾸준히': 33,
#  '먹어서': 3,
#  '인지': 42,
#  '좋아지고': 6,
#  '모발': 4,
#  '풍': 19,
#  '성해진': 1,
#  '스스로': 5,
#  '느껴요': 3,
#  '완전': 217,
#  '강추': 81,
#  '빠른': 218,
#  '보들보들하니': 1,
#  '좋고': 289,
#  '씻고': 2,
#  '된다고': 14,
#  '킹': 3,
#  '사서': 27,
#  '할려고': 19,
#  '샀어요': 56,
#  '포토': 3,
#  '쓰면': 21,
#  '퀸': 2,
#  '패드': 2,
#  '한장': 4,
#  '준다는데': 1,
#  '기횟거': 1,
#  '가볍고': 98,
#  '싸이': 18,
#  '즈': 30,
#  '날씨': 23,
#  '겨울': 55,
#  '무난': 8,
#  '히': 15,
#  '입을듯': 7,
#  '주머니': 3,
#  '양쪽': 1,
#  '지퍼': 2,
#  '아쉽지만': 4,
#  '그러데로': 1,
#  '맘에듭': 16,
#  '니': 305,
#  'FILA': 1,
#  '두툼': 3,
#  '카라': 8,
#  '기모': 2,
#  '부드러우며': 1,
#  '고급스럽습니다': 3,
#  '정사': 29,
#  '빠르고': 302,
#  '셔츠': 6,
#  '최고': 304,
#  '두껍지': 2,
#  '착용': 198,
#  '감': 150,
#  '좋음': 99,
#  '보기': 217,
#  '싸구려': 3,
#  '안남': 2,
#  '키': 36,
#  '신분': 10,
#  '하시는게': 2,
#  '좋을거': 12,
#  '이유': 43,
#  '기장': 9,
#  '살짝': 13,
#  '짧은듯': 2,
#  '개인': 13,
#  '차': 15,
#  '있을수': 1,
#  '입어보고': 16,
#  '후기': 24,
#  '한번': 139,
#  '올려': 7,
#  '보겠습니다': 4,
#  '아주': 337,
#  '포근하고': 12,
#  '좋은데': 42,
#  '종류': 24,
#  '간': 18,
#  '차이': 7,
#  '단': 19,
#  '일색': 2,
#  '같고': 19,
#  '브랜드': 41,
#  '로고': 4,
#  '없으면': 9,
#  '시장': 3,
#  '선명하고': 2,
#  '이쁘네요': 29,
#  '조아': 34,
#  '져요': 8,
#  '이뻐서': 21,
#  '화사해질': 1,
#  '둘러보다': 1,
#  '1만원': 6,
#  '준다는': 3,
#  '링크': 18,
#  '다운': 201,
#  '받았는데': 34,
#  '주네': 11,
#  '마케팅': 4,
#  '수법': 1,
#  '사기꾼': 16,
#  '일부': 6,
#  '특': 42,
#  '화': 30,
#  '우수하다고': 1,
#  '되며': 3,
#  '방송': 336,
#  '되는듯': 2,
#  '하여': 33,
#  '장만': 11,
#  '있었는데': 22,
#  '마침': 15,
#  '여러': 79,
#  '망설임': 5,
#  '좋아졌네요': 7,
#  '고급': 33,
#  '스럽고': 5,
#  '원단': 38,
#  '검정색': 3,
#  '할꺼예요': 2,
#  '디자인': 278,
#  '마음': 284,
#  '고급스러': 4,
#  '움': 30,
#  '베이지': 6,
#  '비교': 48,
#  '한가지': 13,
#  '딸도': 5,
#  '예쁘다고': 6,
#  '둘다': 5,
#  '하기로': 2,
#  '에든': 3,
#  '코디': 5,
#  '하기가': 48,
#  '강력': 14,
#  '무상': 2,
#  '있으니': 19,
#  '편하게': 188,
#  '가능하게': 3,
#  '되네요': 140,
#  '입긴': 2,
#  '냉감': 1,
#  '추울듯': 1,
#  '톡톡하고': 1,
#  '드럽고': 3,
#  '예쁨니다': 1,
#  '봄': 30,
#  '입어': 11,
#  '만하': 19,
#  '업뎃해': 4,
#  '껐다': 4,
#  '켜도': 5,
#  '깔았다': 6,
#  '지워도': 10,
#  '그래요': 23,
#  '듀얼': 4,
#  '쇼닉': 1,
#  '맥시': 5,
#  '엄': 4,
#  '한지': 13,
#  '되었는데': 7,
#  '확실히': 24,
#  '좋아지는거': 1,
#  '느끼겠어요': 1,
#  '매일': 83,
#  '있어요': 227,
#  '잘사': 24,
#  '용할것': 1,
#  '쌀쌀한': 3,
#  '누룽지': 1,
#  '그릇': 9,
#  '일듯': 4,
#  '모양': 14,
#  '예쁘고': 107,
#  '묵직하니': 1,
#  '토프': 1,
#  '그레이': 8,
#  '이쁘고': 66,
#  '가벼워서': 24,
#  '입고': 69,
#  '다녀요': 3,
#  '도마': 18,
#  '위생': 3,
#  '원목': 2,
#  '가성': 74,
#  '비': 98,
#  '좋게': 26,
#  '빨라': 20,
#  '무게': 6,
#  '있어': 213,
#  '위주': 5,
#  '먼저': 21,
#  '베스트': 6,
#  '스타일': 108,
#  '들지만': 4,
#  '입어보구': 2,
#  '하려구요': 10,
#  '편해서': 71,
#  '부드럽고': 71,
#  '좋아서': 97,
#  '렌': 2,
#  '시아': 1,
#  '건조해지는데': 1,
#  '했': 14,
#  '읍': 44,
#  '받고': 83,
#  '타이': 4,
#  '트업': 1,
#  '이마': 4,
#  '라인업': 1,
#  '됬어요': 3,
#  '진': 12,
#  '부피': 1,
#  '포근해서': 4,
#  '딱이네요': 12,
#  '신속하고': 5,
#  '제일': 65,
#  '홈': 39,
#  '긴급하게': 1,
#  '햇': 72,
#  '마감': 2,
#  '박': 4,
#  'ㅠㅠ': 88,
#  '서두르지': 1,
#  '안으면': 1,
#  '놓쳐요': 1,
#  '딴': 6,
#  '킵킵': 1,
#  'OK': 1,
#  '청바지': 7,
#  '편안함': 12,
#  '들어서': 28,
#  '했습니다': 80,
#  '벌은': 1,
#  '벌': 14,
#  '세트': 42,
#  '낮췄으면': 1,
#  '바람': 8,
#  '간혹': 8,
#  '쇼': 28,
#  '호스트': 27,
#  '과대': 3,
#  '액션': 1,
#  '있기는': 1,
#  '많아서': 109,
#  '사랑': 46,
#  '통화': 14,
#  '너무나': 13,
#  '친절하셔서': 2,
#  '좋아지죠': 1,
#  '칭찬': 8,
#  '넘': 863,
#  '상태': 30,
#  '멈춰서': 2,
#  '진행': 20,
#  '잦아서': 3,
#  '불편해요': 28,
#  '을해': 11,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='/Library/Fonts/paybooc Bold.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
