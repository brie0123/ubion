# %% [markdown]
# # 리뷰 데이터 수집

# %%
# https://play.google.com/store/apps/details?id=com.musinsa.store&hl=ko-KR

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.musinsa.store",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST,
                      count=50000)

# %%
import numpy as np
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    raw_df.to_csv(f'./data/{name}_raw.csv',index=False)
    df.to_csv(f'./data/{name}_df.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'musinsa_test')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df.dropna(subset="content",axis=0,inplace=True)

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <18168x5161 sparse matrix of type '<class 'numpy.int64'>'
# 	with 40210 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <18168x5161 sparse matrix of type '<class 'numpy.float64'>'
# 	with 40210 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '인스타 역 시즌 기획전 광고 렉 구경 못 위쪽 카테고리 로딩 뒤쪽 액세서리 구경 클릭 앱 자체 마비 버튼 소용 앱 기획전 검색 옷 무한 로딩 그냥 앱 정상 작동 기획전 보라,애플리케이션 발전 게 결제 부분 체감 부분 가끔 카카오 톡 네이버 베너 마음 코디 확인 이벤트 메인 화면 링크 게 해당 코디 링크 이벤트 메인 화면 해당 아이템 찾기 가끔 마음 옷 게,셀렉 트숍 앱 적립금 옷 카테고리 별로 볼 정말 인터넷 쇼핑 입문 계기 준 앱 몇개 사용 정말 개선 매우 실용 성도 꼭 개선 로딩 속도 와이파이 속도 현저 감 로딩 속도 개선 터치 오류 가끔 터치 아마 기기 오류 수도 상세 페이지 종종 발생 터치 곳 무관 창 터치 부분 오류 발견 개선 정렬 고정 리뷰 순 판매량 순 정렬 순 걸 카테고리 걸 설정 움 개인 별로 고정 정렬 순 마지막 정렬 순 적용 꼭 업데이트 사이즈 추천 작성 후기 사이즈 추천 매우 분류,리프 레쉬 앱 앱 튕깁니 삼성 정책 어플 자체 개선 방안 후기 사진 못 사진 플러스 버튼 응용프로그램 선택 카메라 권한 팝업 계속 카메라 어플 진입,점점 업데이트 이후 버튼 위로 이동 항상 특정 화면 버튼 문제점 리뷰 업데이트 이후 꼭 가다가 부분 점수 뚝 어플 그게 사일,상품 랭킹 전체 페이지 페이지 연령 카테고리 반응 상품 클릭 옵션 작동 삭제 설치 다른사람 증상 리뷰 해결 이용,패션 스토어 어플 최근 활용 최근 어플 로딩 핸드폰 상단 바 이벤트 소식 알람 해당 사항 브랜드 한정 발매 인기 상품 재 해당 공지 소식 이동 어플 가장 최근 종료 화면 그대로 이동 사용자 컨버스 보고 어플 종료 뒤 상단 바 노출 아디다스 인기 상품 재 공지 이전 보고 컨 버스 상품 페이지 이동 오류 갑자기 발생 요것 진짜 퍼펙트 완벽 어플 자체,업데이트 편리 성은 퇴화 느낌 이전 눈 랭킹 자주 기능 버튼 볼 파격 쿠폰 뭐 사용 맘 제품 그냥 상품 사라 건가 예전 사가,업데이트 후기 작성 짐 원래 후기 작성 카메라 실행 갤러리 실행 선택 갤러리 선택 선택 사진 얼굴 앱 편집 기능 편집 사진 기능 이해 불가,호감 순 하트 나열 젠 판매량 광고 상품 랭킹 위 렀습 평소 랭킹 순 추천 순은 걸렀는데 최근 스포츠 랭킹 한번 아쉬움 항상 애용 반영 참고,신사 여러 제품 한번 옷 보고 비교 구매 첫 화면 구매 창 보이지 사항 신경 개선,편의 아주 사용 화면 거래 옷 여러가지 패션 의류 스킨 로션 질 제품 자주 이용 아이템 구성 눈 쇼핑 매우 계속 이용 감사,옷 쇼핑 앱 앱 후기 작성 과정 카메라 앱 앱 앱 사이 오류 파일 사진 올린다 앱 자체 사진 수정 사진 자체 검정 오류 먼저 사진 수정 올린다 수정 사진 거 정말 앱 하나로 교 더욱 앱 거,스타일 탭 하트 기능 사진 후루룩 사진 클릭 위치 위 계속 인스타 사진 꾹 사진 크게 하트 기능,패션 스토어 어플 최근 활용 최근 어플 로딩 패션 트 레드 성향 스타일 제안 옷 선택 도움 적립금 쿠폰 사용 할인 단 구입 제품 세용 마켓 쇼핑몰,실 기능 정말 자주 사용 앱 앱 월간 사용 유저 로서 추가 기능 후기 옵션 별로 볼 상품 여러 옵션 구매 옵션 후기 볼 기능 후기 필터 선택 키별 필터 몸무게 별 필터 선택 선택 부분,브랜드 폭 매우 참여 이벤트 일리 추천 아이템 조합 추천 기능 개인 도매 스틱 브랜드 제외 브랜드 부재 패 진입 장벽 높이 평가 이름,강추 패션 앱 이유 모델 옷 과장 별로 패션 앱 옷 설명 카테고리 한눈 옷 퀄리티 옷 모자 장갑 메이크업 장식 템 혜택 이벤트 쿠폰 단점 배송 주일 주일 수도 쿠폰 정작 맘 옷 사용 폭 굿굿,웹사이트 대체 로그아웃 버튼 마이 하단 정말 혁신 기능 사용자 제공 웹 앱 터 부분 보이지 로그아웃 버튼 설정 한참 항상 업데이트 업데이트 핀트 어긋나게 로그아웃 버튼 뭐 로그아웃 빈도 예전 설정 로그아웃 버튼 설정 로그아웃 버튼 한참 사용자 장난 치 로그아웃 위치 명시 해주시,예전 업데이트 뒤 뒤 가기 오류 가장 최근 버전 해결 앱 현상 폰 항상 처음 군데 갤럭시 화면 하단 뒤 가기 터치 인식 뒤 화면 위 모양 뒤 가기 버튼 마찬가지 정말 해결 방법,앱 업뎃전 기능 후기 작성 시 카메라 갤러리 회전 편집 기능 문의 폰 어플 삭제 마찬가지 정말 구글 글 안드로이드 버전 확인 리부팅 삭제 재 설치 반복 마찬가지,브랜드 검색 대부분 주문 반품 교환 반품 교환 처음 앱 검색 버튼 밑 위 추천 랭킹,업데이트 이후 창 상품 뒤 가기 곳 맨 위로 화면 볼때 일일 아래 업데이트 이후 기능,앱 자체 랙 폰 종 나름 최신기종 앱 사용 시 램 용량 최적화 상태 웹사이트 앱 완전 최악 키 보드 렉 앱 랙 앱,폴더 기능 가요 애 바 아예 컴퓨터 폴더 폴더 폴더 느낌 버그 결벽증 진짜 폴더 기능 업그레이드,상품 가격 구매 자주 애용 스타일 후기 상품 사진 후기 필터 링 성별 키 몸무게 보고 후기 볼 사이즈 추천 검색 표현 아쉬움,앱 블프때 특가 상품 무 통장 입금 결제 후기 사이트 가보 정가 표기 할인 율 주문 취소 취소 사유 선택 게 변심 정가 확인,패션 트 레드 성향 스타일 제안 옷 선택 도움 적립금 쿠폰 사용 할인 단 구입 사가 정 할인 율 할인 쿠폰 적용 일부 상품 할인 쿠폰 사용 제외 보유 적립금 사용 제외 적립금 제외,제발 오류 랭킹 검색 옷 뒤 가기 먹통 이해 수가 인원 사용 어플 대면 진짜 복 치질 뒤 가기 아예 먹통 어플 수고 옷 상세 마다 껏 어플 고치 고객 개선 진짜,사용자 커뮤니티 리뷰 옷 살때 비교 리뷰 미션 참여 포인트 옷 수도 브랜드 리뷰 제품 제대로 제품 정보,최근 건 결제 실 소비 액 연말 결산 브랜드 공식 홈페이지 컨셉 타 플랫폼 결제 금액 배 가까이 여러 브랜드 입점 건 과도 상품 찾기 스포츠 볼캡 사고 카테고리 스포츠 모자 여성 라바 퀄리티 니즈 의류 컨셉 스타일 타 플랫폼 손 거 사용 빈도 점점 유 신사 안녕,상품 여러 연령 층 사용 의류 세탁,물품 어플 편의 이벤트 쿠폰 제품 가격 뉴비 혜택 모음 어플 자체 기능 정말 배송 제품 사진 가격 대비 퀄리티 확인 글 현재,사고 품목 옷 휜색 셔츠 검색 가격 별로 정보 볼 구매 계속 거,란 세부 카테고리 로만 분류 업뎃 이전 란 처음 화면 분류 구분 분류 하위 분류 식 분류,사용자 과실 앱 오류로 이벤트 진행 적립금 못 문의 복구 보상 이벤트 종료 처리,옷 기능 화면 전환,업뎃만하 쓰레기 앱 옷 사고 시스템 무진장 블프하 버러지 터치 옷살때 계산기 앱 자꾸 창 앱 진짜 억 제대로 함 업뎃할거 제대로 해,할인 율 순 가격 순 가격 순 보기 이해 거 제발 한번 할인 율 가격 순,후기 사진 앱 편집 기능 자체 조정,네이버 제품 스타 일링 사진 정말 거,상품 배송 고객 처 대처 엉망 진창 뭐 피해 대한 보상 상품 계속 잘못 재고 후속 조취 하든 장난 치,브랜드 신상 쇼케이스 룩북 접근 함 앱 키 랭킹 추천 옷 관심,리프 레쉬 폰 램 버전 게임 리프 레쉬 폰 앱 근본 리프 레쉬 이전 페이지 페이지 뭐임 개발자 실 사용 쇼핑 화장실 쇼핑카트 기분 몇번,결제 갑자기 품절 취소 시스템 품절 결제 결제 취소 하필 이면 주말 옷 돈 적립금 적립금 못 제한 보상,살짝 로딩 매우 사용 의류 플랫폼 쿠폰 상품,쿠폰 낚시 쿠폰 상품 못 못 쿠폰 상품 사진 확대 글씨 칸 확대 축소 사진 스 크롤 반복 확대 축소 요것 원래,배송 배송 지연 위로 금도 청소년 의류 구매 곳 은근 마땅치 쇼핑 무척,앱 자주 오류 문의 대응,리프 레쉬 심해 어플 메인 화면 돌 아강,스토어 새 제품 아이템 곳 소통,옷 유행 아이템 판매 소비자 온라인쇼핑 앱 옷 패션 강추,종류 여러 브랜드 여러 데이터 자주,어플 결제 참여 장바구니 상품 삭제 어플 최신 휴대폰 소프트웨어 업데이트 최신 상태,그냥 무난 함 거 꽤 이벤트 낚시 뭐 상술 레트로 이벤트 낚시 느낌,최근 업데이트 역 구매 옷 신발 업데이트,늙은이 이용 제품 정보 화면 기 빨림,배송 빨 쿠폰 자주 주시 감사 제품 가격 쿠폰 쇼핑,옷 살수 여러가지 기능 어플,의류 신발 남성 성용 필터 링 카테고리 관심 상품,출고 지연 미리 도착 예정 한참 뒤 출고 지연 메세지 띡,홈 정상 창 화면 건가 삭제 재 설치,에이 블리 바지 사이즈 찾기 바지,딸 티셔츠 바지 듸자인 심플 고급 지고 편안함 아주,리뷰 사진 어플 업데이트 앱 사진  ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'인스타': 5,
#  '역': 20,
#  '시즌': 4,
#  '기획전': 7,
#  '광고': 150,
#  '렉': 116,
#  '구경': 18,
#  '못': 92,
#  '위쪽': 1,
#  '카테고리': 101,
#  '로딩': 94,
#  '뒤쪽': 1,
#  '액세서리': 1,
#  '클릭': 42,
#  '앱': 1083,
#  '자체': 103,
#  '마비': 1,
#  '버튼': 69,
#  '소용': 2,
#  '검색': 221,
#  '옷': 1451,
#  '무한': 13,
#  '그냥': 265,
#  '정상': 10,
#  '작동': 8,
#  '보라': 2,
#  '애플리케이션': 1,
#  '발전': 25,
#  '게': 67,
#  '결제': 164,
#  '부분': 46,
#  '체감': 3,
#  '가끔': 48,
#  '카카오': 7,
#  '톡': 6,
#  '네이버': 47,
#  '베너': 3,
#  '마음': 62,
#  '코디': 77,
#  '확인': 117,
#  '이벤트': 195,
#  '메인': 39,
#  '화면': 129,
#  '링크': 14,
#  '해당': 30,
#  '아이템': 31,
#  '찾기': 97,
#  '셀렉': 8,
#  '트숍': 3,
#  '적립금': 124,
#  '별로': 285,
#  '볼': 110,
#  '정말': 233,
#  '인터넷': 50,
#  '쇼핑': 349,
#  '입문': 8,
#  '계기': 3,
#  '준': 12,
#  '몇개': 10,
#  '사용': 629,
#  '개선': 94,
#  '매우': 98,
#  '실용': 5,
#  '성도': 4,
#  '꼭': 37,
#  '속도': 53,
#  '와이파이': 13,
#  '현저': 1,
#  '감': 36,
#  '터치': 22,
#  '오류': 156,
#  '아마': 7,
#  '기기': 9,
#  '수도': 10,
#  '상세': 34,
#  '페이지': 112,
#  '종종': 10,
#  '발생': 18,
#  '곳': 194,
#  '무관': 2,
#  '창': 79,
#  '발견': 10,
#  '정렬': 20,
#  '고정': 6,
#  '리뷰': 215,
#  '순': 55,
#  '판매량': 2,
#  '걸': 63,
#  '설정': 39,
#  '움': 45,
#  '개인': 27,
#  '마지막': 6,
#  '적용': 60,
#  '업데이트': 219,
#  '사이즈': 223,
#  '추천': 148,
#  '작성': 35,
#  '후기': 208,
#  '분류': 47,
#  '리프': 7,
#  '레쉬': 7,
#  '튕깁': 1,
#  '삼성': 2,
#  '정책': 21,
#  '어플': 537,
#  '방안': 6,
#  '사진': 105,
#  '플러스': 5,
#  '응용프로그램': 1,
#  '선택': 114,
#  '카메라': 5,
#  '권한': 5,
#  '팝업': 14,
#  '계속': 251,
#  '진입': 6,
#  '점점': 45,
#  '이후': 57,
#  '위로': 12,
#  '이동': 16,
#  '항상': 139,
#  '특정': 19,
#  '문제점': 3,
#  '가다가': 1,
#  '점수': 4,
#  '뚝': 4,
#  '그게': 16,
#  '사일': 1,
#  '상품': 683,
#  '랭킹': 36,
#  '전체': 48,
#  '연령': 9,
#  '반응': 9,
#  '옵션': 17,
#  '삭제': 295,
#  '설치': 81,
#  '다른사람': 5,
#  '증상': 2,
#  '해결': 68,
#  '이용': 392,
#  '패션': 207,
#  '스토어': 71,
#  '최근': 52,
#  '활용': 16,
#  '핸드폰': 17,
#  '상단': 11,
#  '바': 19,
#  '소식': 8,
#  '알람': 23,
#  '사항': 22,
#  '브랜드': 435,
#  '한정': 6,
#  '발매': 1,
#  '인기': 32,
#  '재': 51,
#  '공지': 12,
#  '가장': 49,
#  '종료': 21,
#  '그대로': 14,
#  '사용자': 65,
#  '컨': 5,
#  '버스': 4,
#  '보고': 135,
#  '뒤': 107,
#  '노출': 10,
#  '아디다스': 6,
#  '이전': 23,
#  '갑자기': 73,
#  '요것': 2,
#  '진짜': 310,
#  '퍼펙트': 1,
#  '완벽': 6,
#  '편리': 12,
#  '성은': 5,
#  '퇴화': 9,
#  '느낌': 64,
#  '눈': 38,
#  '자주': 189,
#  '기능': 142,
#  '파격': 7,
#  '쿠폰': 644,
#  '뭐': 221,
#  '맘': 92,
#  '제품': 442,
#  '사라': 14,
#  '건가': 47,
#  '예전': 63,
#  '사가': 70,
#  '짐': 26,
#  '원래': 33,
#  '실행': 35,
#  '갤러리': 9,
#  '얼굴': 6,
#  '편집': 38,
#  '이해': 35,
#  '불가': 12,
#  '호감': 2,
#  '하트': 11,
#  '나열': 7,
#  '젠': 31,
#  '위': 65,
#  '렀습': 1,
#  '평소': 11,
#  '순은': 3,
#  '걸렀는데': 1,
#  '스포츠': 6,
#  '한번': 106,
#  '아쉬움': 12,
#  '애용': 109,
#  '반영': 10,
#  '참고': 56,
#  '신사': 164,
#  '여러': 68,
#  '비교': 87,
#  '구매': 504,
#  '첫': 21,
#  '보이지': 9,
#  '신경': 24,
#  '편의': 30,
#  '아주': 209,
#  '거래': 11,
#  '여러가지': 45,
#  '의류': 71,
#  '스킨': 1,
#  '로션': 1,
#  '질': 65,
#  '구성': 18,
#  '감사': 16,
#  '과정': 12,
#  '사이': 21,
#  '파일': 4,
#  '올린다': 2,
#  '수정': 44,
#  '검정': 4,
#  '먼저': 9,
#  '거': 273,
#  '하나로': 2,
#  '교': 3,
#  '더욱': 14,
#  '스타일': 129,
#  '탭': 11,
#  '후루룩': 1,
#  '위치': 4,
#  '꾹': 7,
#  '크게': 21,
#  '트': 28,
#  '레드': 2,
#  '성향': 3,
#  '제안': 12,
#  '도움': 53,
#  '할인': 430,
#  '단': 15,
#  '구입': 81,
#  '세용': 2,
#  '마켓': 6,
#  '쇼핑몰': 162,
#  '실': 29,
#  '월간': 1,
#  '유저': 17,
#  '로서': 9,
#  '추가': 47,
#  '필터': 45,
#  '키별': 1,
#  '몸무게': 11,
#  '별': 147,
#  '폭': 26,
#  '참여': 10,
#  '일리': 4,
#  '조합': 3,
#  '도매': 4,
#  '스틱': 3,
#  '제외': 26,
#  '부재': 3,
#  '패': 22,
#  '장벽': 3,
#  '높이': 1,
#  '평가': 14,
#  '이름': 37,
#  '강추': 12,
#  '이유': 101,
#  '모델': 36,
#  '과장': 3,
#  '설명': 57,
#  '한눈': 44,
#  '퀄리티': 47,
#  '모자': 8,
#  '장갑': 2,
#  '메이크업': 2,
#  '장식': 2,
#  '템': 17,
#  '혜택': 112,
#  '단점': 14,
#  '배송': 536,
#  '주일': 8,
#  '정작': 11,
#  '굿굿': 168,
#  '웹사이트': 14,
#  '대체': 33,
#  '로그아웃': 32,
#  '마이': 13,
#  '하단': 14,
#  '혁신': 5,
#  '제공': 22,
#  '웹': 37,
#  '터': 11,
#  '한참': 12,
#  '핀트': 1,
#  '어긋나게': 1,
#  '빈도': 4,
#  '장난': 35,
#  '치': 19,
#  '명시': 3,
#  '해주시': 11,
#  '가기': 66,
#  '버전': 31,
#  '현상': 10,
#  '폰': 57,
#  '처음': 133,
#  '군데': 3,
#  '갤럭시': 17,
#  '인식': 5,
#  '모양': 25,
#  '마찬가지': 11,
#  '방법': 20,
#  '업뎃전': 2,
#  '시': 65,
#  '회전': 5,
#  '문의': 193,
#  '구글': 8,
#  '글': 46,
#  '안드로이드': 9,
#  '리부팅': 1,
#  '반복': 29,
#  '대부분': 23,
#  '주문': 111,
#  '반품': 87,
#  '교환': 124,
#  '밑': 11,
#  '맨': 10,
#  '볼때': 18,
#  '일일': 5,
#  '아래': 13,
#  '랙': 5,
#  '종': 4,
#  '나름': 23,
#  '최신기종': 1,
#  '램': 2,
#  '용량': 5,
#  '최적화': 40,
#  '상태': 31,
#  '완전': 52,
#  '최악': 144,
#  '키': 41,
#  '보드': 3,
#  '폴더': 11,
#  '가요': 57,
#  '애': 28,
#  '아예': 33,
#  '컴퓨터': 7,
#  '버그': 26,
#  '결벽증': 1,
#  '업그레이드': 1,
#  '가격': 374,
#  '링': 16,
#  '성별': 44,
#  '표현': 21,
#  '블프때': 4,
#  '특': 19,
#  '무': 72,
#  '통장': 10,
#  '입금': 28,
#  '사이트': 144,
#  '가보': 3,
#  '정가': 9,
#  '표기': 8,
#  '율': 20,
#  '취소': 60,
#  '사유': 3,
#  '변심': 3,
#  '정': 18,
#  '일부': 6,
#  '보유': 3,
#  '제발': 83,
#  '먹통': 13,
#  '수가': 37,
#  '인원': 4,
#  '대면': 1,
#  '복': 19,
#  '치질': 1,
#  '수고': 62,
#  '마다': 6,
#  '껏': 8,
#  '고치': 8,
#  '고객': 311,
#  '커뮤니티': 16,
#  '살때': 22,
#  '미션': 4,
#  '포인트': 63,
#  '제대로': 79,
#  '정보': 113,
#  '건': 73,
#  '소비': 14,
#  '액': 1,
#  '연말': 1,
#  '결산': 1,
#  '공식': 12,
#  '홈페이지': 23,
#  '컨셉': 8,
#  '타': 26,
#  '플랫폼': 41,
#  '금액': 14,
#  '배': 23,
#  '가까이': 8,
#  '입점': 28,
#  '과도': 1,
#  '볼캡': 1,
#  '사고': 50,
#  '여성': 117,
#  '라바': 1,
#  '손': 33,
#  '유': 17,
#  '안녕': 14,
#  '층': 61,
#  '세탁': 4,
#  '물품': 25,
#  '뉴비': 4,
#  '모음': 3,
#  '대비': 13,
#  '현재': 27,
#  '품목': 25,
#  '휜색': 1,
#  '셔츠': 9,
#  '란': 16,
#  '세부': 4,
#  '로만': 13,
#  '업뎃': 40,
#  '구분': 18,
#  '하위': 3,
#  '식': 37,
#  '과실': 3,
#  '오류로': 6,
#  '진행': 26,
#  '복구': 5,
#  '보상': 11,
#  '처리': 118,
#  '전환': 15,
#  '만하': 12,
#  '쓰레기': 110,
#  '시스템': 64,
#  '무진장': 8,
#  '블프하': 1,
#  '버러지': 4,
#  '옷살때': 22,
#  '계산기': 5,
#  '자꾸': 105,
#  '억': 1,
#  '함': 142,
#  '업뎃할거': 1,
#  '해': 181,
#  '보기': 190,
#  '조정': 2,
#  '스타': 24,
#  '일링': 14,
#  '처': 12,
#  '대처': 60,
#  '엉망': 17,
#  '진창': 1,
#  '피해': 5,
#  '대한': 62,
#  '잘못': 30,
#  '재고': 48,
#  '후속': 9,
#  '조취': 1,
#  '하든': 3,
#  '신상': 15,
#  '쇼케이스': 5,
#  '룩북': 10,
#  '접근': 3,
#  '관심': 43,
#  '게임': 7,
#  '근본': 6,
#  '뭐임': 2,
#  '개발자': 23,
#  '화장실': 2,
#  '쇼핑카트': 1,
#  '기분': 23,
#  '몇번': 23,
#  '품절': 59,
#  '하필': 2,
#  '이면': 14,
#  '주말': 19,
#  '돈': 165,
#  '제한': 21,
#  '살짝': 18,
#  '낚시': 13,
#  '확대': 7,
#  '글씨': 3,
#  '칸': 8,
#  '축소': 3,
#  '스': 31,
#  '크롤': 25,
#  '지연': 31,
#  '금도': 2,
#  '청소년': 3,
#  '은근': 6,
#  '마땅치': 1,
#  '무척': 3,
#  '대응': 51,
#  '심해': 16,
#  '돌': 2,
#  '아강': 1,
#  '새': 5,
#  '소통': 8,
#  '유행': 15,
#  '판매': 62,
#  '소비자': 110,
#  '온라인쇼핑': 5,
#  '종류': 105,
#  '데이터': 17,
#  '장바구니': 59,
#  '최신': 19,
#  '휴대폰': 21,
#  '소프트웨어': 2,
#  '무난': 35,
#  '꽤': 21,
#  '상술': 3,
#  '레트로': 1,
#  '신발': 40,
#  '늙은이': 2,
#  '기': 23,
#  '빨림': 1,
#  '빨': 28,
#  '주시': 11,
#  '살수': 51,
#  '남성': 177,
#  '성용': 4,
#  '출고': 50,
#  '미리': 8,
#  '도착': 24,
#  '예정': 19,
#  '메세지': 4,
#  '띡': 2,
#  '홈': 37,
#  '에이': 9,
#  '블리': 4,
#  '바지': 34,
#  '딸': 9,
#  '티셔츠': 9,
#  '듸자': 1,
#  '심플': 9,
#  '고급': 5,
#  '지고': 2,
#  '편안함': 2,
#  '직관': 39,
#  '방향': 8,
#  '시절': 7,
#  '비': 112,
#  '차이': 14,
#  '역시': 87,
#  '항목': 5,
#  '반대': 6,
#  '흰색': 4,
#  '위주': 16,
#  '컬러링': 1,
#  '피로': 3,
#  '배터리': 2,
#  '액정': 1,
#  '수명': 1,
#  '디자인': 74,
#  '레이아웃': 2,
#  '친': 10,
#  '컨텐츠': 10,
#  '배열': 2,
#  '낭비': 3,
#  '찜': 6,
#  '필수': 17,
#  '구석': 1,
#  '진': 10,
#  '서비스': 99,
#  '중심': 5,
#  '따름': 3,
#  '비율': 6,
#  '날': 34,
#  '갈수록': 16,
#  '이슈': 22,
#  '검색어': 6,
#  '전혀': 18,
#  '사용성': 5,
#  '이미지': 55,
#  '첨부': 5,
#  '거나': 13,
#  '개판': 18,
#  '그거': 27,
#  '반': 5,
#  '발악': 1,
#  '다크': 18,
#  '모드': 21,
#  '변경': 22,
#  '똑바로': 23,
#  '규정': 3,
#  '매크로': 40,
#  '답변': 153,
#  '의미': 12,
#  '연결': 50,
#  '테마': 5,
#  '웹디자인': 5,
#  '좀더': 20,
#  '사만': 30,
#  '곁': 1,
#  '바램': 3,
#  '예시': 2,
#  '트렌디': 15,
#  '베이직': 3,
#  '전략': 4,
#  '의견': 14,
#  '착용': 16,
#  '모든': 47,
#  '물건': 135,
#  '긍정': 1,
#  '배경': 5,
#  '도저히': 5,
#  '끌': 2,
#  '엄슴': 2,
#  '뿌리': 12,
#  '남친': 4,
#  '땜': 3,
#  '가입': 122,
#  '모로': 10,
#  '대서': 5,
#  '뻥튀기': 3,
#  '기침': 1,
#  '평상시': 1,
#  '기간': 13,
#  '소규모': 1,
#  '온라인': 72,
#  '쿠팡': 9,
#  '큐': 3,
#  '레이': 4,
#  '션': 4,
#  '시기': 5,
#  '가성': 83,
#  '품질': 117,
#  '패린': 2,
#  '입': 23,
#  '버퍼링': 12,
#  '켜': 6,
#  '크롭': 1,
#  '모자이크': 1,
#  '득템': 19,
#  '싸구려': 5,
#  '환불': 213,
#  '신청': 48,
#  '깜깜': 1,
#  '무소식': 1,
#  '택배': 81,
#  '직접': 27,
#  '어의': 1,
#  '센터': 67,
#  '듯': 91,
#  '피드백': 13,
#  '기준': 25,
#  '오늘': 39,
#  '사면': 18,
#  '일해': 7,
#  '복불복': 3,
#  '급': 5,
#  '불': 13,
#  '제일': 59,
#  '기장': 3,
#  '옷감': 5,
#  '젤': 14,
#  '막상': 11,
#  '커서': 5,
#  '듬': 6,
#  '체험': 6,
#  '것땜': 1,
#  '요즘': 83,
#  '배달': 10,
#  '빅세일': 1,
#  '대박': 22,
#  '가독성': 12,
#  '골': 10,
#  '최대한': 6,
#  '이제야': 8,
#  '후회': 12,
#  '습': 34,
#  '합리': 29,
#  '관리': 79,
#  '번창': 36,
#  '정리': 64,
#  '에드': 14,
#  '등급': 22,
#  '응원': 26,
#  '헤택': 1,
#  '나용': 2,
#  '가면': 12,
#  '하라': 32,
#  '행사': 22,
#  '아들': 36,
#  '아빠': 6,
#  '싼값': 1,
#  '종합': 2,
#  '굳이': 40,
#  '필요': 30,
#  '상처': 1,
#  '방식': 17,
#  '효율': 3,
#  '색깔': 9,
#  '입력': 41,
#  '구동': 4,
#  '강제': 20,
#  '이건': 27,
#  '초기': 10,
#  '문후': 3,
#  '이틀': 12,
#  '지나': 6,
#  '클라스': 1,
#  '거지': 15,
#  '이용자': 22,
#  '상대': 2,
#  '코': 22,
#  '디도': 11,
#  '카톡': 9,
#  '로그인': 145,
#  '뭘': 30,
#  '가겻': 1,
#  '폭이넖': 1,
#  '폼': 2,
#  '최저': 24,
#  '최상급': 1,
#  '라며': 3,
#  '랍': 3,
#  '관리자': 9,
#  '후드': 14,
#  '티': 34,
#  '연관': 3,
#  '베스트': 6,
#  '산': 15,
#  '밴딩': 1,
#  '청바지': 2,
#  '반쪽': 1,
#  '지속': 9,
#  '무탠': 41,
#  '상점': 2,
#  '조회': 13,
#  '화': 2,
#  '구시대': 3,
#  '핏': 21,
#  '잡고': 4,
#  '등가교환': 1,
#  '갠찮은거': 1,
#  '안전성': 1,
#  '댓글': 42,
#  '주작': 4,
#  '겨울': 7,
#  '폴리스': 1,
#  '반했어': 1,
#  '회원': 144,
#  '시대': 13,
#  '벌': 11,
#  '연락': 45,
#  '옴': 11,
#  '동의': 3,
#  '피': 9,
#  '보임': 6,
#  '봄': 13,
#  '벌써': 13,
#  '거래처': 3,
#  '범위': 4,
#  '숫자': 7,
#  '본인': 37,
#  '재미': 15,
#  '색상': 27,
#  '사정': 3,
#  '개별': 8,
#  '합': 9,
#  '배송비': 40,
#  '배송지': 12,
#  '무게': 3,
#  '부피': 1,
#  '상담': 38,
#  '전화': 44,
#  '수준': 23,
#  '일주일': 31,
#  '장문': 1,
#  '토스': 7,
#  '일부러': 9,
#  '선착순': 7,
#  '며': 3,
#  '마감': 1,
#  '해논': 3,
#  '하자': 9,
#  '마자': 1,
#  '나위': 1,
#  '매장': 8,
#  '방문': 3,
#  '디피': 2,
#  '저렴': 9,
#  '최고': 357,
#  '가겍': 1,
#  '대별': 4,
#  '메뉴': 29,
#  '웃숩': 1,
#  '반송': 9,
#  '대기업': 6,
#  '횡포': 2,
#  '어런': 1,
#  '태': 3,
#  '배사': 1,
#  '선정': 5,
#  '전화번호': 9,
#  '직원': 30,
#  '벽': 2,
#  '임': 122,
#  '빅사': 9,
#  '이즈': 10,
#  '대도': 7,
#  '알림': 64,
#  '허용': 6,
#  '무집': 1,
#  '차단': 8,
#  '응대': 28,
#  '응답': 9,
#  '이주': 2,
#  '접수': 8,
#  '쓰기': 44,
#  '싼마이': 1,
#  '아아': 4,
#  '어케해': 1,
#  '품': 10,
#  '책정': 1,
#  '후려': 1,
#  '치기': 4,
#  '급식': 2,
#  '성인': 4,
#  '소개': 9,
#  '굿': 1391,
#  '제품군': 3,
#  '용이': 6,
#  '혼재': 1,
#  '므': 1,
#  '편': 21,
#  '처럼': 11,
#  '서버': 64,
#  '환경': 6,
#  '요청': 30,
#  '불편': 38,
#  '안보': 19,
#  '스냅': 14,
#  '믹스': 1,
#  '투자': 9,
#  '세월': 3,
#  '혈압': 2,
#  '목끝': 1,
#  '버벅일': 1,
#  '도대체': 19,
#  '플래그': 1,
#  '뮬건': 1,
#  '정신': 26,
#  '의상': 7,
#  '감격': 1,
#  '덕분': 49,
#  '세': 23,
#  '재질': 19,
#  '사서': 16,
#  '폭도': 6,
#  '장기': 1,
#  '평점': 32,
#  '적립': 13,
#  '웹페이지': 11,
#  '꼬아놓': 1,
#  '농락': 4,
#  '두시': 1,
#  '파시': 3,
#  '머리': 17,
#  '호구': 36,
#  '하니': 6,
#  '전보': 5,
#  '위장': 1,
#  '낚시질': 3,
#  '멋대로': 8,
#  '사기': 81,
#  '신고': 4,
#  '코디맵': 3,
#  '즐겨찾기': 2,
#  '만족': 56,
#  '의사': 1,
#  '물어': 2,
#  '릏': 1,
#  '주로': 3,
#  '뎁스': 1,
#  '적도': 6,
#  '스텝': 1,
#  '불만': 21,
#  '젠더': 11,
#  '흐름': 1,
#  '천': 2,
#  '수단': 4,
#  '개뭐': 1,
#  '님들': 5,
#  '뻘': 2,
#  '휴대폰결제': 1,
#  '주민등록': 1,
#  '번호': 42,
#  '더더': 1,
#  '무니': 1,
#  '기존': 21,
#  '표시': 14,
#  '하나요': 19,
#  '접속': 87,
#  '응모': 16,
#  '랜덤': 16,
#  '천명': 2,
#  '회사': 113,
#  '내부': 6,
#  '트래픽': 2,
#  '그동안': 33,
#  '세번': 5,
#  '허리': 2,
#  '숨': 1,
#  '확정': 8,
#  '도해': 1,
#  '대체로': 9,
#  '니트': 2,
#  '뿐': 12,
#  '요한': 7,
#  '목록': 28,
#  '된거': 13,
#  '오른쪽': 1,
#  '겉멋': 1,
#  '영진': 1,
#  '사전': 4,
#  '검토': 2,
#  '픽업': 1,
#  '개수': 3,
#  '불가능': 4,
#  '부티크': 4,
#  '솔드아웃': 9,
#  '계정': 27,
#  '다운': 45,
#  '연예인': 4,
#  '콘서트': 2,
#  '번열': 1,
#  '난리': 4,
#  '테러': 10,
#  '티켓': 1,
#  '예매': 1,
#  '인터파크': 1,
#  '애초': 11,
#  '증설': 1,
#  '유지비': 1,
#  '소리': 16,
#  '신지': 1,
#  '상식': 7,
#  '새로고침': 24,
#  '자동': 40,
#  '고려': 7,
#  '다기': 2,
#  '여자도': 2,
#  '쇼': 33,
#  '저번': 26,
#  '뭔가': 24,
#  '조잡': 4,
#  '골프': 8,
#  '페이': 30,
#  '카드': 86,
#  '크루': 3,
#  '강점': 4,
#  '인지': 12,
#  '기억': 7,
#  '본의': 1,
#  '실수': 51,
#  '번은': 10,
#  '대중': 3,
#  '번의': 1,
#  '의사결정': 2,
#  '자정작용': 1,
#  '결과': 12,
#  '외부': 2,
#  '공개': 3,
#  '분': 41,
#  '대체재': 9,
#  '분야': 1,
#  '특성': 3,
#  '모습': 17,
#  '남': 97,
#  '과거': 3,
#  '다드': 46,
#  '이자': 5,
#  '체헝별': 1,
#  '선호': 4,
#  '고민': 15,
#  '인터페이스': 44,
#  '미형': 1,
#  '천이': 1,
#  '면': 15,
#  '상의': 12,
#  '면도': 1,
#  '결재': 7,
#  '완료': 51,
#  '정품': 12,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='/Library/Fonts/paybooc Bold.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %% [markdown]
# ### tf-idf 기준

# %%
weighted = pd.DataFrame({
    '단어':tf_idf.get_feature_names_out(),
    'tf-idf':tf_idf.sum(axis=0).flat
})

weighted.sort_values('tf-idf',ascending=False).head(5)

cloud_weighted = wc.fit_words(weighted)
cloud_weighted.to_image()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 weighted = pd.DataFrame({
# ----> 2     '단어':tf_idf.get_feature_names_out(),
#       3     'tf-idf':tf_idf.sum(axis=0).flat
#       4 })
#       6 weighted.sort_values('tf-idf',ascending=False).head(5)
#       8 cloud_weighted = wc.fit_words(weighted)
#
# AttributeError: 'csr_matrix' object has no attribute 'get_feature_names_out'
