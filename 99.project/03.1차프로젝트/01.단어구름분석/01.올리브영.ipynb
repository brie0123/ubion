# %% [markdown]
# # 리뷰 데이터 수집

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.oliveyoung",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST)

# %%
import numpy as np
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    raw_df.to_csv(f'./data/{name}_raw.csv',index=False)
    df.to_csv(f'./data/{name}_df.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'oliveyoung_test')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
from kiwipiepy import Kiwi
import re

kiwi = Kiwi()
df['result'] = [kiwi.analyze(value) for value in df['morphs']]
df.head()

noun = re.compile('[N]')

for token, pos, start, end in df['result'][0]:
    if noun.match(pos):
        print(token, pos, start, end)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 10
#       6 df.head()
#       8 noun = re.compile('[N]')
# ---> 10 for token, pos, start, end in df['result'][0]:
#      11     if noun.match(pos):
#      12         print(token, pos, start, end)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.morphs(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '만족합니다 최고 서 세 느리고 느려요 합니다 계쏙 렉 뭐 편해요 못 자주 좋습니다 좋아요 좋고 거 좋네요 좋은데 마다 굳 굿 다 어플 앱 너무 진짜 계속 이 가 은 는 올리브영 면 하면 좋아요 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    dtm_words = cv.get_feature_names_out()
    return dtm, dtm_words

def tf_idf_maker(dtm,dtm_words):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    
    weighted = pd.DataFrame({
    '단어':dtm_words,
    'tf-idf':tf_idf.sum(axis=0).flat
})
    return tf_idf,weighted

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm,dtm_words = dtm_maker(dataFrame)
    
    return dataFrame,dtm,dtm_words

# %%
dataframe = tokenize(df)
dataframe = remove_stop_words(dataframe)
dtm,dtm_words = dtm_maker(dataframe)

# %%
dataframe
# Out:
#                                                 content  score  thumbsUpCount  \
# 0     앱이 너무 느려요.. 터치 밀려서 다른 거 터치되고, 올영페스타 티켓구매 때는 차라...      1              4
# 1     자동로그인되어있는데도 이벤트 참여하려고 할때마다 로그인해야 이용할 수 있다고 계속 ...      1             89
# 2     세일 때마다 서버가 터짐 +수정 업데이트 후 사진 첨부가 불가 그래서 사진 리뷰가 ...      1             92
# 3     7/3 추가: 역시나 느리고 무겁고 그대로... 많은 사용자가 불편을 호소하는 문제...      1            869
# 4     일단 앱이 너무너무 느려요. 뭔 이벤트 한번하면 사이트 터질거같이 로딩이 엄청 오래...      1            131
# ...                                                 ...    ...            ...
# 3124                                               대단해요      5              0
# 3125                                                 Ff      5              0
# 3126                                                 충족      5              1
# 3127                                                 🫶🏻      5              0
# 3128                                               가봤어요      5              0
#
#                       at                                             morphs
# 0    2023-12-27 17:23:45  .. 터치 밀려서 터치 되고 , 올 페스 타 티켓 구매 서버 터져서 페이지 열리는 ...
# 1    2023-09-02 13:27:38  자동 로그인 되어있는데도 이벤트 참여 하려고 로그인 해야 이용 있다고 떠요 . 로그...
# 2    2023-09-19 21:16:32  서버 터짐 + 수정 업데이트 사진 첨부 불가 사진 리뷰 불가하여 크게 불편함 ( 참...
# 3    2022-07-03 19:38:39  7/3 추가 : 역시 무겁고 그대로 ... 사용자 불편 호소 모른 척 하시면서 피드...
# 4    2022-11-16 15:57:16  . 뭔 이벤트 한번 사이트 터질거같이 로딩 엄청 오래 걸리고 , 제품 택배 받아 박...
# ...                  ...                                                ...
# 3124 2020-09-11 23:49:47                                               대단해요
# 3125 2023-06-01 06:56:24                                                 Ff
# 3126 2021-04-01 11:26:50                                                 충족
# 3127 2023-07-17 03:07:43                                                 🫶🏻
# 3128 2023-02-05 15:21:40                                               가봤어요
#
# [3129 rows x 5 columns]

# %%
dtm
# Out:
# <3129x8097 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31688 stored elements in Compressed Sparse Row format>

# %%
tf_idf, weighted = tf_idf_maker(dtm, dtm_words)
tf_idf
# Out:
# <3129x8097 sparse matrix of type '<class 'numpy.float64'>'
# 	with 31688 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(dataframe['morphs'])
doc
# Out:
# '.. 터치 밀려서 터치 되고 , 올 페스 타 티켓 구매 서버 터져서 페이지 열리는 일자 선택 라면 옵션 선택 창 띄워지지도 결산 해보라면서 클릭 돼요 .. 열면 나이 광고 하루 보지 않기라도 넣어 주든가 접속 차로 나와서 잘못 누르게 되네요,자동 로그인 되어있는데도 이벤트 참여 하려고 로그인 해야 이용 있다고 떠요 . 로그인 화면 자동 이동 하겠다면서 이미 로그인 되어있으니 이동 그냥 아무 이벤트 참여 수가 없네요 . 삭제 했다가 깔아도 뿐 . 이벤트 참여 하려고 시도 하다가 화가 나네요 . 이럴거면 자동 로그인 기능 만들어 신 건가 .,서버 터짐 + 수정 업데이트 사진 첨부 불가 사진 리뷰 불가하여 크게 불편함 ( 참고 , 기기 : 갤럭시 노트 9 ) 평소 처럼 사진 리뷰 올리려고 하는데 무의미한 로딩 길어지고 이미지 파일 아예 첨부 되지 않았음 대체 인가 싶어 사진 리뷰 올릴 10 mb 이하 이미지 파일 첨부 라고 하길래 갤러리 사진 파일 용량 약 2 mb 확인 했음 사진 첨부 하여 재시 하려하니 불가함을 확인 하게 됨 몰라 와이파이 5 칸 이어도 일부러 데이터 시도 해봤음에도 전혀 달라지지 무의미한 로딩 미 첨부 됨 1:1 문의 에서도 사진 첨부 하니 하얀 네모 3 뜨더니 첨부 됨 멀쩡히 사진 첨부 재차 확인 . 사진 용량 10 mb 이하임 갤러리 재차 확인 . 조속 히 사진 미 첨부 오류 고쳐주기 바람 + 수정 재업 1:1 문의 넣었는데 답변 오긴 왔으나 아직 관련 내용 확인 중이 라고 함,7/3 추가 : 역시 무겁고 그대로 ... 사용자 불편 호소 모른 척 하시면서 피드백 반영 했다는 건지 의문 이네 . 로딩 시 나오던 광고 없앤 대신 젠 진입 차 팝업 광고 띄워서 실수 클릭 유도 , 정말 이지 이용 사용자 편의 성은 전혀 고려 않은 채 화면 최대한 상품 행사 노출 시키겠다는 집념 느껴집니다 . 에만 올인 하시니 젠 화면 터치 밀려서 엉뚱한게 터치 되기 일쑤 , 상하 스크롤 멋대로 좌우 스크롤 빈번 해서 쓰면 쓸수록 스트레스 커지네요 . 첫 화면 오늘 드림 강조 하느라 상단 메뉴 가리는 불편하고요 . 덧붙여서 리뷰 답변 선택 하시는군요 . 심플 함 미학 까진 바라지 않으니 UI / UX 개선 이라도 관심 가져 주시 좋겠습니다 . 가볍고 편리해서 쓰고 싶어지는 만들어주세요 . 부탁드립니다 .,. 뭔 이벤트 한번 사이트 터질거같이 로딩 엄청 오래 걸리고 , 제품 택배 받아 박스 구겨져있어요 . 아예 박스 정상 직육면체 기대도 안되고 , 제품 기스 나있는거는 기본 옵션 . 택배 로는 절대 시키면 안되고 그나마 오늘 드림 시키는게 덜합니다 ;; 주변 려면 오래 가야 해서 어쩔 없이 깔긴 했는데 ;; 별로 ;;,갤럭시 z 플립 안드로이드 버전 11 사용 인데 오래전 몇몇 페이지 화면 아래 내렸다가 위로 올릴 수가 없어요 . 예전 그러던데 업데이트 에도 여전하네요 . 사용 편하게 부분 확인 해주시고 업데이트 달라졌으면 좋겠어요 . 1 . 메인 이벤트 행사 안내 뜨는 화면 오른쪽 밑 작게 있는 플러스 버튼 눌러서 전체 보기 넘어갔어요 . 화면 행사 종류 있나 보려고 아래 내린 위로 올라가려고 자꾸 새로고침 되면서 메인 돌아가 버려요 . 2 . 전체 판매 상품 리뷰 전체 상품 보기 아닌 원하는 홋수 선택 해서 리뷰 보려고 목록 아래 한번 내리면 위로 올라갈 수가 없어요 . 새로고침 버려요 . 제품 처음 화면 돌아가 버려서 여러가지 리뷰 골라 보려면 번거로워요 .,사용 경험 아주 불쾌함 오류 엄청 뜨고 , 요새 튕기 경험 매우 신선했습니다 . App 에서만 받을 있는 혜택 다운 받았는데 받을 있는 혜택 없었습니다 . 1시간 내내 결제 시도 해봤지만 , 오래 걸리고 통신 주문 취소 됩니다 . 엉망 진창 app 스마트폰 사고 처음 써 봅니다 . 기능 . 추천 않습니다 .,오류 빠른 시일 고쳐주시기 바랍니다 . 구매 할게 있어 접속 홈 화면 정상 카테고리 , 검색 창 , 장바구니 제대로 뜨는 화면 없습니다 . 이틀 꼴 오류 뜨는데 식 이용 없으면 존재 의미 없는듯 . 이벤트 좋지만 위 언급 부분 수정 이벤트 진행 좋을 같습니다 .,. 그러다가 저번 부터는 하얀 화면 뜨더니 아무 없어서 삭제 받으니 로그인 자꾸 서버 불안정하다면서 오류 걸리네요 . 와이파이 데이터 . 며칠 째 로그인 안되고 접속 안되고 몇번 삭제 받아도 똑같아요 . 답답합니다 .,직접 않아도 에서도 손쉽게 쇼핑 있어서 정말 !! 덕분 텅 장이 되었지만 .. 마음 행복 , 든든합니당 ^^ 근데 며칠 상품 평 등록 시 사진 첨부 안되는데 .. 그럴까 ㅠㅠ 사진 선택 Crop 눌러도 상품 평 사진 올라와있어요 ㅜㅜ 버그 일까 ~...?? 힝 포인트 받아야하는데 ..,답답할 검색 기능 이상합니다 . 페이지 그냥 쌓이기만 같아요 . 검색 홈 가려고 뒤 가기 누르면 검색 했던 페이지 그대로 나와서 뒤 가기 해야하는지 모르겠네요 12시 에는 쿠폰 배부 대기 생겨서 오류 거나 들어가려면 대기 기다렸다가 들어가야하는데 대기 생기는거 처음 봤어요 . 오류 나서 검색 오류 불편하고 속도 느려서 키 제품 검색 하는데 분 걸리는 같아요 . 수정 될지 모르겠네요 .,보다도 조건 부 정렬 했을 상품 보고 뒤 가기 정렬 리셋 되는게 가장 불편합니다 . 정렬 의미 없어요 . 물건 볼때 정렬 위 에서부터 내려가야 . 오류 버그 신고 있으면 좋을텐데 기능 없는것 같아서 리뷰 남깁니다 ... 솔직히 구글 리뷰 아무 보는거 같지만 ... 오류 외 에는 그냥 냥 크게 불편하지 않아서 신경 쓰여요 .,. 정렬순서 변경 상품 상세 보기 뒤 가면 정렬순서 리셋 있습니다 ( 자체 뒤 가기 버튼 으로는 설정 유지 되지만 휴대폰 뒤 가기 사용 리셋 되네요 ) 광고 이상한 위치 , 느리게 떠서 상품 클릭 했을 갑자기 위치 뜨는 광고 누르게 됩니다 . 봐도 보다 느린 본 없어요 .,다양한 상품 한눈 볼 있어서 매우 만족하지만 오늘 드림 라던가 직접 지러 가는 제품 주문 시킬 혼동 됩니다 . 주문 된다 했다가 안된다고 했다가 확인 어렵네요 . 추가 증정 제품 빠져서 왔다니 간 고객 센터 찾아보라고만 CS 대응 없을 뿐입니다 . 행사 상품 매장 에선 정가 인데 에선 할인 가로 팔고 엄청 손 해보는 기분 이라 통일 해주셨음 해 . 살짝 버벅이는 게 있지만 모든 화면 사진 이라 그런거 같은데 로딩 빠른 해서 여러 상품 찾는데 사용 있습니다 .,기능 에는 없지만 서비스 개선 많이 되어야 할것 같습니다 . 불량 제품 교환 번했는데 세번 불량 이었고 수령 확인 , 재 배송 과정 오래 걸렸습니다 . 고객 센터 통화량 많아서 연결 한참 걸리고 ux 직관 이진 않아서 교환 신청 진행 단계 확인 번거롭고 불쾌했어요,처음 실행 전면 광고 뜨는 건 이해 있다고 쳐도 ( 이해 감 . 유튭 처럼 단순히 컨텐츠 이용 하러 들어가는 아니고 , 애초 돈 쓰러 들어가는 인데 풀 화면 팝업 광고 띄우나요 ?) 초 광고 창 자동 사라지는 게 , 초 팝업창 끄지 자동 광고 들어가지는 역대 급 X 신 시스템 정말 짜증납니다 . 정말 정말 짜증납니다 . 제발 해 보세요 . 느려 터져서 짜증나는데 들어갈 빡치니까 아예 올 들어가게 돼요 .,페이지 리다 화면 멈추거나 보고 있던 상품 아예 프레임 밖 나갑니다 . 데이터 느린 편이긴 메인 화면 두세 들어가야 접속 되고 난리 . 당사 큐 레이 팅 광고 보고 싶지 않는데 광고 뿜뿜 봐야 하는지 모르겠습니다 . 데이터 간소화 하던지 , 광고 축소 시키던지 하셔야 듯 . 쇼핑몰 소비자 신경 거슬리게 몰래 몰래 광고 박아놓는데 댕청 .... 미가 있네요 . 배짱 장사 려 . 장바구니 클릭 하려는데 자꾸 선택 란 이동해 광고 페이지 넘어갑니다 . 의도 기분 나쁘고 , 의도 안일하다 싶네요 . 개선 많이 필요해 보입니다 .,물건 있는지 한눈 알아볼 있어요 . 탑 리뷰 순위도 있고 체험 단 이벤트 손쉽게 참가 있어서 . 근데 바라는 라면 최근 검색어 한번 씩 빨리 뜨더라고요 . 중간 한번 씩 랙 걸려요 . 외 에는 !,3 주전 ...? 보다가 백 라운드 넘겼다가 켜면 맨날 서버 끊겼다고 하네요 . 짜증나 죽겠어요 .. 완전 종료 켜면 보던 흐름 끊기고 완전 ㅡㅡ 빨리 업데이트 해주세요 폰 갤럭시 노트 10 데이터 환경 매우 좋으니 얼 ...

# %%
result = kiwi.analyze(doc)
result
def extract_keywords(text):
    result = kiwi.analyze(text)
    for token, pos, _, _ in result[0][0]:
        if pos[0] in 'NV':
            yield f'{token}'
list(extract_keywords(doc))
# Out:
# ['터치',
#  '밀리',
#  '터치',
#  '되',
#  '페스',
#  '타',
#  '티켓',
#  '구매',
#  '서버',
#  '터지',
#  '페이지',
#  '열리',
#  '일자',
#  '선택',
#  '라면',
#  '옵션',
#  '선택',
#  '창',
#  '띄우',
#  '지',
#  '결산',
#  '보',
#  '클릭',
#  '열',
#  '면',
#  '나이',
#  '광고',
#  '하루',
#  '보',
#  '않',
#  '이',
#  '넣',
#  '주',
#  '접속',
#  '차',
#  '나오',
#  '누르',
#  '되',
#  '자동',
#  '로그인',
#  '있',
#  '이벤트',
#  '참여',
#  '하',
#  '로그인',
#  '이용',
#  '있',
#  '뜨',
#  '로그',
#  '이',
#  '화면',
#  '자동',
#  '이동',
#  '로그인',
#  '있',
#  '이동',
#  '이벤트',
#  '참여',
#  '수',
#  '없',
#  '삭제',
#  '깔',
#  '뿐',
#  '이벤트',
#  '참여',
#  '시도',
#  '화',
#  '나',
#  '이렇',
#  '거',
#  '이',
#  '자동',
#  '로그인',
#  '기능',
#  '만들',
#  '거',
#  '이',
#  '서버',
#  '터지',
#  '수정',
#  '업데이트',
#  '사진',
#  '첨부',
#  '불가',
#  '사진',
#  '리뷰',
#  '불가',
#  '크',
#  '불편',
#  '참고',
#  '기기',
#  '갤럭시',
#  '노트',
#  '평소',
#  '사진',
#  '리뷰',
#  '올리',
#  '하',
#  '의미',
#  '로딩',
#  '길어지',
#  '이미지',
#  '파일',
#  '첨부',
#  '되',
#  '않',
#  '대체',
#  '이',
#  '싶',
#  '사진',
#  '리뷰',
#  '올리',
#  '이하',
#  '이미지',
#  '파일',
#  '첨부',
#  '이',
#  '하',
#  '갤러리',
#  '사진',
#  '파일',
#  '용량',
#  '확인',
#  '사진',
#  '첨부',
#  '시',
#  '하',
#  '하',
#  '불가',
#  '확인',
#  '되',
#  '모르',
#  '와이파이',
#  '칸',
#  '잇',
#  '데이터',
#  '시도',
#  '보',
#  '달라지',
#  '의미',
#  '로딩',
#  '미',
#  '첨부',
#  '되',
#  '문의',
#  '사진',
#  '첨부',
#  '하얗',
#  '네모',
#  '뜨',
#  '첨부',
#  '사진',
#  '첨부',
#  '확인',
#  '사진',
#  '용량',
#  '이하',
#  '이',
#  '갤러리',
#  '확인',
#  '사진',
#  '미',
#  '첨부',
#  '오류',
#  '고치',
#  '주',
#  '바라',
#  '수정',
#  '재업',
#  '문의',
#  '넣',
#  '답변',
#  '오',
#  '오',
#  '관련',
#  '내용',
#  '확인',
#  '중',
#  '이',
#  '하',
#  '추가',
#  '무겁',
#  '사용자',
#  '불편',
#  '호소',
#  '모르',
#  '척',
#  '하',
#  '피드백',
#  '반영',
#  '거',
#  '이',
#  '의문',
#  '이',
#  '로딩',
#  '시',
#  '나오',
#  '광고',
#  '없애',
#  '대신',
#  '저',
#  '진입',
#  '차',
#  '팝업',
#  '광고',
#  '띄우',
#  '실수',
#  '클릭',
#  '유도',
#  '정말',
#  '이',
#  '이용',
#  '사용자',
#  '편의',
#  '고려',
#  '않',
#  '채',
#  '화면',
#  '상품',
#  '행사',
#  '노출',
#  '집념',
#  '느끼',
#  '지',
#  '올인',
#  '저',
#  '화면',
#  '터치',
#  '밀리',
#  '것',
#  '터치',
#  '일쑤',
#  '상하',
#  '스크',
#  '좌우',
#  '스크',
#  '쓰',
#  '쓰',
#  '스트레스',
#  '크',
#  '지',
#  '화면',
#  '오늘',
#  '드림',
#  '강조',
#  '상단',
#  '메뉴',
#  '가리',
#  '불편',
#  '덧붙이',
#  '리뷰',
#  '답변',
#  '선택',
#  '하',
#  '심플',
#  '함',
#  '미학',
#  '바라',
#  '않',
#  '개선',
#  '이',
#  '관심',
#  '가지',
#  '주시',
#  '좋',
#  '가볍',
#  '편리',
#  '쓰',
#  '싶',
#  '지',
#  '만들',
#  '주',
#  '부탁',
#  '드리',
#  '이벤트',
#  '한번',
#  '사이트',
#  '터지',
#  '거',
#  '걸리',
#  '제품',
#  '택배',
#  '받',
#  '박스',
#  '구겨지',
#  '있',
#  '박스',
#  '정상',
#  '직육면체',
#  '기대',
#  '되',
#  '제품',
#  '기스',
#  '나',
#  '있',
#  '거',
#  '기본',
#  '옵션',
#  '택배',
#  '시키',
#  '되',
#  '오늘',
#  '드림',
#  '시키',
#  '것',
#  '주변',
#  '이',
#  '가',
#  '하',
#  '어쩌',
#  '깔',
#  '하',
#  '갤럭시',
#  '플립',
#  '안드로이드',
#  '버전',
#  '사용',
#  '이',
#  '전',
#  '몇몇',
#  '페이지',
#  '화면',
#  '아래',
#  '내리',
#  '위',
#  '올리',
#  '수',
#  '없',
#  '예전',
#  '그러',
#  '데',
#  '업데이트',
#  '여전하',
#  '사용',
#  '편하',
#  '부분',
#  '확인',
#  '주',
#  '업데이트',
#  '달라지',
#  '좋',
#  '메인',
#  '이벤트',
#  '행사',
#  '안내',
#  '뜨',
#  '화면',
#  '오른쪽',
#  '밑',
#  '작',
#  '있',
#  '플러스',
#  '버튼',
#  '누르',
#  '전체',
#  '보기',
#  '넘어가',
#  '화면',
#  '행사',
#  '종류',
#  '있',
#  '보',
#  '아래',
#  '내리',
#  '위',
#  '올라가',
#  '고치',
#  '되',
#  '메인',
#  '돌아가',
#  '버리',
#  '전체',
#  '판매',
#  '상품',
#  '리뷰',
#  '전체',
#  '상품',
#  '보',
#  '아니',
#  '원',
#  '홋수',
#  '선택',
#  '리뷰',
#  '보',
#  '목록',
#  '아래',
#  '번',
#  '내리',
#  '위',
#  '올라가',
#  '수',
#  '없',
#  '고치',
#  '버리',
#  '제품',
#  '처음',
#  '화면',
#  '돌아가',
#  '버리',
#  '가지',
#  '리뷰',
#  '고르',
#  '보',
#  '번거롭',
#  '사용',
#  '경험',
#  '불쾌',
#  '오류',
#  '뜨',
#  '요새',
#  '튕기',
#  '경험',
#  '받',
#  '있',
#  '혜택',
#  '다운',
#  '받',
#  '받',
#  '있',
#  '혜택',
#  '없',
#  '시간',
#  '결제',
#  '시도',
#  '보',
#  '걸리',
#  '통신',
#  '주문',
#  '취소',
#  '엉망',
#  '진창',
#  '스마트폰',
#  '사고',
#  '처음',
#  '쓰',
#  '보',
#  '기능',
#  '추천',
#  '않',
#  '오류',
#  '빠르',
#  '시일',
#  '고치',
#  '주',
#  '바라',
#  '구매',
#  '하',
#  '것',
#  '있',
#  '접속',
#  '홈',
#  '화면',
#  '정상',
#  '카테고리',
#  '검색',
#  '창',
#  '장바구니',
#  '뜨',
#  '화면',
#  '없',
#  '이틀',
#  '꼴',
#  '오류',
#  '뜨',
#  '식',
#  '이용',
#  '없',
#  '존재',
#  '의미',
#  '없',
#  '듯',
#  '이벤트',
#  '좋',
#  '위',
#  '언급',
#  '부분',
#  '수정',
#  '이벤트',
#  '진행',
#  '좋',
#  '같',
#  '저번',
#  '하얗',
#  '화면',
#  '뜨',
#  '없',
#  '삭제',
#  '받',
#  '로그인',
#  '서버',
#  '안정',
#  '오류',
#  '걸리',
#  '와이파이',
#  '데이터',
#  '며칠',
#  '째',
#  '로그인',
#  '되',
#  '접속',
#  '되',
#  '번',
#  '삭제',
#  '받',
#  '똑같',
#  '답답하',
#  '않',
#  '도',
#  '손쉽',
#  '쇼핑',
#  '있',
#  '덕분',
#  '장',
#  '되',
#  '마음',
#  '행복',
#  '든든하',
#  '며칠',
#  '상품',
#  '평',
#  '등록',
#  '시',
#  '사진',
#  '첨부',
#  '되',
#  '그렇',
#  '사진',
#  '선택',
#  '누르',
#  '상품',
#  '평',
#  '사진',
#  '올라오',
#  '있',
#  '버그',
#  '이',
#  '힝',
#  '포인트',
#  '받',
#  '하',
#  '답답하',
#  '검색',
#  '기능',
#  '이상',
#  '페',
#  '이',
#  '쌓이',
#  '같',
#  '검색',
#  '홈',
#  '가',
#  '뒤',
#  '가',
#  '누르',
#  '검색',
#  '페이지',
#  '나오',
#  '뒤',
#  '가',
#  '하',
#  '하',
#  '모르',
#  '시',
#  '쿠폰',
#  '배부',
#  '대기',
#  '생기',
#  '오류',
#  '이',
#  '들어가',
#  '대기',
#  '기다리',
#  '들어가',
#  '하',
#  '대기',
#  '생기',
#  '거',
#  '처음',
#  '보',
#  '오류',
#  '나',
#  '검색',
#  '오류',
#  '불편',
#  '속',
#  '느리',
#  '키',
#  '제품',
#  '검색',
#  '데',
#  '분',
#  '걸리',
#  '같',
#  '수정',
#  '되',
#  '모르',
#  '조건',
#  '정렬',
#  '상품',
#  '보고',
#  '뒤',
#  '가',
#  '정렬',
#  '리셋',
#  '되',
#  '것',
#  '불편',
#  '정렬',
#  '의미',
#  '없',
#  '물건',
#  '볼',
#  '때',
#  '정렬',
#  '위',
#  '내려가',
#  '오류',
#  '버그',
#  '신',
#  '있',
#  '좋',
#  '터',
#  '이',
#  '기능',
#  '없',
#  '것',
#  '같',
#  '리뷰',
#  '남기',
#  '구글',
#  '리뷰',
#  '보',
#  '거',
#  '같',
#  '오류',
#  '외',
#  '냥',
#  '크',
#  '불편',
#  '않',
#  '신경',
#  '쓰이',
#  '정렬',
#  '순서',
#  '변경',
#  '상품',
#  '보기',
#  '뒤',
#  '가',
#  '정렬',
#  '순서',
#  '리셋',
#  '있',
#  '자체',
#  '뒤',
#  '가',
#  '버튼',
#  '설정',
#  '유지',
#  '휴대폰',
#  '뒤',
#  '가기',
#  '사용',
#  '리셋',
#  '되',
#  '광고',
#  '이상',
#  '위치',
#  '느리',
#  '뜨',
#  '상품',
#  '클릭',
#  '위치',
#  '뜨',
#  '광고',
#  '누르',
#  '되',
#  '보',
#  '느리',
#  '본',
#  '없',
#  '다양',
#  '상품',
#  '한눈',
#  '볼',
#  '있',
#  '만족',
#  '오늘',
#  '드림',
#  '지',
#  '가',
#  '제품',
#  '주문',
#  '시키',
#  '혼동',
#  '되',
#  '주문',
#  '되',
#  '하',
#  '되',
#  '하',
#  '확인',
#  '어렵',
#  '추가',
#  '증정',
#  '제품',
#  '빠지',
#  '오',
#  '가',
#  '고객',
#  '센터',
#  '찾아보',
#  '대응',
#  '없',
#  '뿐',
#  '이',
#  '행사',
#  '상품',
#  '매장',
#  '정',
#  '이',
#  '데',
#  '할인',
#  '가',
#  '팔',
#  '손',
#  '보',
#  '기분',
#  '이',
#  '통일',
#  '주',
#  '하',
#  '버벅이',
#  '것',
#  '있',
#  '화면',
#  '사진',
#  '이',
#  '그러',
#  '거',
#  '같',
#  '로딩',
#  '빠르',
#  '하',
#  '상품',
#  '찾',
#  '데',
#  '사용',
#  '있',
#  '기능',
#  '없',
#  '서비스',
#  '개선',
#  '되',
#  '하',
#  '것',
#  '같',
#  '불량',
#  '제품',
#  '교환',
#  '번하',
#  '번',
#  '불량',
#  '이',
#  '수령',
#  '확인',
#  '배송',
#  '과정',
#  '걸리',
#  '고객',
#  '센터',
#  '통화량',
#  '많',
#  '연결',
#  '걸리',
#  '직관',
#  '이',
#  '않',
#  '교환',
#  '신청',
#  '진행',
#  '단계',
#  '확인',
#  '처음',
#  '실행',
#  '전면',
#  '광고',
#  '뜨',
#  '거',
#  '이해',
#  '있',
#  '치',
#  '이해',
#  '감',
#  '유튭',
#  '컨텐츠',
#  '이용',
#  '하',
#  '들어가',
#  '아니',
#  '애초',
#  '돈',
#  '쓰',
#  '들어가',
#  '이',
#  '이',
#  '풀',
#  '화면',
#  '팝업',
#  '광고',
#  '띄우',
#  '초',
#  '광고',
#  '창',
#  '자동',
#  '사라지',
#  '것',
#  '초',
#  '팝업',
#  '창',
#  '끄',
#  '자동',
#  '광고',
#  '들어가',
#  '지',
#  '역대',
#  '급',
#  '신',
#  '시스템',
#  '짜증',
#  '나',
#  '짜증',
#  '나',
#  '하',
#  '보',
#  '느리',
#  '터지',
#  '짜증',
#  '나',
#  '데',
#  '들어가',
#  '치',
#  '들',
#  '가',
#  '되',
#  '페이지',
#  '이',
#  '화면',
#  '멈추',
#  '보',
#  '있',
#  '상품',
#  '프레임',
#  '밖',
#  '나가',
#  '데이터',
#  '느리',
#  '편',
#  '이',
#  '메인',
#  '화면',
#  '들어가',
#  '접속',
#  '난리',
#  '당사',
#  '큐',
#  '레이',
#  '팅',
#  '광고',
#  '보',
#  '싶',
#  '않',
#  '광고',
#  '보',
#  '하',
#  '모르',
#  '데이터',
#  '하',
#  '광고',
#  '축소',
#  '시키',
#  '하',
#  '듯',
#  '쇼핑몰',
#  '소비자',
#  '신경',
#  '거슬리',
#  '광고',
#  '박',
#  '놓',
#  '댕청',
#  '미',
#  '있',
#  '배짱',
#  '장사',
#  '이',
#  '장바구니',
#  '클릭',
#  '하',
#  '선택',
#  '란',
#  '이동',
#  '광고',
#  '페이지',
#  '넘어가',
#  '의도',
#  '기분',
#  '나쁘',
#  '의도',
#  '안일',
#  '싶',
#  '개',
#  '필요',
#  '보이',
#  '물건',
#  '있',
#  '한눈',
#  '알아보',
#  '있',
#  '탑',
#  '리뷰',
#  '순위',
#  '있',
#  '체험',
#  '이벤트',
#  '손쉽',
#  '가',
#  '있',
#  '바라',
#  '라면',
#  '최근',
#  '검색어',
#  '번',
#  '뜨',
#  '중간',
#  '번',
#  '랙',
#  '걸리',
#  '외',
#  '주',
#  '전',
#  '보',
#  '백',
#  '라운드',
#  '넘기',
#  '켜',
#  '서버',
#  '끊기',
#  '하',
#  '짜증',
#  '나',
#  '죽',
#  '완전',
#  '종료',
#  '켜',
#  '보',
#  '흐름',
#  '끊기',
#  '완전',
#  '업데이트',
#  '주',
#  '폰',
#  '갤럭시',
#  '노트',
#  '데이터',
#  '환경',
#  '좋',
#  '고치',
#  '주',
#  '해당',
#  '사용',
#  '하',
#  '뒤',
#  '밀',
#  '두',
#  '들어가',
#  '들어가',
#  '스마트폰',
#  '인터넷',
#  '연결',
#  '끊어지',
#  '문구',
#  '뜨',
#  '뒤',
#  '가',
#  '누르',
#  '나가',
#  '없',
#  '강제',
#  '종료',
#  '들어가',
#  '불편',
#  '있',
#  '상품',
#  '설명',
#  '구매',
#  '정보',
#  '리뷰',
#  '칸',
#  '쉽',
#  ...]

# %%
len(result[0][0])
# noun = re.compile('[N]')

# for token, pos, start, end in result[0]:
#     if noun.match(pos):
#         print(token, pos, start, end)
# Out:
# 73101

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')
    document = document.replace(',','')
    document = document.replace(':','')
    document = document.replace('"','')
    document = document.replace('?','')
    tokenized_document = okt.morphs(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'터치': 70,
#  '밀려서': 2,
#  '되고': 61,
#  '올': 105,
#  '페스': 1,
#  '타': 13,
#  '티켓': 1,
#  '구매': 209,
#  '서버': 93,
#  '터져서': 13,
#  '페이지': 119,
#  '열리는': 2,
#  '일자': 2,
#  '선택': 70,
#  '라면': 13,
#  '옵션': 15,
#  '창': 108,
#  '띄워지지도': 1,
#  '결산': 1,
#  '해보라면서': 1,
#  '클릭': 61,
#  '돼요': 93,
#  '열면': 6,
#  '나이': 8,
#  '광고': 132,
#  '하루': 17,
#  '보지': 8,
#  '않기라도': 1,
#  '넣어': 4,
#  '주든가': 1,
#  '접속': 120,
#  '차로': 1,
#  '나와서': 16,
#  '잘못': 23,
#  '누르게': 2,
#  '되네요': 28,
#  '자동': 39,
#  '로그인': 486,
#  '되어있는데도': 1,
#  '이벤트': 118,
#  '참여': 16,
#  '하려고': 69,
#  '해야': 55,
#  '이용': 88,
#  '있다고': 16,
#  '떠요': 32,
#  '화면': 205,
#  '이동': 18,
#  '하겠다면서': 1,
#  '이미': 19,
#  '되어있으니': 1,
#  '그냥': 145,
#  '아무': 59,
#  '수가': 48,
#  '없네요': 51,
#  '삭제': 100,
#  '했다가': 17,
#  '깔아도': 19,
#  '뿐': 12,
#  '시도': 40,
#  '하다가': 27,
#  '화가': 19,
#  '나네요': 11,
#  '이럴거면': 25,
#  '기능': 61,
#  '만들어': 15,
#  '신': 14,
#  '건가': 47,
#  '터짐': 23,
#  '+': 19,
#  '수정': 39,
#  '업데이트': 188,
#  '사진': 57,
#  '첨부': 25,
#  '불가': 12,
#  '리뷰': 256,
#  '불가하여': 1,
#  '크게': 4,
#  '불편함': 16,
#  '(': 40,
#  '참고': 10,
#  '기기': 2,
#  '갤럭시': 13,
#  '노트': 14,
#  '9': 14,
#  ')': 40,
#  '평소': 16,
#  '처럼': 23,
#  '올리려고': 2,
#  '하는데': 107,
#  '무의미한': 2,
#  '로딩': 83,
#  '길어지고': 2,
#  '이미지': 11,
#  '파일': 3,
#  '아예': 54,
#  '되지': 23,
#  '않았음': 3,
#  '대체': 29,
#  '인가': 7,
#  '싶어': 5,
#  '올릴': 6,
#  '10': 25,
#  'mb': 3,
#  '이하': 2,
#  '라고': 71,
#  '하길래': 5,
#  '갤러리': 3,
#  '용량': 7,
#  '약': 8,
#  '2': 45,
#  '확인': 100,
#  '했음': 4,
#  '하여': 5,
#  '재시': 1,
#  '하려하니': 1,
#  '불가함을': 1,
#  '하게': 41,
#  '됨': 48,
#  '몰라': 4,
#  '와이파이': 25,
#  '5': 32,
#  '칸': 11,
#  '이어도': 1,
#  '일부러': 16,
#  '데이터': 29,
#  '해봤음에도': 1,
#  '전혀': 27,
#  '달라지지': 1,
#  '미': 4,
#  '11': 19,
#  '문의': 76,
#  '에서도': 14,
#  '하니': 21,
#  '하얀': 17,
#  '네모': 1,
#  '3': 43,
#  '뜨더니': 3,
#  '멀쩡히': 1,
#  '재차': 2,
#  '이하임': 1,
#  '조속': 1,
#  '히': 4,
#  '오류': 199,
#  '고쳐주기': 1,
#  '바람': 7,
#  '재업': 1,
#  '넣었는데': 4,
#  '답변': 42,
#  '오긴': 2,
#  '왔으나': 1,
#  '아직': 18,
#  '관련': 15,
#  '내용': 12,
#  '중이': 6,
#  '함': 76,
#  '7/3': 1,
#  '추가': 36,
#  '역시': 4,
#  '무겁고': 12,
#  '그대로': 12,
#  '사용자': 37,
#  '불편': 20,
#  '호소': 1,
#  '모른': 1,
#  '척': 3,
#  '하시면서': 3,
#  '피드백': 5,
#  '반영': 6,
#  '했다는': 2,
#  '건지': 151,
#  '의문': 8,
#  '이네': 35,
#  '시': 59,
#  '나오던': 1,
#  '없앤': 1,
#  '대신': 2,
#  '젠': 14,
#  '진입': 3,
#  '차': 3,
#  '팝업': 26,
#  '띄워서': 1,
#  '실수': 5,
#  '유도': 6,
#  '정말': 61,
#  '이지': 8,
#  '편의': 8,
#  '성은': 1,
#  '고려': 2,
#  '않은': 10,
#  '채': 5,
#  '최대한': 1,
#  '상품': 209,
#  '행사': 30,
#  '노출': 3,
#  '시키겠다는': 1,
#  '집념': 1,
#  '느껴집니다': 1,
#  '에만': 5,
#  '올인': 1,
#  '하시니': 1,
#  '엉뚱한게': 1,
#  '되기': 2,
#  '일쑤': 3,
#  '상하': 1,
#  '스': 52,
#  '크롤': 44,
#  '멋대로': 12,
#  '좌우': 2,
#  '빈번': 3,
#  '해서': 142,
#  '쓰면': 8,
#  '쓸수록': 1,
#  '스트레스': 10,
#  '커지네요': 1,
#  '첫': 52,
#  '오늘': 176,
#  '드림': 126,
#  '강조': 2,
#  '하느라': 1,
#  '상단': 8,
#  '메뉴': 17,
#  '가리는': 1,
#  '불편하고요': 2,
#  '덧붙여서': 1,
#  '하시는군요': 1,
#  '심플': 2,
#  '미학': 1,
#  '까진': 4,
#  '바라지': 2,
#  '않으니': 2,
#  'UI': 7,
#  '/': 11,
#  'UX': 1,
#  '개선': 148,
#  '이라도': 17,
#  '관심': 3,
#  '가져': 1,
#  '주시': 6,
#  '좋겠습니다': 8,
#  '가볍고': 2,
#  '편리해서': 1,
#  '쓰고': 28,
#  '싶어지는': 1,
#  '만들어주세요': 7,
#  '부탁드립니다': 21,
#  '뭔': 44,
#  '한번': 46,
#  '사이트': 23,
#  '터질거같이': 1,
#  '엄청': 50,
#  '오래': 25,
#  '걸리고': 45,
#  '제품': 178,
#  '택배': 22,
#  '받아': 20,
#  '박스': 8,
#  '구겨져있어요': 1,
#  '정상': 19,
#  '직육면체': 1,
#  '기대도': 2,
#  '안되고': 95,
#  '기스': 1,
#  '나있는거는': 1,
#  '기본': 23,
#  '로는': 7,
#  '절대': 13,
#  '시키면': 5,
#  '그나마': 2,
#  '시키는게': 1,
#  '덜합니다': 1,
#  ';;': 71,
#  '주변': 3,
#  '려면': 1,
#  '가야': 7,
#  '어쩔': 10,
#  '없이': 35,
#  '깔긴': 1,
#  '했는데': 149,
#  '별로': 42,
#  'z': 4,
#  '플립': 5,
#  '안드로이드': 11,
#  '버전': 17,
#  '사용': 201,
#  '인데': 86,
#  '오래전': 2,
#  '몇몇': 1,
#  '아래': 9,
#  '내렸다가': 2,
#  '위로': 7,
#  '없어요': 40,
#  '예전': 20,
#  '그러던데': 1,
#  '에도': 41,
#  '여전하네요': 1,
#  '편하게': 14,
#  '부분': 23,
#  '해주시': 9,
#  '고': 3,
#  '달라졌으면': 1,
#  '좋겠어요': 31,
#  '1': 110,
#  '메인': 38,
#  '안내': 24,
#  '뜨는': 22,
#  '오른쪽': 1,
#  '밑': 21,
#  '작게': 1,
#  '있는': 45,
#  '플러스': 5,
#  '버튼': 66,
#  '눌러서': 8,
#  '전체': 15,
#  '보기': 39,
#  '넘어갔어요': 1,
#  '종류': 6,
#  '있나': 7,
#  '보려고': 17,
#  '내린': 1,
#  '올라가려고': 1,
#  '자꾸': 151,
#  '새로고침': 30,
#  '되면서': 10,
#  '돌아가': 6,
#  '버려요': 4,
#  '판매': 14,
#  '아닌': 15,
#  '원하는': 5,
#  '홋수': 1,
#  '목록': 14,
#  '내리면': 8,
#  '올라갈': 1,
#  '처음': 86,
#  '버려서': 3,
#  '여러가지': 6,
#  '골라': 1,
#  '보려면': 2,
#  '번거로워요': 2,
#  '경험': 10,
#  '아주': 20,
#  '불쾌함': 1,
#  '뜨고': 77,
#  '요새': 5,
#  '튕기': 28,
#  '매우': 26,
#  '신선했습니다': 1,
#  'App': 3,
#  '에서만': 16,
#  '받을': 9,
#  '혜택': 21,
#  '다운': 53,
#  '받았는데': 10,
#  '없었습니다': 5,
#  '1시간': 8,
#  '내내': 4,
#  '결제': 249,
#  '해봤지만': 2,
#  '통신': 3,
#  '주문': 129,
#  '취소': 59,
#  '됩니다': 22,
#  '엉망': 13,
#  '진창': 2,
#  'app': 2,
#  '스마트폰': 7,
#  '사고': 17,
#  '써': 29,
#  '봅니다': 10,
#  '추천': 14,
#  '않습니다': 20,
#  '빠른': 23,
#  '시일': 2,
#  '고쳐주시기': 3,
#  '바랍니다': 15,
#  '할게': 4,
#  '있어': 16,
#  '홈': 38,
#  '카테고리': 24,
#  '검색': 106,
#  '장바구니': 96,
#  '제대로': 44,
#  '없습니다': 8,
#  '이틀': 2,
#  '꼴': 3,
#  '뜨는데': 21,
#  '식': 16,
#  '없으면': 5,
#  '존재': 6,
#  '의미': 6,
#  '없는듯': 3,
#  '좋지만': 3,
#  '위': 15,
#  '언급': 1,
#  '진행': 18,
#  '좋을': 5,
#  '같습니다': 9,
#  '그러다가': 2,
#  '저번': 9,
#  '부터는': 2,
#  '없어서': 26,
#  '받으니': 1,
#  '불안정하다면서': 1,
#  '걸리네요': 7,
#  '며칠': 15,
#  '째': 58,
#  '몇번': 46,
#  '받아도': 4,
#  '똑같아요': 4,
#  '답답합니다': 3,
#  '직접': 13,
#  '않아도': 4,
#  '손쉽게': 2,
#  '쇼핑': 79,
#  '있어서': 38,
#  '!!': 41,
#  '덕분': 11,
#  '텅': 1,
#  '장이': 2,
#  '되었지만': 1,
#  '마음': 12,
#  '행복': 1,
#  '든든합니당': 1,
#  '^^': 60,
#  '근데': 22,
#  '평': 10,
#  '등록': 30,
#  '안되는데': 20,
#  '그럴까': 3,
#  'ㅠㅠ': 70,
#  'Crop': 1,
#  '눌러도': 34,
#  '올라와있어요': 1,
#  'ㅜㅜ': 38,
#  '버그': 29,
#  '일까': 4,
#  '~': 82,
#  '힝': 1,
#  '포인트': 41,
#  '받아야하는데': 1,
#  '답답할': 2,
#  '이상합니다': 1,
#  '쌓이기만': 1,
#  '같아요': 58,
#  '가려고': 4,
#  '뒤': 65,
#  '가기': 36,
#  '누르면': 61,
#  '했던': 3,
#  '해야하는지': 2,
#  '모르겠네요': 25,
#  '12시': 9,
#  '에는': 32,
#  '쿠폰': 237,
#  '배부': 1,
#  '대기': 36,
#  '생겨서': 5,
#  '거나': 8,
#  '들어가려면': 2,
#  '기다렸다가': 2,
#  '들어가야하는데': 2,
#  '생기는거': 2,
#  '봤어요': 2,
#  '나서': 23,
#  '불편하고': 15,
#  '속도': 65,
#  '느려서': 47,
#  '키': 17,
#  '분': 25,
#  '걸리는': 11,
#  '될지': 1,
#  '보다도': 4,
#  '조건': 6,
#  '부': 3,
#  '정렬': 7,
#  '했을': 6,
#  '보고': 45,
#  '리셋': 10,
#  '되는게': 8,
#  '가장': 8,
#  '불편합니다': 14,
#  '물건': 53,
#  '볼때': 11,
#  '에서부터': 2,
#  '내려가야': 1,
#  '신고': 3,
#  '있으면': 16,
#  '좋을텐데': 1,
#  '없는것': 1,
#  '같아서': 4,
#  '남깁니다': 10,
#  '솔직히': 11,
#  '구글': 9,
#  '보는거': 2,
#  '같지만': 1,
#  '외': 8,
#  '냥': 3,
#  '불편하지': 1,
#  '않아서': 10,
#  '신경': 17,
#  '쓰여요': 1,
#  '정렬순서': 2,
#  '변경': 18,
#  '상세': 26,
#  '가면': 12,
#  '있습니다': 21,
#  '자체': 78,
#  '으로는': 9,
#  '설정': 45,
#  '유지': 4,
#  '되지만': 2,
#  '휴대폰': 17,
#  '이상한': 14,
#  '위치': 10,
#  '느리게': 5,
#  '떠서': 38,
#  '갑자기': 67,
#  '봐도': 7,
#  '보다': 35,
#  '느린': 23,
#  '본': 17,
#  '다양한': 12,
#  '한눈': 4,
#  '볼': 23,
#  '만족하지만': 1,
#  '라던가': 1,
#  '지러': 2,
#  '가는': 5,
#  '시킬': 7,
#  '혼동': 1,
#  '된다': 6,
#  '안된다고': 24,
#  '어렵네요': 3,
#  '증정': 5,
#  '빠져서': 1,
#  '왔다니': 1,
#  '간': 7,
#  '고객': 66,
#  '센터': 35,
#  '찾아보라고만': 1,
#  'CS': 2,
#  '대응': 3,
#  '없을': 9,
#  '뿐입니다': 1,
#  '매장': 110,
#  '에선': 18,
#  '정가': 2,
#  '할인': 88,
#  '가로': 2,
#  '팔고': 2,
#  '손': 7,
#  '해보는': 1,
#  '기분': 29,
#  '이라': 52,
#  '통일': 2,
#  '해주셨음': 1,
#  '해': 91,
#  '살짝': 6,
#  '버벅이': 1,
#  '는': 10,
#  '게': 104,
#  '있지만': 9,
#  '모든': 12,
#  '그런거': 6,
#  '같은데': 38,
#  '여러': 18,
#  '찾는데': 3,
#  '없지만': 4,
#  '서비스': 41,
#  '많이': 84,
#  '되어야': 3,
#  '할것': 3,
#  '불량': 4,
#  '교환': 11,
#  '번했는데': 3,
#  '세번': 3,
#  '이었고': 1,
#  '수령': 5,
#  '재': 38,
#  '배송': 267,
#  '과정': 5,
#  '걸렸습니다': 1,
#  '통화량': 1,
#  '많아서': 28,
#  '연결': 60,
#  '한참': 16,
#  'ux': 1,
#  '직관': 3,
#  '이진': 1,
#  '신청': 20,
#  '단계': 6,
#  '번거롭고': 2,
#  '불쾌했어요': 1,
#  '실행': 56,
#  '전면': 1,
#  '건': 45,
#  '이해': 16,
#  '쳐도': 4,
#  '감': 8,
#  '유튭': 1,
#  '단순히': 3,
#  '컨텐츠': 1,
#  '하러': 10,
#  '들어가는': 4,
#  '아니고': 72,
#  '애초': 4,
#  '돈': 48,
#  '쓰러': 7,
#  '풀': 4,
#  '띄우나요': 1,
#  '초': 7,
#  '사라지는': 1,
#  '팝업창': 8,
#  '끄지': 1,
#  '들어가지는': 2,
#  '역대': 3,
#  '급': 13,
#  'X': 4,
#  '시스템': 27,
#  '짜증납니다': 7,
#  '제발': 70,
#  '보세요': 3,
#  '느려': 58,
#  '짜증나는데': 2,
#  '들어갈': 17,
#  '빡치니까': 1,
#  '들어가게': 4,
#  '리다': 5,
#  '멈추거나': 1,
#  '있던': 3,
#  '프레임': 2,
#  '밖': 3,
#  '나갑니다': 1,
#  '편이긴': 1,
#  '두세': 1,
#  '들어가야': 4,
#  '난리': 5,
#  '당사': 1,
#  '큐': 2,
#  '레이': 4,
#  '팅': 3,
#  '싶지': 2,
#  '않는데': 6,
#  '뿜뿜': 1,
#  '봐야': 3,
#  '하는지': 16,
#  '모르겠습니다': 2,
#  '간소화': 1,
#  '하던지': 1,
#  '축소': 1,
#  '시키던지': 1,
#  '하셔야': 2,
#  '듯': 32,
#  '쇼핑몰': 23,
#  '소비자': 18,
#  '거슬리게': 1,
#  '몰래': 2,
#  '박아놓는데': 1,
#  '댕청': 1,
#  '미가': 1,
#  '있네요': 10,
#  '배짱': 2,
#  '장사': 10,
#  '려': 11,
#  '하려는데': 17,
#  '란': 9,
#  '이동해': 3,
#  '넘어갑니다': 7,
#  '의도': 4,
#  '나쁘고': 1,
#  '안일하다': 1,
#  '싶네요': 6,
#  '필요해': 1,
#  '보입니다': 3,
#  '있는지': 12,
#  '알아볼': 1,
#  '있어요': 26,
#  '탑': 7,
#  '순위도': 1,
#  '있고': 24,
#  '체험': 5,
#  '단': 9,
#  '참가': 1,
#  '바라는': 1,
#  '최근': 11,
#  '검색어': 2,
#  '씩': 32,
#  '빨리': 59,
#  '뜨더라고요': 2,
#  '중간': 7,
#  '랙': 4,
#  '걸려요': 29,
#  '!': 98,
#  '주전': 1,
#  '보다가': 11,
#  '백': 6,
#  '라운드': 1,
#  '넘겼다가': 1,
#  '켜면': 5,
#  '맨날': 12,
#  '끊겼다고': 4,
#  '하네요': 35,
#  '짜증나': 4,
#  '죽겠어요': 5,
#  '완전': 24,
#  '종료': 37,
#  '보던': 6,
#  '흐름': 1,
#  '끊기고': 8,
#  'ㅡㅡ': 77,
#  '해주세요': 108,
#  '폰': 59,
#  '환경': 9,
#  '좋으니': 1,
#  '얼른': 4,
#  '고쳐주시길': 2,
#  '해당': 5,
#  '밀어': 2,
#  '두고': 5,
#  '들어갔다': 4,
#  '들어가면': 45,
#  "'": 26,
#  '인터넷': 48,
#  '끊어졌습니다': 2,
#  '문구': 12,
#  '뜨며': 2,
#  '나갈': 1,
#  '강제': 24,
#  '불편함이': 2,
#  '설명': 20,
#  '정보': 57,
#  'Q': 4,
#  '&': 12,
#  'A': 4,
#  '쉽게': 9,
#  '넘어가게': 1,
#  '되면': 26,
#  '맨': 9,
#  '바뀌어': 4,
#  '곳': 46,
#  '없게': 3,
#  '0': 13,
#  '없는거지': 1,
#  ';;;': 15,
#  '지난달': 1,
#  '안되더니': 2,
#  '지우고': 21,
#  '까니까': 1,
#  '되는데': 44,
#  '하라': 59,
#  '고함': 4,
#  ';;;;;': 3,
#  '들어가거나': 3,
#  '뜸': 20,
#  '오프라인': 34,
#  '이든': 4,
#  '온라인': 57,
#  '영만': 4,
#  '롭스': 14,
#  '깔아': 7,
#  '봤습니다': 2,
#  'ㅎㅎㅎㅎ': 3,
#  '방': 3,
#  '요즘': 25,
#  '버퍼링': 10,
#  '심해': 26,
#  '특히': 12,
#  '신상': 10,
#  '뿌림': 1,
#  '방송': 2,
#  '작아졌다가': 1,
#  '음소거': 2,
#  '해제': 16,
#  '멈추고': 12,
#  '댓글': 7,
#  '올려도': 4,
#  '해줌': 1,
#  '쓸': 31,
#  '있게': 14,
#  '있으면서': 2,
#  '뜨게': 4,
#  '예요': 17,
#  '킹': 1,
#  '받게': 3,
#  '앨범': 1,
#  '수도': 8,
#  '장난': 25,
#  '치는': 2,
#  '이전': 5,
#  '터지는': 4,
#  '현상': 16,
#  '있었던': 2,
#  '관리자': 5,
#  '안고치시고': 1,
#  '하시나요': 7,
#  '누를': 6,
#  '1분': 12,
#  '가까이': 7,
#  '기다려야하고': 3,
#  '배송비': 18,
#  '조회': 8,
#  '문서': 1,
#  '작성': 34,
#  '않나': 3,
#  '넘게': 28,
#  '걸렸네요': 1,
#  ';': 43,
#  '전용': 10,
#  '주지': 2,
#  '마세요': 16,
#  'pc': 9,
#  '통한': 2,
#  '몰은': 1,
#  '빠르게': 9,
#  '잘만': 14,
#  '돌아가는데': 6,
#  '거기': 14,
#  '서는': 1,
#  '불가하고': 2,
#  '쓰라는': 8,
#  '몰릴': 2,
#  '최소한': 3,
#  '불편하진': 1,
#  '않게': 1,
#  '구축': 6,
#  '해놓았어야죠': 1,
#  '낭비': 5,
#  '밤': 10,
#  '짜증나고': 2,
#  '도중': 2,
#  '통장': 5,
#  '빠져나갔는데': 1,
#  '안되어있네요': 1,
#  '하자': 11,
#  '겁': 15,
#  '니까': 63,
#  '증설': 3,
#  '하든': 3,
#  '처리': 30,
#  '대한': 17,
#  '준비': 36,
#  '해놓고': 21,
#  '마케팅': 9,
#  '펼치던가': 1,
#  '하세요': 43,
#  '불편할': 2,
#  '느립니다': 13,
#  '불가능한': 2,
#  '넘어가지': 5,
#  '서너': 1,
#  '인식': 6,
#  '로드': 2,
#  '샵': 3,
#  '비교': 6,
#  '도저히': 4,
#  '불편해서': 6,
#  '문제점': 3,
#  '지속': 8,
#  '제기': 2,
#  '있는데': 31,
#  '있다는': 3,
#  '실망': 11,
#  '스럽네요': 3,
#  '반응속도': 7,
#  '느림': 68,
#  '내리는': 2,
#  '걸': 37,
#  '옆': 30,
#  '와이프': 4,
#  '했다고': 7,
#  '옮겨': 2,
#  '모션': 2,
#  '식이': 1,
#  '거슬림': 1,
#  '뜬': 2,
#  '이후': 19,
#  '그렇고': 5,
#  '된': 35,
#  '느낌': 13,
#  '무거워': 13,
#  '넘어가는데': 2,
#  '원래': 20,
#  '돌아오는데': 1,
#  '후기': 26,
#  '오면': 5,
#  '프리징': 1,
#  '되어있고': 6,
#  'ㅎㅎ': 41,
#  '스토어': 12,
#  '빡종하': 1,
#  '많지': 2,
#  '않은데': 2,
#  '해냅니다': 1,
#  '최적화': 19,
#  '장점': 5,
#  '-': 33,
#  '화장품': 42,
#  '생긴': 2,
#  '학생': 2,
#  '♥︎': 3,
#  '돼서': 21,
#  '도움': 2,
#  '브랜드': 18,
#  '즐길수': 1,
#  '일도': 8,
#  '가격': 51,
#  '대': 41,
#  '15000': 1,
#  '9000': 1,
#  '7000': 1,
#  '3000': 1,
#  '단점': 4,
#  '순위': 4,
#  '이름': 9,
#  '뜸니다': 1,
#  '잘못건': 1,
#  '이상해지고': 1,
#  '튕깁': 2,
#  '니': 32,
#  '그레': 2,
#  '예쁜거': 1,
#  '보는데': 12,
#  '튕겼어': 1,
#  '발색': 1,
#  '칠해': 1,
#  '볼수': 6,
#  '없다는게': 2,
#  '아쉽습니다': 3,
#  '이러해서': 1,
#  '4': 14,
#  '드리도록': 1,
#  '하게습니다': 1,
#  '은근': 1,
#  '들면서': 1,
#  '좋아졌어요': 3,
#  '받아서': 14,
#  '바코드': 24,
#  '찍기전에': 1,
#  '누루': 1,
#  '버리는데': 1,
#  '짝': 1,
#  '쓸데없는': 5,
#  '전향': 1,
#  '버림': 8,
#  '직원': 23,
#  '찍고': 2,
#  '완료': 20,
#  '활성화': 8,
#  '되던지': 1,
#  '해야지': 8,
#  '뭡': 3,
#  '계산': 5,
#  '직전': 8,
#  '눌려': 8,
#  '이라고': 45,
#  '반복': 38,
#  '스스로': 3,
#  '누룰': 1,
#  '있게끔': 1,
#  '해놓으면': 1,
#  '당연히': 6,
#  '아닙니까': 6,
#  '3만원': 6,
#  '이래서': 1,
#  '30분': 15,
#  '받고': 18,
#  '버렸네요': 1,
#  '최악': 53,
#  '였고': 1,
#  '되게': 17,
#  '놔도': 1,
#  '어렵게': 2,
#  '되어있네요': 1,
#  '괜히': 5,
#  '받으려다가': 1,
#  '였네요': 3,
#  '어제': 13,
#  '까지만': 2,
#  '작동': 20,
#  '했었는데': 4,
#  '캐시': 5,
#  '제거': 12,
#  '해보고': 6,
#  '다운로드': 22,
#  '봤지만': 2,
#  '인해': 4,
#  '시정': 1,
#  '엔': 31,
#  '들어가도': 12,
#  '흰색': 4,
#  '터지고': 15,
#  '느려지는건': 2,
#  '알았는데': 13,
#  '할줄은': 1,
#  '알았네요': 2,
#  '부탁드려요': 13,
#  '계정': 15,
#  '휴면': 11,
#  '상태': 34,
#  '여서': 7,
#  ...}

# %%
sorted_items_by_values = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)
print(dict(sorted_items_by_values))
# Out:
# {'로그인': 486, '배송': 267, '리뷰': 256, '결제': 249, '쿠폰': 237, '구매': 209, '상품': 209, '화면': 205, '사용': 201, '오류': 199, '업데이트': 188, '제품': 178, '오늘': 176, '가입': 153, '건지': 151, '자꾸': 151, '했는데': 149, '개선': 148, '그냥': 145, '해서': 142, '광고': 132, '주문': 129, '드림': 126, '접속': 120, '페이지': 119, '이벤트': 118, '회원': 114, '1': 110, '매장': 110, '창': 108, '해주세요': 108, '하는데': 107, '검색': 106, '올': 105, '안됨': 105, '게': 104, '삭제': 100, '확인': 100, '!': 98, '장바구니': 96, '안되고': 95, '서버': 93, '돼요': 93, '설치': 92, '해': 91, '이용': 88, '할인': 88, '인데': 86, '처음': 86, '많이': 84, '로딩': 83, '안되네요': 83, '~': 82, '쇼핑': 79, '자체': 78, '뜨고': 77, 'ㅡㅡ': 77, '문의': 76, '함': 76, '아니고': 72, '라는': 72, 'ㅋㅋ': 72, '라고': 71, ';;': 71, '터치': 70, '선택': 70, 'ㅠㅠ': 70, '제발': 70, '하려고': 69, '입력': 69, '느림': 68, '갑자기': 67, '버튼': 66, '고객': 66, '출석': 66, '뒤': 65, '속도': 65, '아이디': 64, '니까': 63, '체크': 63, '되고': 61, '클릭': 61, '기능': 61, '정말': 61, '누르면': 61, '^^': 60, '연결': 60, '아무': 59, '시': 59, '취소': 59, '빨리': 59, '폰': 59, '하라': 59, 'ㅠ': 59, '째': 58, '같아요': 58, '느려': 58, '기간': 58, '사진': 57, '정보': 57, '온라인': 57, '실행': 56, '별': 56, '해야': 55, '관리': 55, '버벅': 55, '임': 55, '아예': 54, '죠': 54, '다운': 53, '물건': 53, '최악': 53, '비밀번호': 53, '뭘': 53, '스': 52, '첫': 52, '이라': 52, '없네요': 51, '가격': 51, '엄청': 50, '안됩니다': 49, '수가': 48, '됨': 48, '돈': 48, '인터넷': 48, '건가': 47, '느려서': 47, '안되요': 47, '인증': 47, '한번': 46, '몇번': 46, '곳': 46, '없음': 46, '2': 45, '걸리고': 45, '있는': 45, '보고': 45, '설정': 45, '건': 45, '들어가면': 45, '이라고': 45, '크롤': 44, '뭔': 44, '제대로': 44, '되는데': 44, '했더니': 44, '3': 43, ';': 43, '하세요': 43, 'ㅋㅋㅋ': 43, '거리': 43, '답변': 42, '별로': 42, '화장품': 42, '좋은': 42, '카드': 42, '품절': 42, '하게': 41, '에도': 41, '!!': 41, '포인트': 41, '서비스': 41, 'ㅎㅎ': 41, '대': 41, '시도': 40, '(': 40, ')': 40, '없어요': 40, '없는': 40, '픽업': 40, '비번': 40, '자동': 39, '수정': 39, '보기': 39, '불편해요': 39, '메인': 38, '홈': 38, '있어서': 38, 'ㅜㅜ': 38, '떠서': 38, '같은데': 38, '재': 38, '반복': 38, '지연': 38, '사용자': 37, '종료': 37, '걸': 37, '뜨네요': 37, '번호': 37, '추가': 36, '가기': 36, '대기': 36, '준비': 36, '고쳐주세요': 36, '기': 36, '해결': 36, '이네': 35, '없이': 35, '보다': 35, '센터': 35, '하네요': 35, '된': 35, '에요': 35, '열': 35, '눌러도': 34, '오프라인': 34, '작성': 34, '상태': 34, '달': 34, '알림': 34, '가요': 34, '-': 33, '도대체': 33, '안되는': 33, '문': 33, '배송지': 33, '인지': 33, '깔았는데': 33, '떠요': 32, '5': 32, '에는': 32, '듯': 32, '씩': 32, '니': 32, '좋겠어요': 31, '쓸': 31, '있는데': 31, '엔': 31, '날': 31, '했는데도': 31, '네': 31, '행사': 30, '새로고침': 30, '등록': 30, '처리': 30, '옆': 30, '걍': 30, '항상': 30, 'ㅋㅋㅋㅋ': 30, '대체': 29, '데이터': 29, '써': 29, '버그': 29, '기분': 29, '걸려요': 29, '보니': 29, '저만': 29, '랑': 29, '어쩌': 29, '글': 29, 'ㅡ': 29, '되네요': 28, '쓰고': 28, '튕기': 28, '많아서': 28, '넘게': 28, '쓰레기': 28, 'cj': 28, '이랑': 28, '하다가': 27, '전혀': 27, '시스템': 27, '이건': 27, '팝업': 26, '매우': 26, '없어서': 26, '상세': 26, '있어요': 26, "'": 26, '되면': 26, '심해': 26, '후기': 26, '먹통': 26, '마이': 26, '반응': 26, '출첵': 26, '안되서': 26, '이럴거면': 25, '첨부': 25, '10': 25, '와이파이': 25, '오래': 25, '모르겠네요': 25, '분': 25, '요즘': 25, '장난': 25, '움': 25, '만든': 25, '~~': 25, '안내': 24, '카테고리': 24, '안된다고': 24, '있고': 24, '완전': 24, '강제': 24, '바코드': 24, '많아요': 24, '적용': 24, '업뎃': 24, 'ㅜ': 24, '개발자': 24, '대기업': 24, '성': 24, '걸림': 24, '하래': 24, '14': 24, '잘못': 23, '터짐': 23, '처럼': 23, '되지': 23, '사이트': 23, '기본': 23, '부분': 23, '빠른': 23, '나서': 23, '느린': 23, '볼': 23, '쇼핑몰': 23, '직원': 23, '한두': 23, '연락': 23, '무한': 23, '택배': 22, '뜨는': 22, '됩니다': 22, '근데': 22, '다운로드': 22, '사려': 22, '아닌가요': 22, '나오고': 22, '아직도': 22, '!!!': 22, 'ㅋ': 22, '될': 22, '들어가서': 22, '로그': 22, '하니': 21, '부탁드립니다': 21, '밑': 21, '혜택': 21, '뜨는데': 21, '있습니다': 21, '지우고': 21, '해놓고': 21, '돼서': 21, '에서는': 21, '라도': 21, 'CJ': 21, '않아요': 21, '넘': 21, '없는데': 21, '많고': 21, 'ㅎ': 21, '동의': 21, '환불': 21, '불편': 20, '받아': 20, '예전': 20, '아주': 20, '않습니다': 20, '안되는데': 20, '신청': 20, '설명': 20, '뜸': 20, '원래': 20, '완료': 20, '작동': 20, '하는게': 20, '튕겨': 20, '넘어가고': 20, '초기': 20, '이유': 20, '무': 20, '쓰는데': 20, '일주일': 20, '찾기': 20, '이': 20, '이미': 19, '깔아도': 19, '화가': 19, '+': 19, '11': 19, '정상': 19, '이후': 19, '최적화': 19, '제일': 19, '선착순': 19, '탭': 19, '발생': 19, '감사합니다': 1 ...

# %% [markdown]
# ## 이미지화

# %% [markdown]
# ### 단순 빈도

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='/Library/Fonts/paybooc Bold.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %% [markdown]
# ### tf-idf

# %%
weighted.sort_values('tf-idf',ascending=False).head()
# Out:
#         단어     tf-idf
# 2722   로그인  80.637597
# 1795   느려요  52.996977
# 781     결제  40.531674
# 5285  업데이트  37.962927
# 3494    배송  37.224887

# %%
weighted.sort_values('tf-idf',ascending=False).head(10)
# Out:
#         단어     tf-idf
# 2722   로그인  80.637597
# 1795   느려요  52.996977
# 781     결제  40.531674
# 5285  업데이트  37.962927
# 3494    배송  37.224887
# 5551    오류  36.299666
# 7116    쿠폰  34.042198
# 2749    리뷰  33.640829
# 8016    화면  33.130685
# 4127    사용  33.088908

# %%
cloud_weighted = wc.fit_words(weighted.head(2000))
cloud_weighted.to_image()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 cloud_weighted = wc.fit_words(weighted.head(2000))
#       2 cloud_weighted.to_image()
#
# File ~/anaconda3/lib/python3.11/site-packages/wordcloud/wordcloud.py:389, in WordCloud.fit_words(self, frequencies)
#     375 def fit_words(self, frequencies):
#     376     """Create a word_cloud from words and frequencies.
#     377
#     378     Alias to generate_from_frequencies.
#    (...)
#     387     self
#     388     """
# --> 389     return self.generate_from_frequencies(frequencies)
#
# File ~/anaconda3/lib/python3.11/site-packages/wordcloud/wordcloud.py:408, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     392 """Create a word_cloud from words and frequencies.
#     393
#     394 Parameters
#    (...)
#     405
#     406 """
#     407 # make sure frequencies are sorted and normalized
# --> 408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409 if len(frequencies) <= 0:
#     410     raise ValueError("We need at least 1 word to plot a word cloud, "
#     411                      "got %d." % len(frequencies))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:80, in comp_method_OBJECT_ARRAY(op, x, y)
#      78     if x.shape != y.shape:
#      79         raise ValueError("Shapes must match", x.shape, y.shape)
# ---> 80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
#      82     result = libops.scalar_compare(x.ravel(), y, op)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/ops.pyx:173, in pandas._libs.ops.vec_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'float'
