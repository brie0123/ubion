# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df = pd.read_excel('./data/화해_리뷰포함.xlsx')

# %%
df['content'].isnull().sum()
df
# Out:
#       Unnamed: 0                                            content  score  \
# 0              2  총평  사용자 수가 많은게 장점이고 그외에는 다 단점임 이용자 수만 많으면 옆동네 ...      3
# 1              4  발색리뷰 작성 시 검색 키워드 설정이 굉장히 이상합니다 제품명을 다 써도 안될 때가...      3
# 2             12  잘 쓰고 있는데 두 가지 기능이 추가되면 좋겠습니다 1 유저차단 기능이 있었으면 좋...      4
# 3             19  화장품 살 일 있을 때마다 정말 유용하게 잘쓰고있어요 리뷰 작성해주시는 분들도 꼼꼼...      3
# 4             25  화해를 통해서 많은 리뷰도 보고 정말 제게 맞는 유용하고 좋은 제품들을 많이 만날 ...      4
# ...          ...                                                ...    ...
# 3191       27568                             후기 보려 리뷰 쓰는데 괜찮은 것 같아요      5
# 3192       27608                        성분 가격 리뷰 이거없었을 때는 정말 원시인이었죠      5
# 3193       27621                                 100만 리뷰 더 승승장구 하시길      5
# 3194       27642                                   괜찮아요 솔직한 리뷰가 좋아요      5
# 3195       27666                                리뷰쓰는게 다른 거에 비해 까다로움      1
#
#       thumbsUpCount                  at
# 0                40 2023-10-12 13:54:15
# 1                14 2023-08-26 03:22:31
# 2               186 2020-07-20 11:13:11
# 3                42 2020-03-13 01:12:53
# 4                 3 2020-09-19 00:17:16
# ...             ...                 ...
# 3191              0 2017-06-26 13:26:20
# 3192              0 2016-01-06 20:25:04
# 3193              0 2016-05-29 22:32:14
# 3194              0 2016-08-29 07:30:35
# 3195              0 2017-05-01 12:19:16
#
# [3196 rows x 5 columns]

# %%
def tokenize(dataFrame):
    okt = Okt()
    
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
tokenized = tokenize(df)

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <3196x3402 sparse matrix of type '<class 'numpy.int64'>'
# 	with 37209 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <3196x3402 sparse matrix of type '<class 'numpy.float64'>'
# 	with 37209 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '평 사용자 수가 장점 외 단점 임 이용자 수만 옆 동네 글로우픽 장점 이벤트 샘플 줌 제품 체험 가능 단점 보임 옥색 인테리어 느낌 정리 느낌 주의 성분 거 대체 한국 유사과학 잡채 랭킹 시스템 랭킹 샘플 단기간 리뷰 키 워드 선택 글로우픽 리뷰 키 워드 검색 자꾸 비교,발색 리뷰 작성 시 검색 키 워드 설정 제품 일부 브랜드 별로 구분 분류 작업 검색 최적화 전혀 제품 라인 건 검색 필터 건,기능 추가 유저 차단 기능 해당 유저 차단 리뷰 댓글 일절 블라인드 처리 기능 프로필 상 웜톤 쿨톤 톤 설정 기능 톤 설정 색조 메이크업 제품 톤 매우 걸 수가 어플 사용,화장품 정말 리뷰 작성 분 작성 앱 업데이트 가요 업데이트 이벤트 참여 려고 몇개 상품 선택 개정 상품 선택 빈칸 폰 폰 폰 개선,화해 통해 리뷰 보고 정말 제품 만날 정말 앱 성분 피부 타입 별 랭킹 여러 리뷰 눈 볼 최애 앱 유튜브 통해 추천 제품 접 화해 앱 통해 기준 제품 과정 신세계 한가지 치명 화해 앱 결제 게 정말 분 결제 기억 실시간 계좌 이체 카드 결제 휴대폰결제 카드 결제 계좌 이체 연결 앱 오류 정보 학생 체크 카드 카드 보안 번호 결제 못 쇼핑몰 화해 단독 상품 사고 결제 못,화장품 관련 리뷰 상품 결제 기존 곳 온라인 결제 시 토스 무 통장 입금 결제 화해 온라인 결제 시스템 세라 휴대폰결제 카드 결제 계좌 이체 관련 앱 꽤 절차 최근 결제 처음 개선 더욱,화장품 성분 사용자 후기 볼 이용 리뷰 포인트 할인 제도 정말 결제 방식 제발 무 통장 입금 기능 화장품 어플 사용 실제 구매 어플 사용 못 해결 어플,리뷰 기간 포인트 혜자 움 업데이트 제때 화해 쇼핑 가격 보기 뷰티 온 메뉴 내용 캐릭터 표현 모습 실생활 유행 거리,성분 피부 리뷰 볼 랭킹 볼 제품 참고 화장품 구매 실패 확률 한가지 부탁 도구 랭킹 도구 사용 화해 도구 장단점 볼 파운데이션 브러쉬 아이섀도우 브러쉬 타입 분류 브러쉬 랭킹,화해 정말 애용 인기 제품 등록 이해 효과 제품 종종 기간 제품 등록 신청 데이터 수신 습니 네트워크 확인 와이파이 빵빵 앱 계속 포기 브랜드 제품 사진 표기 뭡 화해 앱 버그 해결 등록 성분 검색 가격 표시 위 앱 명성 바 문의 해결 임시 저장 리뷰 제품 등록 요청 로드 기간 뒷북,광고 리뷰 광고 실사 용인 성분 집착 화장품 구매 독 방부 처리 피부 뭐 신뢰 사용 면,리뷰 볼때 피부 맞춤 기능 정말 카테고리 별로 분류 피부 타입 별로 분류 피부 타입 별로 선택 검색 기능 매우,화장품 성분 도움 의성 알러지 성분 표기 정말 평소 화장품 몇몇 의성 함유 보고 매우 앱 주의 성분 확인 구매 피부 트러블 앱 쇼핑 이벤트 리뷰 포인트 개념 마음 앱 엄마 앱,화해 온 유저 앱 반복 화장품 살때 앱 스킨 케어 제품 성분 앱 성분 꼭 확인 리뷰 볼 정말 카테고리 랭킹 정말 글쿠 제품 할인 정말 진짜 앱 단종 제품 제품 단종 가격 수정,화해 앱 사용 유저 평소 화장품 살때 성분 관심 편 어플 상품 가격 최근 애용 어플 결제 수단 어려움 결제 앱 추가 설치 중간 결제 포기 상황 발생 리뷰 분 어려움 꼭 담당 부서 내용 전달 무 통장 입금 결제 수단 마련,화장품 골 이제 화장 시작 테 제품 제품 성분 리뷰 이건 성분 거 성분 거 성분 가격 거 앱 가장 별 습,화해 앱 사용 피부 눈치 발생 간식 일절 먹기 초콜렛 커피 사랑 발생 스트레스 이유 피부 그냥 얘기 처방 그게 다임 화해 앱 시작 피부 타입 모든 기초 사용 중단 드 매일 막 트러블 어쩌다가 생리 주기 거나 하루 이틀 아주 중단 단 피부 화해 성분 조회 피부 타입 별 사용 가능 사용자 리뷰 덕이 몇개 중단 화장품 사기 용도 상품 검색 상품 비교 판매 처 가격 비교 이벤트 몇개 구매 설 도착,화해 이벤트 신청 시 개인정보 전화번호 유출 의심 화장품 성분 리뷰 확인 곳 이벤트 신청 화해 꼼평단 신청 계속 스팸 보이스피싱 전화 쇄도 어플 거르 불구 최근 국제 전화 스팸 보이스피싱,모든 화장품 성분 리뷰 가득 차서 화장품 선별 사용 제품 리뷰 작성 도움 포인트 화장품 브랜드 카테고리 별로 정리 순위도 화장품 구입 도움 앱 이벤트 나름,사용 화장품 리뷰 포인트 출석 체크 매일 쿠폰 사용 화장품 할인 구매 재미 갑자기 포인트 쿠폰 중복 적용 그냥 쿠팡 화장품 정책 굳이 리뷰 포인드 출석 체크 필요성 요즘 네이버 화장품 성분 혜택 화장품 애플리캐이션 굳이 화해 계속 사용 필요성,점점 업데이트 앱 관리 제대로 로딩 화장품 리뷰 볼때 사진 로딩 예전 대폭 졋 점점 앱,포인트 리뷰 출첵 포인트 재미 소용 그냥 네이버 최저 가로,세 세 이용 가능 폰 혼란 사용 점도 리뷰,오른쪽 왼쪽 창 사용자 정보 수집 몰입 거 정말 꼼평단 당첨 사용자 품 무료 증정 공짜 피부 제품 소리 꼼평단 당첨 사용자 리뷰 꼼 평단 최소 기간 평가 화장품 기능 기간 꼼평단 공통점 며칠 효과 요가 대부분 도움 꼼 평단 리뷰 순위 글 리뷰 화장품 기간 효과 걸,제품 리뷰 몇개 리뷰 가기 버튼 리뷰 창 밑 해결 하나요,사용 제품 리뷰 봄웜여쿨 선택 봄웜 검색 추천 템 연관,정말 앱 잼 리뷰 수정 어플 구매 상품 제품 분구 피부 타입 별 성분 성분 참고 정말 포인트 할인 쿠폰 자주 선크림 토너 최저 습 샘플 체험 무료 보고 구매 마음 상품 품 구매 샘플 체험 배송비 페이 점도 정말 무료 체험 이벤트 꼼 평단 제품 정말 여러가지 한번 당첨 리뷰 제작자 앱 화해 피부 부디 바,화해 리뷰 포인트 기한 차곡차곡 사용 기한 부분 개선,성분 확인 리뷰 화장품 사기 자주 확인 앱 관리 제품 리뷰 화해 리뷰 포인트 적립 화해 쇼핑 이용 이제 포인트 주지 굳이 화해 쇼핑 이용 필요 듭니 가장 메리트,파우더 룸 앱 역시 선택 이유 이벤트 랜덤 당첨 파우더 룸 활동 응모 레벨 가래 리기 드릅 리뷰 화해 소통 파우더 룸 화해 추천,화해 앱 기초 제품 클렌징 선 케어 색조 화장품 제품 리뷰 백 성분 표시 비교 사기 인기 제품 제품 골 이벤트 랭킹 화플 건성 지성 중성 복합 게 화 테 진짜 도움 화해 제품 사고 사용 리뷰 포인트 적립 포인트 화장품 꼭꼭 사용,화해 정말 유저 화해 상품 예전 성분 가격 유명 브랜드 렉템 신생 브랜드 품질 화장품 구별 메이크업 꿀팁 유저 광고 후기 꼼 평단 회화 설 무료 화장품 보고 리뷰 기회 한번 요가 너므 습 화해 결제 방법 앱 카드 설치 학생 연령 층 화해 포인트 특 화해 구매 학생 앱 카드 부모님 결재 편의점 결제 무 통장 입금 연령 연령 결 제법,먼저 화해 거 진짜 화장품 인기 피부 타입 트러블 임산부 한눈 랭킹 화해 이용자 리뷰 덕분 제품 소비 더욱 도움 이벤트 제품 의성 알레르기 의성 거 다운 후회,화해 리뷰 앱 소개 장점 모든 화장품 성분 성분 뿐 화장품 성분 피부 타입 도움 기능 성분 장점 랭킹 화해 피플 분 직접 보고 정말 객관 조언 리뷰 랭킹 신뢰 화 블로그 형 화장품 이외 꿀팁 브러쉬 세척 법 용법 네일아트 다이어트 색 조합 퍼스 널 컬러 정말 꿀팁 이벤트 다공 화장품 리뷰 정말 템 경쟁률 당첨 은근 성분 화장품 리뷰 기회 단점 단점 화해 사랑,점점 기능 정말 앱 하나로 성분 보고 리뷰 보고 구매 화장품 쇼핑 확 드 평가 단 신청 제품 무료 볼 기회 후기 칸 건 필수 어플 정말,진짜 앱 제품 리뷰 볼 게 제일 한가지 추가 부분 렌즈 렌즈 화장 부분 부분 꼭 요새 렌즈 정보 찾기 화해 싹 렌즈 리뷰 제품 확인,리뷰 정말 사용자 직접 리뷰 작성 이벤트 진행 건 정말 태그 별로 꿀팁 페이지 참고 유해 성분 그냥,이제 화해 화장품 성분 가격 특징 리뷰 화해 한눈 확인 유튜브 블로그 홍보 보고 이제 걱정 이벤트 신청 껜 당첨 화해 분 그냥 확률 왜냐면 포기 계속 도전 쇼,화장품 대한 리뷰 가격 정보 상세 보기 계속 앱 즐겨찾기 상품 순서 기능 순,제품 햐 여러 의견 곳 가장 곳 화해 진짜 화해 덕분 피부 화장품 돈 일도 사용 화장품 어플 화해 이벤트 통해 시험 단 추첨 솔직 리뷰 당첨 노력 당첨 화해 랭킹 통해 화장품 브랜드 별 순위 피부 별 순위 연령 대별 순위 방면 순위 볼 걱정,어플 오류 자주 데이터 수신 튕기거 리뷰 아예 안보 제발,화장품 리뷰 볼 추천 앱 한가지 추가 필터 기능 피부 퍼스 널 컬러 추가 뭐 겨울 딥 쿨 라이트 봄웜 여름 쿨 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'평': 13,
#  '사용자': 140,
#  '수가': 40,
#  '장점': 85,
#  '외': 37,
#  '단점': 79,
#  '임': 37,
#  '이용자': 37,
#  '수만': 1,
#  '옆': 2,
#  '동네': 1,
#  '글': 117,
#  '로우': 13,
#  '픽': 9,
#  '이벤트': 325,
#  '샘플': 10,
#  '줌': 6,
#  '제품': 1079,
#  '체험': 25,
#  '가능': 23,
#  '보임': 2,
#  '옥색': 1,
#  '인테리어': 1,
#  '느낌': 31,
#  '정리': 44,
#  '주의': 58,
#  '성분': 2514,
#  '거': 351,
#  '대체': 5,
#  '한국': 6,
#  '유사과학': 1,
#  '잡채': 1,
#  '랭킹': 182,
#  '시스템': 14,
#  '단기간': 1,
#  '리뷰': 4150,
#  '키': 32,
#  '워드': 23,
#  '선택': 128,
#  '검색': 438,
#  '자꾸': 31,
#  '비교': 137,
#  '발색': 9,
#  '작성': 84,
#  '시': 16,
#  '설정': 18,
#  '일부': 3,
#  '브랜드': 102,
#  '별로': 211,
#  '구분': 22,
#  '분류': 28,
#  '작업': 2,
#  '최적화': 3,
#  '전혀': 11,
#  '라인': 6,
#  '건': 65,
#  '필터': 31,
#  '기능': 165,
#  '추가': 74,
#  '유저': 52,
#  '차단': 16,
#  '해당': 13,
#  '댓글': 35,
#  '일절': 2,
#  '블라인드': 42,
#  '처리': 34,
#  '프로필': 5,
#  '상': 4,
#  '웜톤': 8,
#  '쿨톤': 6,
#  '톤': 11,
#  '색조': 25,
#  '메이크업': 31,
#  '매우': 51,
#  '걸': 103,
#  '어플': 1053,
#  '사용': 523,
#  '화장품': 3069,
#  '정말': 788,
#  '분': 253,
#  '앱': 1190,
#  '업데이트': 71,
#  '가요': 40,
#  '참여': 22,
#  '려고': 7,
#  '몇개': 34,
#  '상품': 85,
#  '개정': 2,
#  '빈칸': 1,
#  '폰': 36,
#  '개선': 38,
#  '화해': 2043,
#  '통해': 213,
#  '보고': 662,
#  '만날': 2,
#  '피부': 1482,
#  '타입': 459,
#  '별': 134,
#  '여러': 106,
#  '눈': 51,
#  '볼': 471,
#  '최애': 5,
#  '유튜브': 16,
#  '추천': 337,
#  '접': 27,
#  '기준': 31,
#  '과정': 6,
#  '신세계': 6,
#  '한가지': 23,
#  '치명': 1,
#  '결제': 87,
#  '게': 93,
#  '기억': 11,
#  '실시간': 6,
#  '계좌': 15,
#  '이체': 13,
#  '카드': 11,
#  '휴대폰결제': 3,
#  '연결': 10,
#  '오류': 26,
#  '정보': 532,
#  '학생': 26,
#  '체크': 49,
#  '보안': 3,
#  '번호': 1,
#  '못': 62,
#  '쇼핑몰': 4,
#  '단독': 1,
#  '사고': 84,
#  '관련': 60,
#  '기존': 11,
#  '곳': 45,
#  '온라인': 9,
#  '토스': 5,
#  '무': 29,
#  '통장': 22,
#  '입금': 28,
#  '세라': 1,
#  '꽤': 35,
#  '절차': 1,
#  '최근': 24,
#  '처음': 154,
#  '더욱': 36,
#  '후기': 151,
#  '이용': 120,
#  '포인트': 72,
#  '할인': 23,
#  '제도': 1,
#  '방식': 12,
#  '제발': 33,
#  '실제': 65,
#  '구매': 418,
#  '해결': 24,
#  '기간': 38,
#  '혜자': 3,
#  '움': 10,
#  '제때': 1,
#  '쇼핑': 56,
#  '가격': 174,
#  '보기': 125,
#  '뷰티': 99,
#  '온': 5,
#  '메뉴': 2,
#  '내용': 26,
#  '캐릭터': 1,
#  '표현': 4,
#  '모습': 10,
#  '실생활': 4,
#  '유행': 7,
#  '거리': 7,
#  '참고': 158,
#  '실패': 56,
#  '확률': 33,
#  '부탁': 6,
#  '도구': 9,
#  '장단점': 43,
#  '파운데이션': 8,
#  '브러쉬': 16,
#  '아이섀도우': 1,
#  '애용': 67,
#  '인기': 34,
#  '등록': 99,
#  '이해': 14,
#  '효과': 21,
#  '종종': 8,
#  '신청': 32,
#  '데이터': 22,
#  '수신': 12,
#  '습': 43,
#  '네트워크': 6,
#  '확인': 428,
#  '와이파이': 14,
#  '빵빵': 8,
#  '계속': 113,
#  '포기': 8,
#  '사진': 56,
#  '표기': 19,
#  '뭡': 1,
#  '버그': 2,
#  '표시': 111,
#  '위': 38,
#  '명성': 1,
#  '바': 11,
#  '문의': 12,
#  '임시': 3,
#  '저장': 11,
#  '요청': 16,
#  '로드': 50,
#  '뒷북': 1,
#  '광고': 284,
#  '실사': 2,
#  '용인': 1,
#  '집착': 2,
#  '독': 4,
#  '방부': 1,
#  '뭐': 170,
#  '신뢰': 73,
#  '면': 16,
#  '볼때': 19,
#  '맞춤': 17,
#  '카테고리': 48,
#  '도움': 522,
#  '의성': 61,
#  '알러지': 14,
#  '평소': 56,
#  '몇몇': 7,
#  '함유': 3,
#  '트러블': 121,
#  '개념': 1,
#  '마음': 44,
#  '엄마': 18,
#  '반복': 6,
#  '살때': 254,
#  '스킨': 43,
#  '케어': 28,
#  '꼭': 279,
#  '글쿠': 1,
#  '진짜': 594,
#  '단종': 10,
#  '수정': 40,
#  '관심': 80,
#  '편': 41,
#  '수단': 17,
#  '어려움': 12,
#  '설치': 43,
#  '중간': 6,
#  '상황': 5,
#  '발생': 4,
#  '담당': 1,
#  '부서': 2,
#  '전달': 7,
#  '마련': 2,
#  '골': 28,
#  '이제': 138,
#  '화장': 107,
#  '시작': 46,
#  '테': 7,
#  '이건': 43,
#  '가장': 80,
#  '눈치': 4,
#  '간식': 1,
#  '먹기': 2,
#  '초콜렛': 1,
#  '커피': 1,
#  '사랑': 62,
#  '스트레스': 8,
#  '이유': 31,
#  '그냥': 148,
#  '얘기': 12,
#  '처방': 1,
#  '그게': 17,
#  '다임': 1,
#  '모든': 54,
#  '기초': 52,
#  '중단': 7,
#  '드': 10,
#  '매일': 20,
#  '막': 62,
#  '어쩌다가': 1,
#  '생리': 1,
#  '주기': 2,
#  '거나': 77,
#  '하루': 14,
#  '이틀': 3,
#  '아주': 70,
#  '단': 26,
#  '조회': 9,
#  '덕이': 1,
#  '사기': 99,
#  '용도': 12,
#  '판매': 16,
#  '처': 6,
#  '설': 4,
#  '도착': 2,
#  '개인정보': 3,
#  '전화번호': 1,
#  '유출': 1,
#  '의심': 9,
#  '꼼': 68,
#  '평단': 68,
#  '스팸': 2,
#  '보이스피싱': 2,
#  '전화': 2,
#  '쇄도': 1,
#  '거르': 9,
#  '불구': 4,
#  '국제': 1,
#  '가득': 4,
#  '차서': 1,
#  '선별': 2,
#  '순위도': 18,
#  '구입': 83,
#  '나름': 10,
#  '출석': 4,
#  '쿠폰': 8,
#  '재미': 33,
#  '갑자기': 29,
#  '중복': 6,
#  '적용': 4,
#  '쿠팡': 1,
#  '정책': 1,
#  '굳이': 20,
#  '포인드': 1,
#  '필요성': 3,
#  '요즘': 108,
#  '네이버': 39,
#  '혜택': 4,
#  '애플리캐이션': 1,
#  '점점': 26,
#  '관리': 30,
#  '제대로': 17,
#  '로딩': 19,
#  '예전': 71,
#  '대폭': 1,
#  '졋': 2,
#  '출첵': 1,
#  '소용': 3,
#  '최저': 3,
#  '가로': 1,
#  '세': 9,
#  '혼란': 1,
#  '점도': 21,
#  '오른쪽': 3,
#  '왼쪽': 2,
#  '창': 27,
#  '수집': 1,
#  '몰입': 1,
#  '당첨': 118,
#  '품': 9,
#  '무료': 33,
#  '증정': 3,
#  '공짜': 6,
#  '소리': 7,
#  '최소': 4,
#  '평가': 53,
#  '공통점': 2,
#  '며칠': 7,
#  '요가': 5,
#  '대부분': 37,
#  '순위': 65,
#  '가기': 6,
#  '버튼': 18,
#  '밑': 13,
#  '하나요': 12,
#  '봄웜여쿨': 1,
#  '봄웜': 2,
#  '템': 50,
#  '연관': 2,
#  '잼': 2,
#  '분구': 1,
#  '자주': 87,
#  '선크림': 9,
#  '토너': 8,
#  '배송비': 3,
#  '페이': 14,
#  '여러가지': 57,
#  '한번': 162,
#  '제작자': 6,
#  '부디': 1,
#  '기한': 3,
#  '차곡차곡': 1,
#  '부분': 59,
#  '적립': 6,
#  '주지': 3,
#  '필요': 29,
#  '듭': 12,
#  '메리트': 2,
#  '파우더': 4,
#  '룸': 3,
#  '역시': 14,
#  '랜덤': 2,
#  '활동': 3,
#  '응모': 10,
#  '레벨': 5,
#  '가래': 1,
#  '리기': 7,
#  '드릅': 1,
#  '소통': 15,
#  '클렌징': 7,
#  '선': 11,
#  '백': 2,
#  '화': 82,
#  '건성': 66,
#  '지성': 39,
#  '중성': 3,
#  '복합': 27,
#  '꼭꼭': 9,
#  '유명': 6,
#  '렉템': 1,
#  '신생': 1,
#  '품질': 3,
#  '구별': 8,
#  '꿀팁': 122,
#  '회화': 1,
#  '기회': 19,
#  '너므': 2,
#  '방법': 42,
#  '연령': 31,
#  '층': 3,
#  '특': 5,
#  '부모님': 3,
#  '결재': 6,
#  '편의점': 1,
#  '결': 2,
#  '제법': 1,
#  '먼저': 59,
#  '임산부': 3,
#  '한눈': 92,
#  '덕분': 208,
#  '소비': 15,
#  '알레르기': 92,
#  '다운': 80,
#  '후회': 47,
#  '소개': 21,
#  '뿐': 73,
#  '피플': 1,
#  '직접': 100,
#  '객관': 36,
#  '조언': 5,
#  '블로그': 102,
#  '형': 3,
#  '이외': 5,
#  '세척': 2,
#  '법': 17,
#  '용법': 6,
#  '네일아트': 1,
#  '다이어트': 13,
#  '색': 12,
#  '조합': 1,
#  '퍼스': 4,
#  '널': 4,
#  '컬러': 7,
#  '다공': 1,
#  '경쟁률': 2,
#  '은근': 7,
#  '하나로': 14,
#  '확': 17,
#  '칸': 14,
#  '필수': 88,
#  '제일': 56,
#  '렌즈': 13,
#  '요새': 19,
#  '찾기': 64,
#  '싹': 5,
#  '진행': 8,
#  '태그': 1,
#  '페이지': 14,
#  '유해': 207,
#  '특징': 6,
#  '홍보': 34,
#  '걱정': 43,
#  '껜': 1,
#  '왜냐면': 2,
#  '도전': 5,
#  '쇼': 1,
#  '대한': 105,
#  '상세': 29,
#  '즐겨찾기': 18,
#  '순서': 14,
#  '순': 37,
#  '햐': 1,
#  '의견': 23,
#  '돈': 67,
#  '일도': 27,
#  '시험': 4,
#  '추첨': 4,
#  '솔직': 26,
#  '노력': 16,
#  '대별': 8,
#  '방면': 2,
#  '튕기거': 1,
#  '아예': 27,
#  '안보': 28,
#  '겨울': 9,
#  '딥': 4,
#  '쿨': 4,
#  '라이트': 2,
#  '여름': 5,
#  '가을': 1,
#  '웜': 2,
#  '항상': 197,
#  '고민': 179,
#  '로션': 30,
#  '바디': 10,
#  '욤': 6,
#  '적립금': 7,
#  '이벵': 2,
#  '팁': 68,
#  '공유': 50,
#  '필러': 1,
#  '임티': 1,
#  '설명': 68,
#  '가끔': 35,
#  '쉐딩': 2,
#  '득탬했음': 1,
#  '원래': 59,
#  '뒤': 25,
#  '첫': 12,
#  '두번째': 4,
#  '외국': 2,
#  '장가': 5,
#  '배송': 10,
#  '관계자': 4,
#  '보시': 13,
#  '답변': 18,
#  '점검': 4,
#  '복구': 4,
#  '맘': 33,
#  '카카오': 13,
#  '바람': 5,
#  '화설': 1,
#  '프리': 1,
#  '브러시': 1,
#  '주시': 13,
#  '렉': 24,
#  '폼': 3,
#  '친구': 122,
#  '건의': 7,
#  '사항': 7,
#  '동물실험': 1,
#  '동물': 1,
#  '실험': 1,
#  '해': 87,
#  '시대': 8,
#  '신용카드': 7,
#  '북': 2,
#  '피드백': 7,
#  '위험': 23,
#  '달라': 12,
#  '위해': 43,
#  '처럼': 6,
#  '민감': 132,
#  '홍조': 6,
#  '디테일': 1,
#  '쏠쏠': 2,
#  '브랜드관': 1,
#  '무리': 1,
#  '직관': 3,
#  '단어': 13,
#  '포함': 15,
#  '번창': 10,
#  '고난': 5,
#  '이후': 36,
#  '공률': 1,
#  '정가': 3,
#  '정품': 4,
#  '등급': 17,
#  '실용': 9,
#  '매력': 4,
#  '휴대폰': 10,
#  '대애': 1,
#  '건가': 19,
#  '중이': 8,
#  '어워즈': 2,
#  '선정': 4,
#  '가입': 36,
#  '성별': 7,
#  '남성': 7,
#  '공부': 19,
#  '화이팅': 17,
#  '모낭': 2,
#  '염': 3,
#  '지루': 5,
#  '피부염': 8,
#  '고생': 21,
#  '뭔가': 16,
#  '대박': 14,
#  '살짝': 8,
#  '분석': 149,
#  '살수': 50,
#  '좀더': 26,
#  '해주시': 24,
#  '저가': 4,
#  '고가': 3,
#  '안심': 41,
#  '첨부': 8,
#  '끝': 12,
#  '다해': 8,
#  '밥': 1,
#  '재': 8,
#  '분과': 34,
#  '착착': 1,
#  '심심': 2,
#  '풀이': 1,
#  '개이득': 4,
#  '남': 21,
#  '지성민': 2,
#  '감성': 2,
#  '이름': 33,
#  '함': 38,
#  '결정': 60,
#  '쩌보': 1,
#  '신상': 5,
#  '닪는거': 1,
#  '용량': 18,
#  '장': 3,
#  '로그인': 28,
#  '조작': 2,
#  '이전': 14,
#  '폴더': 7,
#  '찜': 3,
#  '글자': 3,
#  '여요': 5,
#  '설문': 4,
#  '횟수': 5,
#  '성부': 2,
#  '폭발': 3,
#  '만원': 1,
#  '클렌져': 1,
#  '용품': 4,
#  '표': 32,
#  '사서': 57,
#  '막상': 8,
#  '별하나': 2,
#  '어쨋': 4,
#  '기분': 31,
#  '가루': 1,
#  '날림': 1,
#  '숨기': 1,
#  '요사': 1,
#  '고등학교': 2,
#  '군인': 1,
#  '아무': 26,
#  '군대': 1,
#  '장교': 1,
#  '태': 2,
#  '사려': 43,
#  '기': 24,
#  '달': 23,
#  '의미': 6,
#  '수분크림': 14,
#  '재생': 2,
#  '크림': 20,
#  '사이': 6,
#  '남자': 17,
#  '런가': 3,
#  '때매': 2,
#  '버': 2,
#  '문의사항': 3,
#  '뿐더러': 2,
#  '거기': 33,
#  '다가': 15,
#  '유발': 33,
#  '나이': 64,
#  '반값': 1,
#  '오늘': 14,
#  '가가': 3,
#  '헤어': 10,
#  '향수': 2,
#  '품성': 6,
#  '급': 2,
#  '존댓말': 1,
#  '여태': 11,
#  '조건': 8,
#  '거짓말': 8,
#  '박사': 3,
#  '우리엄마': 1,
#  '허락': 4,
#  '은': 11,
#  '초보': 11,
#  '하든': 1,
#  '은행': 2,
#  '입력': 9,
#  '나사': 1,
#  '꼴': 4,
#  '딜': 4,
#  '초특': 1,
#  '이하': 5,
#  '젹': 1,
#  '사이트': 18,
#  '그동안': 22,
#  '본격': 2,
#  '쓰기': 32,
#  '운영': 14,
#  '폭도': 2,
#  '커서': 5,
#  '올리브영': 4,
#  '즈음': 1,
#  '업뎃되': 2,
#  '꾸욱': 1,
#  '수도': 62,
#  '실행': 5,
#  '일주일': 5,
#  '하늘': 2,
#  '은진': 1,
#  '확율': 1,
#  '말씀': 4,
#  '신규': 4,
#  '가입자': 3,
#  '기제': 1,
#  '최악': 6,
#  '만족도': 5,
#  '적기': 4,
#  '지도': 22,
#  '겹': 6,
#  '최대': 5,
#  '안주': 1,
#  '지급': 3,
#  '정성': 11,
#  '재고': 2,
#  '안정': 4,
#  '장바구니': 4,
#  '목록': 9,
#  '화면': 16,
#  '빈번': 3,
#  '서두': 1,
#  '이점': 4,
#  '빡센데': 1,
#  '소멸': 1,
#  '빨': 6,
#  '싢어짐': 1,
#  '매체': 2,
#  '아이디': 15,
#  '핸드폰': 16,
#  '패드': 1,
#  '컨폰': 1,
#  '하라': 10,
#  '열': 8,
#  '하트': 4,
#  '색상': 5,
#  '케': 3,
#  '점순': 3,
#  '인생': 110,
#  '완전': 125,
#  '순이': 2,
#  '발견': 12,
#  '여드름': 79,
#  '자체': 35,
#  '통한': 2,
#  '뱅크': 3,
#  '신한은행': 1,
#  '우체국': 1,
#  '송금': 2,
#  '제한': 4,
#  '미자': 1,
#  '전체': 19,
#  '짱': 64,
#  '솜': 2,
#  '적극성': 1,
#  '성실': 1,
#  '보이지': 4,
#  '달리': 12,
#  '용감': 11,
#  '그대로': 11,
#  '뷰': 7,
#  '지우': 2,
#  '몸': 7,
#  '강': 31,
#  '추강': 5,
#  '추': 7,
#  '옛날': 30,
#  '얼굴': 51,
#  '욥': 11,
#  '덕': 29,
#  '마스크': 9,
#  '팩': 12,
#  '크기': 4,
#  '크게': 8,
#  '무조건': 70,
#  '평점': 32,
#  '의구': 1,
#  '라며': 2,
#  '기록': 9,
#  '한지': 13,
#  '뭘': 35,
#  '건젔': 1,
#  '마다': 15,
#  '애': 15,
#  '뭐썻어': 1,
#  '지유': 1,
#  '증말': 2,
#  '당청': 1,
#  '택배': 6,
#  '난후': 3,
#  '담청': 1,
#  '문자': 4,
#  '카톡': 11,
#  '떳는데': 1,
#  '용': 31,
#  '저번': 8,
#  '관리자': 9,
#  '구글': 5,
#  '치면': 14,
#  '이모': 1,
#  '예정': 7,
#  '강추': 40,
#  '손해': 3,
#  '전보': 12,
#  '파격': 2,
#  '초창': 7,
#  '쭉': 29,
#  '중인': 4,
#  '유지': 5,
#  '발전': 30,
#  '개발': 14,
#  '요하': 2,
#  '지인': 21,
#  '진성': 1,
#  '여태껏': 2,
#  '트럴블': 1,
#  '과대': 4,
#  '무었': 1,
#  '절말': 1,
#  '높이': 1,
#  '이벤': 3,
#  '개도': 8,
#  '실만': 1,
#  '타박': 1,
#  '란': 9,
#  '늘': 39,
#  '확정': 1,
#  '응원': 10,
#  '애긔': 1,
#  '공': 6,
#  '효율': 13,
#  '성도': 8,
#  '갑': 3,
#  '악용': 5,
#  '일반': 11,
#  '피해': 21,
#  '뇨': 3,
#  '쾌감': 2,
#  '프로': 4,
#  '소비자': 27,
#  '사춘기': 2,
#  '생기': 27,
#  '컨텐츠': 17,
#  '지식': 26,
#  '신제품': 19,
#  '다섯손가락': 1,
#  '더더': 13,
#  '쏙쏙': 7,
#  '알림': 9,
#  '삭제': 38,
#  '진동': 1,
#  '울리몀': 1,
#  '답글': 4,
#  '메일': 1,
#  '플레이스토어': 1,
#  '능력': 3,
#  '스': 5,
#  '크롤': 5,
#  '우측': 3,
#  '하단': 6,
#  '위로': 10,
#  '눌려': 1,
#  '화가': 3,
#  '겨': 4,
#  '지고': 3,
#  '제주도': 3,
#  '거주': 2,
#  '비용': 3,
#  '조': 1,
#  '권': 1,
#  '머': 8,
#  '아보': 6,
#  '랄': 4,
#  '번만': 3,
#  '유': 4,
#  '천자': 1,
#  '생활': 14,
#  '론': 3,
#  '자극': 8,
#  '계정': 23,
#  '현': 1,
#  '일과': 1,
#  '기적': 5,
#  '꿀앱': 6,
#  '최고': 110,
#  '쩐다': 1,
#  '만하': 16,
#  '센스': 1,
#  '만점': 4,
#  '석': 2,
#  '애정': 6,
#  '보더': 1,
#  '취지': 5,
#  '활용': 14,
#  '성은': 3,
#  '촬영': 1,
#  '거치': 4,
#  '데이터베이스': 3,
#  '데모': 2,
#  '해시태그': 1,
#  '유독': 3,
#  '곰': 1,
#  '모양': 5,
#  '부담': 6,
#  '기전': 165,
#  '세안': 2,
#  '제나': 1,
#  '햇': 14,
#  '디자인': 16,
#  '주로': 8,
#  '장문': 1,
#  '장려': 1,
#  '댓': 2,
#  '절절': 3,
#  '요구': 3,
#  '정작': 4,
#  '핵심': 2,
#  '그거': 29,
#  '타': 4,
#  '최신': 5,
#  '버전': 5,
#  '서버': 9,
#  '메인': 4,
#  '벌써': 11,
#  '미리': 54,
#  '맨': 4,
#  '만해': 11,
#  '함량': 3,
#  '토대': 3,
#  '믿음': 59,
#  '신경': 37,
#  '체적': 1,
#  '상한': 1,
#  '위험성': 14,
#  '미백': 7,
#  '지속': 7,
#  '성격': 6,
#  '투자': 3,
#  '비': 7,
#  '요정': 1,
#  '팩트': 7,
#  '오시': 1,
#  '아시': 2,
#  '정리정돈': 1,
#  '용어': 1,
#  '노출': 6,
#  '부언': 1,
#  '분위기': 6,
#  '결론': 8,
#  '똥망': 1,
#  '치기': 3,
#  '프라푸치노': 1,
#  '엽떡': 1,
#  '치맥': 1,
#  '아웃': 1,
#  '문화': 1,
#  '선도': 1,
#  '금방': 3,
#  '관': 14,
#  '유효': 1,
#  '어쩜': 1,
#  '년새': 1,
#  '거인': 1,
#  '안성맞춤': 2,
#  '장공': 2,
#  '진심': 30,
#  '물통': 1,
#  '이야기': 10,
#  '다한': 1,
#  '방출': 1,
#  '오프라인': 6,
#  '마장': 2,
#  '물품': 4,
#  '준비': 3,
#  '뷰러': 6,
#  '어퓨': 1,
#  '칭찬': 53,
#  '뎁': 1,
#  '소모품': 1,
#  '롱런': 1,
#  '법좀': 1,
#  '사지': 13,
#  '젤로': 1,
#  '개인': 35,
#  '판단': 23,
#  '거르길': 1,
#  '로서': 5,
#  '만족': 9,
#  '특별': 1,
#  '종류': 56,
#  '한참': 6,
#  '요즈음': 1,
#  '지점': 1,
#  '질감': 1,
#  '시기': 6,
#  '주문': 14,
#  ...}

# %%
df = pd.DataFrame({'키워드': list(word_counts.keys()), '빈도':list(word_counts.values())})
df = df.sort_values('빈도',ascending=False)
df.head(20)
# Out:
#      키워드    빈도
# 35    리뷰  4150
# 77   화장품  3069
# 26    성분  2514
# 91    화해  2043
# 95    피부  1482
# 80     앱  1190
# 17    제품  1079
# 75    어플  1053
# 78    정말   788
# 93    보고   662
# 237   진짜   594
# 120   정보   532
# 76    사용   523
# 221   도움   522
# 100    볼   471
# 96    타입   459
# 39    검색   438
# 190   확인   428
# 151   구매   418
# 27     거   351

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='/Library/Fonts/paybooc Bold.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
