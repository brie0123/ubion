# %%
pip install -U langchain-cli
# Out:
# Collecting langchain-cli
#   Downloading langchain_cli-0.0.21-py3-none-any.whl.metadata (1.3 kB)
# Collecting gitpython<4.0.0,>=3.1.40 (from langchain-cli)
#   Downloading GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Collecting langserve>=0.0.16 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading langserve-0.0.41-py3-none-any.whl.metadata (37 kB)
# Collecting tomlkit<0.13.0,>=0.12.2 (from langchain-cli)
#   Downloading tomlkit-0.12.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<0.10.0,>=0.9.0 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting uvicorn<0.24.0,>=0.23.2 (from langchain-cli)
#   Downloading uvicorn-0.23.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4.0.0,>=3.1.40->langchain-cli)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting httpx>=0.23.0 (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Using cached httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting langchain>=0.0.333 (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading langchain-0.1.7-py3-none-any.whl.metadata (13 kB)
# Collecting orjson>=2 (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading orjson-3.9.14-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.3 MB/s eta 0:00:00
# Collecting pydantic>=1 (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading pydantic-2.6.1-py3-none-any.whl.metadata (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 1.8 MB/s eta 0:00:00:00:01
# Collecting fastapi<1,>=0.90.1 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse>=0.3.1 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting sse-starlette<2.0.0,>=1.3.0 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading sse_starlette-1.8.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer<0.10.0,>=0.9.0->typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from typer<0.10.0,>=0.9.0->typer[all]<0.10.0,>=0.9.0->langchain-cli) (4.9.0)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich<14.0.0,>=10.11.0 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: h11>=0.8 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from uvicorn<0.24.0,>=0.23.2->langchain-cli) (0.14.0)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi<1,>=0.90.1->langserve[all]>=0.0.16->langchain-cli)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.40->langchain-cli)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting anyio (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Using cached anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading httpcore-1.0.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.4)
# Requirement already satisfied: sniffio in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.3.0)
# Collecting PyYAML>=5.3 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.0.27)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading aiohttp-3.9.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.20 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading langchain_community-0.0.20-py3-none-any.whl.metadata (8.1 kB)
# Collecting langchain-core<0.2,>=0.1.22 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading langchain_core-0.1.23-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.1,>=0.0.83 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading langsmith-0.0.92-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=1->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic>=1->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading pydantic_core-2.16.2-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli) (2.15.1)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (31 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading marshmallow-3.20.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.1)
# Collecting langsmith<0.1,>=0.0.83 (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading langsmith-0.0.87-py3-none-any.whl.metadata (10 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2,>=0.1.22->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading langchain_cli-0.0.21-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 971.8 kB/s eta 0:00:00
# Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 6.0 MB/s eta 0:00:00
# Downloading langserve-0.0.41-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.8/512.8 kB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.1 MB/s eta 0:00:00
# Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.7 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.1 MB/s eta 0:00:00
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 2.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.7 MB/s eta 0:00:00
# Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# Downloading httpcore-1.0.3-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.2 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.1.7-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.9/815.9 kB 11.3 MB/s eta 0:00:0000:01
# Downloading orjson-3.9.14-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 kB 5.7 MB/s eta 0:00:00ta 0:00:01
# Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 6.6 MB/s eta 0:00:00:00:01
# Downloading pydantic_core-2.16.2-cp311-cp311-macosx_10_12_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 5.1 MB/s eta 0:00:00:00:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading sse_starlette-1.8.2-py3-none-any.whl (8.9 kB)
# Downloading aiohttp-3.9.3-cp311-cp311-macosx_10_9_x86_64.whl (398 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.5/398.5 kB 8.4 MB/s eta 0:00:00:00:01
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_community-0.0.20-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading langchain_core-0.1.23-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 4.7 MB/s eta 0:00:00:00:01
# Using cached anyio-4.2.0-py3-none-any.whl (85 kB)
# Downloading langsmith-0.0.87-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.9/187.9 kB 3.3 MB/s eta 0:00:00:00:01
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 1.3 MB/s eta 0:00:00
# Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.2 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl (30 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: tomlkit, tenacity, smmap, shellingham, PyYAML, pydantic-core, packaging, orjson, mypy-extensions, multidict, mdurl, jsonpatch, httpx-sse, httpcore, frozenlist, colorama, click, anyio, annotated-types, yarl, uvicorn, typing-inspect, typer, starlette, pydantic, marshmallow, markdown-it-py, httpx, gitdb, aiosignal, rich, langsmith, gitpython, fastapi, dataclasses-json, aiohttp, sse-starlette, langchain-core, langchain-community, langchain, langserve, langchain-cli
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
# Successfully installed PyYAML-6.0.1 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.2.0 click-8.1.7 colorama-0.4.6 dataclasses-json-0.6.4 fastapi-0.109.2 frozenlist-1.4.1 gitdb-4.0.11 gitpython-3.1.42 httpcore-1.0.3 httpx-0.26.0 httpx-sse-0.4.0 jsonpatch-1.33 langchain-0.1.7 langchain-cli-0.0.21 langchain-community-0.0.20 langchain-core-0.1.23 langserve-0.0.41 langsmith-0.0.87 markdown-it-py-3.0.0 marshmallow-3.20.2 mdurl-0.1.2 multidict-6.0.5 mypy-extensions-1.0.0 orjson-3.9.14 packaging-23.2 pydantic-2.6.1 pydantic-core-2.16.2 rich-13.7.0 shellingham-1.5.4 smmap-5.0.1 sse-starlette-1.8.2 starlette-0.36.3 tenacity-8.2.3 tomlkit-0.12.3 typer-0.9.0 typing-inspect-0.9.0 uvicorn-0.23.2 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain openai langchain-experimental
# Out:
# Requirement already satisfied: langchain in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (0.1.7)
# Requirement already satisfied: openai in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (1.12.0)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.0.51-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.20 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.22 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (0.1.23)
# Requirement already satisfied: langsmith<0.1,>=0.0.83 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (0.26.0)
# Requirement already satisfied: sniffio in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.22->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Downloading langchain_experimental-0.0.51-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 kB 2.9 MB/s eta 0:00:0000:01
# Installing collected packages: langchain-experimental
# Successfully installed langchain-experimental-0.0.51

# %%
export LANGCHAIN_TRACING_V2="true"
export LANGCHAIN_API_KEY="..."
# Out:
#   Cell In[2], line 1
#     export LANGCHAIN_TRACING_V2="true"
#            ^
# SyntaxError: invalid syntax

# %%
pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.0.6-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.2,>=0.1.16 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-openai) (0.1.23)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-openai) (1.26.4)
# Collecting openai<2.0.0,>=1.10.0 (from langchain-openai)
#   Downloading openai-1.12.0-py3-none-any.whl.metadata (18 kB)
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai)
#   Downloading tiktoken-0.6.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (4.2.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.0.88,>=0.0.87 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (0.0.87)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (8.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.26.0)
# Requirement already satisfied: sniffio in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.9.0)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.5.2->langchain-openai)
#   Downloading regex-2023.12.25-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain-openai) (3.4)
# Requirement already satisfied: certifi in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1.16->langchain-openai) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.16->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.16->langchain-openai) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1.16->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/lib/python3.11/site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1.16->langchain-openai) (2.1.0)
# Downloading langchain_openai-0.0.6-py3-none-any.whl (29 kB)
# Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 6.5 MB/s eta 0:00:00
# Downloading tiktoken-0.6.0-cp311-cp311-macosx_10_9_x86_64.whl (999 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.8/999.8 kB 13.9 MB/s eta 0:00:00a 0:00:01
# Downloading regex-2023.12.25-cp311-cp311-macosx_10_9_x86_64.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: regex, tiktoken, openai, langchain-openai
# Successfully installed langchain-openai-0.0.6 openai-1.12.0 regex-2023.12.25 tiktoken-0.6.0
# Note: you may need to restart the kernel to use updated packages.
